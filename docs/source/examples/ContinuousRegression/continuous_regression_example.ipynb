# %% [markdown]
# # Setting things up

# %% [markdown]
# ## Installation

# %%
# !pip install AutoCarver[jupyter]

# %%
import sys
import os

print(os.listdir('../../../../../AutoCarver'))

sys.path.append('../../../../../AutoCarver')
sys.path.append('../../../../../AutoCarver/AutoCarver')
sys.path.append('../../../../../AutoCarver/AutoCarver/discretizers')
sys.path.append('../../../../../AutoCarver/AutoCarver/discretizers/utils')
import AutoCarver

# %% [markdown]
# ## Titanic Data
#
# In this example notebook, we will use the Titanic dataset.
#
# The Titanic dataset is a well-known and frequently used dataset in the field of machine learning and data science. It provides information about the passengers on board the Titanic, the famous ship that sank on its maiden voyage in 1912. The dataset is often used for predictive modeling, classification, and regression tasks.
#
# The dataset includes various features such as passengers' names, ages, genders, ticket classes, cabin information, and whether they survived or not. The primary goal when working with the Titanic dataset is often to build predictive models that can infer whether a passenger survived or perished based on their individual characteristics (binary classification).

# %%
import pandas as pd

# URL to the Titanic dataset on Kaggle
titanic_url = "https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"

# Use pandas to read the CSV file directly from the URL
titanic_data = pd.read_csv(titanic_url)

# Display the first few rows of the dataset
titanic_data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# ## Target type and Carver selection

# %%
target = "Survived"

titanic_data[target].value_counts(dropna=False)
# Out:
# 0    545
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# The target ``"Survived"`` is a binary target of type ``int64`` used for a classification task. Hence we will use ``AutoCarver.BinaryCarver`` and ``AutoCarver.selectors.ClassificationSelector`` in following code blocks.

# %% [markdown]
# ## Data Sampling

# %%
from sklearn.model_selection import train_test_split

# stratified sampling by target
train_set, dev_set = train_test_split(titanic_data, test_size=0.33, random_state=42, stratify=titanic_data[target])

# %%
# checking target rate per dataset
train_set[target].mean(), dev_set[target].mean()
# Out:
# (0.38552188552188554, 0.3856655290102389)

# %% [markdown]
# # Picking up columns to Carve

# %%
train_set.head()
# Out:
#      Survived  Pclass                          Name     Sex   Age  \
# 617         0       3            Mr. Antoni Yasbeck    male  27.0
# 489         0       1     Mr. Harry Markland Molson    male  55.0
# 871         1       3      Miss. Adele Kiamie Najib  female  15.0
# 654         0       3  Mrs. John (Catherine) Bourke  female  32.0
# 653         0       3          Mr. Alexander Radeff    male  27.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 617                        1                        0  14.4542
# 489                        0                        0  30.5000
# 871                        0                        0   7.2250
# 654                        1                        1  15.5000
# 653                        0                        0   7.8958

# %%
# column data types
train_set.dtypes
# Out:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object

# %%
# values taken by Parents/Children Aboard
train_set["Parents/Children Aboard"].value_counts()
# Out:
# 0    438
# 1     87
# 2     60
# 3      3
# 5      3
# 4      2
# 6      1
# Name: Parents/Children Aboard, dtype: int64

# %%
# values taken by Pclass
train_set["Pclass"].value_counts()
# Out:
# 3    326
# 1    142
# 2    126
# Name: Pclass, dtype: int64

# %% [markdown]
# The feature ``"Pclass"`` is of type ``"int64"``, but it can be considered a qualitative ordinal feature rather than a quantitative discrete feature (ranking of named passenger classes). Thus we will add it to the list of ``ordinal_features`` and set the ordering of its values in ``values_orders`` (string values).
#
# ``"Sex"`` is the only quantitative categorical feature, it's added to the list of ``qualitative_features``.
#
# ``"Age"`` and ``"Fare"`` are quantitative continuous features, whilst ``"Siblings/Spouses Aboard"``, ``"Parents/Children Aboard"`` can be considered as quantitative discrete features. Those four features will be added to the list of ``quantitative_features``.

# %%
# lists of features per data type
quantitative_features = ["Age", "Fare", "Siblings/Spouses Aboard", "Parents/Children Aboard"]
qualitative_features = ["Sex"]
ordinal_features = ["Pclass"]

# user-specified ordering for ordinal features
values_orders = {
    "Pclass": ["1", "2", "3"]
}

# %% [markdown]
# # Using AutoCarver

# %% [markdown]
# ## AutoCarver settings
#
# ### Representativness of modalities
#
# The attribute ``min_freq`` allows one to choose the minimum frequency per basic modalities. It is used by **Discretizers**:
#
# - For quantitative features, it defines the number of quantiles to initialy discretize the features with.
#
# - For qualitative features, it defines the threshold under which a modality is grouped to either a default value or its closest modality.

# %%
min_freq = 0.02

# %% [markdown]
# **Tip:** should be set between ``0.01`` (slower, preciser, less robust) and ``0.2`` (faster, more robust)

# %% [markdown]
# ### Desired number of modalities
#
# The attribute ``max_n_mod`` allows one to choose the maximum number of modalities per carved feature. It is used by **Carvers** has the upper limit of number of modalities per consecutive combination of modalities.

# %%
max_n_mod = 5

# %% [markdown]
# **Tip:** should be set between ``3`` (faster, more robust) and ``7`` (slower, preciser, less robust)

# %% [markdown]
# ### Association metric
#
# The attribute ``sort_by`` allows one to choose the association metric used to sort combinations. Combinations of grouped modalities are ranked according to the specified modalities and the best ranked viable combination is returned by **Carvers**.

# %%
# For BinaryCarver, to be choosen amongst ["tschuprowt", "cramerv"]
sort_by = "tschuprowt"  # "cramerv"

# %% [markdown]
# **Tip:** use ``"tschuprowt"`` for more robust, or less output modalities, use ``"cramerv"`` for more output modalities.

# %% [markdown]
# ### Grouping NaNs
#
# The attribute ``dropna`` allows one to choose whether or not ``numpy.nan`` should be grouped with another modality. If set to ``True``, **Carvers** will first find the most suitable combination of non-NaN values, and then test out all possible combinations with ``numpy.nan``.

# %%
dropna = False  # anyway, there are no numpy.nan in this dataset

# %% [markdown]
# ### Optional attributes
#
# #### Minimal frequency per carved modality
#
# The attribute ``min_freq_mod`` allows one to choose the minimum frequency per output modality. It is used by **Carvers** in viability tests to put aside combinations that are not frequent enough in train or dev sets. By default, it is set to ``min_freq/2``.

# %%
min_freq_mod = None  # for 0.05,  at least 5 % of observations per output modality in train and dev sets

# %% [markdown]
# #### Type of output carved features
#
# The attribute ``output_dtype`` allows one to choose the output type:
#
# * Use ``"float"`` for integer output (default)
# * Use ``"str"`` for strin output

# %%
output_dtype = "float"  # "str"

# %% [markdown]
# ## Fitting AutoCarver

# %%
from AutoCarver import BinaryCarver

# intiating AutoCarver
auto_carver = BinaryCarver(
    quantitative_features=quantitative_features,
    qualitative_features=qualitative_features,
    ordinal_features=ordinal_features,
    values_orders=values_orders,
    min_freq=min_freq,
    min_freq_mod=min_freq_mod,
    max_n_mod=max_n_mod,
    dropna=dropna,
    sort_by=sort_by,
    output_dtype=output_dtype,
    verbose=True,  # showing statistics
    copy=True,  # whether or not to return a copy of the input dataset
)

# fitting on training sample, a dev sample can be specified to evaluate carving robustness
train_set_processed = auto_carver.fit_transform(train_set, train_set[target], X_dev=dev_set, y_dev=dev_set[target])
# Out:
# ------
# [Discretizer] Fit Qualitative Features
# ---
#  - [StringDiscretizer] Fit ['Pclass']
#  - [OrdinalDiscretizer] Fit ['Pclass']
#  - [CategoricalDiscretizer] Fit ['Sex']
# ------
#
# ------
# [Discretizer] Fit Quantitative Features
# ---
#  - [ContinuousDiscretizer] Fit ['Fare', 'Age', 'Siblings/Spouses Aboard', 'Parents/Children Aboard']
#  - [OrdinalDiscretizer] Fit ['Fare', 'Age', 'Siblings/Spouses Aboard', 'Parents/Children Aboard']
# c:\Users\defra\Desktop\git\PROJECTS\AutoCarver\docs\source\examples\BinaryClassification\../../../../../AutoCarver\AutoCarver\discretizers\discretizers.py:328: UserWarning:  - [QualitativeDiscretizer] Non-string features: ['Pclass']. Trying to convert them using type_discretizers.StringDiscretizer, otherwise convert them manually. Unexpected data types: [<class 'int'>].
#   warn(
# ------
#
#
# ------
# [AutoCarver] Fit Age (1/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_5a178_row0_col0, #T_5a178_row8_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5a178_row0_col1, #T_5a178_row16_col1, #T_5a178_row20_col1, #T_5a178_row28_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_5a178_row1_col0 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_5a178_row1_col1, #T_5a178_row9_col1, #T_5a178_row14_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_5a178_row2_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_5a178_row2_col1, #T_5a178_row6_col0, #T_5a178_row19_col1, #T_5a178_row22_col1, #T_5a178_row25_col1, #T_5a178_row26_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5a178_row3_col0, #T_5a178_row20_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_5a178_row3_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_5a178_row4_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_5a178_row4_col1 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_5a178_row5_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_5a178_row5_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_5a178_row6_col1, #T_5a178_row13_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_5a178_row7_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_5a178_row7_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_5a178_row8_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_5a178_row9_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_5a178_row10_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_5a178_row10_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_5a178_row11_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_5a178_row11_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_5a178_row12_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_5a178_row12_col1, #T_5a178_row27_col1 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_5a178_row13_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_5a178_row14_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_5a178_row15_col0, #T_5a178_row17_col0, #T_5a178_row29_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_5a178_row15_col1, #T_5a178_row17_col1, #T_5a178_row18_col1, #T_5a178_row23_col1, #T_5a178_row29_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_5a178_row16_col0, #T_5a178_row19_col0, #T_5a178_row27_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_5a178_row18_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_5a178_row21_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_5a178_row21_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_5a178_row22_col0, #T_5a178_row25_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_5a178_row23_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_5a178_row24_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_5a178_row24_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_5a178_row26_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_5a178_row28_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_5a178_row30_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_5a178_row30_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# </style>
# <table id="T_5a178" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a178_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_5a178_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a178_level0_row0" class="row_heading level0 row0" >x <= 2.000e+00</th>
#       <td id="T_5a178_row0_col0" class="data row0 col0" >0.750000</td>
#       <td id="T_5a178_row0_col1" class="data row0 col1" >0.027000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row1" class="row_heading level0 row1" >2.000e+00 < x <= 7.000e+00</th>
#       <td id="T_5a178_row1_col0" class="data row1 col0" >0.625000</td>
#       <td id="T_5a178_row1_col1" class="data row1 col1" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row2" class="row_heading level0 row2" >7.000e+00 < x <= 1.100e+01</th>
#       <td id="T_5a178_row2_col0" class="data row2 col0" >0.167000</td>
#       <td id="T_5a178_row2_col1" class="data row2 col1" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row3" class="row_heading level0 row3" >1.100e+01 < x <= 1.600e+01</th>
#       <td id="T_5a178_row3_col0" class="data row3 col0" >0.440000</td>
#       <td id="T_5a178_row3_col1" class="data row3 col1" >0.042000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row4" class="row_heading level0 row4" >1.600e+01 < x <= 1.800e+01</th>
#       <td id="T_5a178_row4_col0" class="data row4 col0" >0.323000</td>
#       <td id="T_5a178_row4_col1" class="data row4 col1" >0.052000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row5" class="row_heading level0 row5" >1.800e+01 < x <= 1.900e+01</th>
#       <td id="T_5a178_row5_col0" class="data row5 col0" >0.391000</td>
#       <td id="T_5a178_row5_col1" class="data row5 col1" >0.039000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row6" class="row_heading level0 row6" >1.900e+01 < x <= 2.050e+01</th>
#       <td id="T_5a178_row6_col0" class="data row6 col0" >0.111000</td>
#       <td id="T_5a178_row6_col1" class="data row6 col1" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row7" class="row_heading level0 row7" >2.050e+01 < x <= 2.100e+01</th>
#       <td id="T_5a178_row7_col0" class="data row7 col0" >0.190000</td>
#       <td id="T_5a178_row7_col1" class="data row7 col1" >0.035000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row8" class="row_heading level0 row8" >2.100e+01 < x <= 2.350e+01</th>
#       <td id="T_5a178_row8_col0" class="data row8 col0" >0.419000</td>
#       <td id="T_5a178_row8_col1" class="data row8 col1" >0.072000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row9" class="row_heading level0 row9" >2.350e+01 < x <= 2.400e+01</th>
#       <td id="T_5a178_row9_col0" class="data row9 col0" >0.542000</td>
#       <td id="T_5a178_row9_col1" class="data row9 col1" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row10" class="row_heading level0 row10" >2.400e+01 < x <= 2.500e+01</th>
#       <td id="T_5a178_row10_col0" class="data row10 col0" >0.133000</td>
#       <td id="T_5a178_row10_col1" class="data row10 col1" >0.025000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row11" class="row_heading level0 row11" >2.500e+01 < x <= 2.700e+01</th>
#       <td id="T_5a178_row11_col0" class="data row11 col0" >0.467000</td>
#       <td id="T_5a178_row11_col1" class="data row11 col1" >0.051000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row12" class="row_heading level0 row12" >2.700e+01 < x <= 2.850e+01</th>
#       <td id="T_5a178_row12_col0" class="data row12 col0" >0.250000</td>
#       <td id="T_5a178_row12_col1" class="data row12 col1" >0.034000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row13" class="row_heading level0 row13" >2.850e+01 < x <= 2.900e+01</th>
#       <td id="T_5a178_row13_col0" class="data row13 col0" >0.444000</td>
#       <td id="T_5a178_row13_col1" class="data row13 col1" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row14" class="row_heading level0 row14" >2.900e+01 < x <= 3.000e+01</th>
#       <td id="T_5a178_row14_col0" class="data row14 col0" >0.292000</td>
#       <td id="T_5a178_row14_col1" class="data row14 col1" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row15" class="row_heading level0 row15" >3.000e+01 < x <= 3.100e+01</th>
#       <td id="T_5a178_row15_col0" class="data row15 col0" >0.385000</td>
#       <td id="T_5a178_row15_col1" class="data row15 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_5a178_level0_row16" class="row_heading level0 row16" >3.100e+01 < x <= 3.200e+01</th>
#       <td id="T_5a178_row16_col0" class="data row16 col0" >0.500000</td>
#       <td
# Grouping modalities   : 100%|██████████| 31930/31930 [00:05<00:00, 6285.88it/s]
# Computing associations: 100%|██████████| 31930/31930 [00:07<00:00, 4514.91it/s]
# Testing robustness    :   0%|          | 1/31930 [00:04<43:25:44,  4.90s/it]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_f3830_row0_col0, #T_f3830_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f3830_row0_col1, #T_f3830_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f3830" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3830_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_f3830_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3830_level0_row0" class="row_heading level0 row0" >x <= 7.000e+00</th>
#       <td id="T_f3830_row0_col0" class="data row0 col0" >0.675000</td>
#       <td id="T_f3830_row0_col1" class="data row0 col1" >0.067000</td>
#     </tr>
#     <tr>
#       <th id="T_f3830_level0_row1" class="row_heading level0 row1" >7.000e+00 < x</th>
#       <td id="T_f3830_row1_col0" class="data row1 col0" >0.365000</td>
#       <td id="T_f3830_row1_col1" class="data row1 col1" >0.933000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_6552b_row0_col0, #T_6552b_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6552b_row0_col1, #T_6552b_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6552b" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6552b_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_6552b_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6552b_level0_row0" class="row_heading level0 row0" >x <= 7.000e+00</th>
#       <td id="T_6552b_row0_col0" class="data row0 col0" >0.588000</td>
#       <td id="T_6552b_row0_col1" class="data row0 col1" >0.058000</td>
#     </tr>
#     <tr>
#       <th id="T_6552b_level0_row1" class="row_heading level0 row1" >7.000e+00 < x</th>
#       <td id="T_6552b_row1_col0" class="data row1 col0" >0.373000</td>
#       <td id="T_6552b_row1_col1" class="data row1 col1" >0.942000</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
# ------
# [AutoCarver] Fit Siblings/Spouses Aboard (2/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_2ca7e_row0_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_2ca7e_row0_col1, #T_2ca7e_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2ca7e_row1_col0 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_2ca7e_row1_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_2ca7e_row2_col1, #T_2ca7e_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2ca7e_row3_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2ca7e" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ca7e_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_2ca7e_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ca7e_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_2ca7e_row0_col0" class="data row0 col0" >0.361000</td>
#       <td id="T_2ca7e_row0_col1" class="data row0 col1" >0.680000</td>
#     </tr>
#     <tr>
#       <th id="T_2ca7e_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 1.000e+00</th>
#       <td id="T_2ca7e_row1_col0" class="data row1 col0" >0.500000</td>
#       <td id="T_2ca7e_row1_col1" class="data row1 col1" >0.232000</td>
#     </tr>
#     <tr>
#       <th id="T_2ca7e_level0_row2" class="row_heading level0 row2" >1.000e+00 < x <= 2.000e+00</th>
#       <td id="T_2ca7e_row2_col0" class="data row2 col0" >0.550000</td>
#       <td id="T_2ca7e_row2_col1" class="data row2 col1" >0.034000</td>
#     </tr>
#     <tr>
#       <th id="T_2ca7e_level0_row3" class="row_heading level0 row3" >2.000e+00 < x</th>
#       <td id="T_2ca7e_row3_col0" class="data row3 col0" >0.094000</td>
#       <td id="T_2ca7e_row3_col1" class="data row3 col1" >0.054000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_b4b05_row0_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_b4b05_row0_col1, #T_b4b05_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b4b05_row1_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_b4b05_row2_col0, #T_b4b05_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b4b05_row3_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_b4b05_row3_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b4b05" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4b05_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_b4b05_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4b05_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_b4b05_row0_col0" class="data row0 col0" >0.320000</td>
#       <td id="T_b4b05_row0_col1" class="data row0 col1" >0.683000</td>
#     </tr>
#     <tr>
#       <th id="T_b4b05_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 1.000e+00</th>
#       <td id="T_b4b05_row1_col0" class="data row1 col0" >0.606000</td>
#       <td id="T_b4b05_row1_col1" class="data row1 col1" >0.242000</td>
#     </tr>
#     <tr>
#       <th id="T_b4b05_level0_row2" class="row_heading level0 row2" >1.000e+00 < x <= 2.000e+00</th>
#       <td id="T_b4b05_row2_col0" class="data row2 col0" >0.250000</td>
#       <td id="T_b4b05_row2_col1" class="data row2 col1" >0.027000</td>
#     </tr>
#     <tr>
#       <th id="T_b4b05_level0_row3" class="row_heading level0 row3" >2.000e+00 < x</th>
#       <td id="T_b4b05_row3_col0" class="data row3 col0" >0.286000</td>
#       <td id="T_b4b05_row3_col1" class="data row3 col1" >0.048000</td>
#     </tr>
#   </tbody>
# </table>
# Grouping modalities   : 100%|██████████| 7/7 [00:00<00:00, 3508.62it/s]
# Computing associations: 100%|██████████| 7/7 [00:00<00:00, 3508.62it/s]
# Testing robustness    :   0%|          | 0/7 [00:00<?, ?it/s]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_aca2d_row0_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_aca2d_row0_col1, #T_aca2d_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_aca2d_row1_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_aca2d_row2_col0, #T_aca2d_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_aca2d" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aca2d_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_aca2d_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aca2d_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_aca2d_row0_col0" class="data row0 col0" >0.361000</td>
#       <td id="T_aca2d_row0_col1" class="data row0 col1" >0.680000</td>
#     </tr>
#     <tr>
#       <th id="T_aca2d_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 2.000e+00</th>
#       <td id="T_aca2d_row1_col0" class="data row1 col0" >0.506000</td>
#       <td id="T_aca2d_row1_col1" class="data row1 col1" >0.266000</td>
#     </tr>
#     <tr>
#       <th id="T_aca2d_level0_row2" class="row_heading level0 row2" >2.000e+00 < x</th>
#       <td id="T_aca2d_row2_col0" class="data row2 col0" >0.094000</td>
#       <td id="T_aca2d_row2_col1" class="data row2 col1" >0.054000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_6329e_row0_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_6329e_row0_col1, #T_6329e_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6329e_row1_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_6329e_row2_col0, #T_6329e_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6329e" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6329e_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_6329e_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6329e_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_6329e_row0_col0" class="data row0 col0" >0.320000</td>
#       <td id="T_6329e_row0_col1" class="data row0 col1" >0.683000</td>
#     </tr>
#     <tr>
#       <th id="T_6329e_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 2.000e+00</th>
#       <td id="T_6329e_row1_col0" class="data row1 col0" >0.570000</td>
#       <td id="T_6329e_row1_col1" class="data row1 col1" >0.270000</td>
#     </tr>
#     <tr>
#       <th id="T_6329e_level0_row2" class="row_heading level0 row2" >2.000e+00 < x</th>
#       <td id="T_6329e_row2_col0" class="data row2 col0" >0.286000</td>
#       <td id="T_6329e_row2_col1" class="data row2 col1" >0.048000</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
# ------
# [AutoCarver] Fit Pclass (3/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_1e8b6_row0_col0, #T_1e8b6_row2_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1e8b6_row0_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_1e8b6_row1_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_1e8b6_row1_col1, #T_1e8b6_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1e8b6" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e8b6_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_1e8b6_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e8b6_level0_row0" class="row_heading level0 row0" >1, 1</th>
#       <td id="T_1e8b6_row0_col0" class="data row0 col0" >0.620000</td>
#       <td id="T_1e8b6_row0_col1" class="data row0 col1" >0.239000</td>
#     </tr>
#     <tr>
#       <th id="T_1e8b6_level0_row1" class="row_heading level0 row1" >2, 2</th>
#       <td id="T_1e8b6_row1_col0" class="data row1 col0" >0.468000</td>
#       <td id="T_1e8b6_row1_col1" class="data row1 col1" >0.212000</td>
#     </tr>
#     <tr>
#       <th id="T_1e8b6_level0_row2" class="row_heading level0 row2" >3, 3</th>
#       <td id="T_1e8b6_row2_col0" class="data row2 col0" >0.252000</td>
#       <td id="T_1e8b6_row2_col1" class="data row2 col1" >0.549000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_c35f3_row0_col0, #T_c35f3_row2_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c35f3_row0_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_c35f3_row1_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_c35f3_row1_col1, #T_c35f3_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c35f3" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c35f3_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_c35f3_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c35f3_level0_row0" class="row_heading level0 row0" >1, 1</th>
#       <td id="T_c35f3_row0_col0" class="data row0 col0" >0.649000</td>
#       <td id="T_c35f3_row0_col1" class="data row0 col1" >0.253000</td>
#     </tr>
#     <tr>
#       <th id="T_c35f3_level0_row1" class="row_heading level0 row1" >2, 2</th>
#       <td id="T_c35f3_row1_col0" class="data row1 col0" >0.483000</td>
#       <td id="T_c35f3_row1_col1" class="data row1 col1" >0.198000</td>
#     </tr>
#     <tr>
#       <th id="T_c35f3_level0_row2" class="row_heading level0 row2" >3, 3</th>
#       <td id="T_c35f3_row2_col0" class="data row2 col0" >0.230000</td>
#       <td id="T_c35f3_row2_col1" class="data row2 col1" >0.549000</td>
#     </tr>
#   </tbody>
# </table>
# Grouping modalities   : 100%|██████████| 3/3 [00:00<00:00, 2976.09it/s]
# Computing associations: 100%|██████████| 3/3 [00:00<00:00, 3007.39it/s]
# Testing robustness    :   0%|          | 0/3 [00:00<?, ?it/s]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_0e013_row0_col0, #T_0e013_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0e013_row0_col1, #T_0e013_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0e013" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e013_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_0e013_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e013_level0_row0" class="row_heading level0 row0" >1 to 2</th>
#       <td id="T_0e013_row0_col0" class="data row0 col0" >0.549000</td>
#       <td id="T_0e013_row0_col1" class="data row0 col1" >0.451000</td>
#     </tr>
#     <tr>
#       <th id="T_0e013_level0_row1" class="row_heading level0 row1" >3, 3</th>
#       <td id="T_0e013_row1_col0" class="data row1 col0" >0.252000</td>
#       <td id="T_0e013_row1_col1" class="data row1 col1" >0.549000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_0c4e1_row0_col0, #T_0c4e1_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0c4e1_row0_col1, #T_0c4e1_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0c4e1" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c4e1_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_0c4e1_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c4e1_level0_row0" class="row_heading level0 row0" >1 to 2</th>
#       <td id="T_0c4e1_row0_col0" class="data row0 col0" >0.576000</td>
#       <td id="T_0c4e1_row0_col1" class="data row0 col1" >0.451000</td>
#     </tr>
#     <tr>
#       <th id="T_0c4e1_level0_row1" class="row_heading level0 row1" >3, 3</th>
#       <td id="T_0c4e1_row1_col0" class="data row1 col0" >0.230000</td>
#       <td id="T_0c4e1_row1_col1" class="data row1 col1" >0.549000</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
# ------
# [AutoCarver] Fit Sex (4/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_7655a_row0_col0, #T_7655a_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7655a_row0_col1, #T_7655a_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7655a" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7655a_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_7655a_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7655a_level0_row0" class="row_heading level0 row0" >male</th>
#       <td id="T_7655a_row0_col0" class="data row0 col0" >0.188000</td>
#       <td id="T_7655a_row0_col1" class="data row0 col1" >0.636000</td>
#     </tr>
#     <tr>
#       <th id="T_7655a_level0_row1" class="row_heading level0 row1" >female</th>
#       <td id="T_7655a_row1_col0" class="data row1 col0" >0.731000</td>
#       <td id="T_7655a_row1_col1" class="data row1 col1" >0.364000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_c3f95_row0_col0, #T_c3f95_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c3f95_row0_col1, #T_c3f95_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c3f95" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3f95_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_c3f95_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3f95_level0_row0" class="row_heading level0 row0" >male</th>
#       <td id="T_c3f95_row0_col0" class="data row0 col0" >0.195000</td>
#       <td id="T_c3f95_row0_col1" class="data row0 col1" >0.666000</td>
#     </tr>
#     <tr>
#       <th id="T_c3f95_level0_row1" class="row_heading level0 row1" >female</th>
#       <td id="T_c3f95_row1_col0" class="data row1 col0" >0.765000</td>
#       <td id="T_c3f95_row1_col1" class="data row1 col1" >0.334000</td>
#     </tr>
#   </tbody>
# </table>
# Grouping modalities   : 100%|██████████| 1/1 [00:00<00:00, 1003.18it/s]
# Computing associations: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Testing robustness    :   0%|          | 0/1 [00:00<?, ?it/s]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_389de_row0_col0, #T_389de_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_389de_row0_col1, #T_389de_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_389de" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_389de_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_389de_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_389de_level0_row0" class="row_heading level0 row0" >male</th>
#       <td id="T_389de_row0_col0" class="data row0 col0" >0.188000</td>
#       <td id="T_389de_row0_col1" class="data row0 col1" >0.636000</td>
#     </tr>
#     <tr>
#       <th id="T_389de_level0_row1" class="row_heading level0 row1" >female</th>
#       <td id="T_389de_row1_col0" class="data row1 col0" >0.731000</td>
#       <td id="T_389de_row1_col1" class="data row1 col1" >0.364000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_55857_row0_col0, #T_55857_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_55857_row0_col1, #T_55857_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_55857" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55857_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_55857_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55857_level0_row0" class="row_heading level0 row0" >male</th>
#       <td id="T_55857_row0_col0" class="data row0 col0" >0.195000</td>
#       <td id="T_55857_row0_col1" class="data row0 col1" >0.666000</td>
#     </tr>
#     <tr>
#       <th id="T_55857_level0_row1" class="row_heading level0 row1" >female</th>
#       <td id="T_55857_row1_col0" class="data row1 col0" >0.765000</td>
#       <td id="T_55857_row1_col1" class="data row1 col1" >0.334000</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
# ------
# [AutoCarver] Fit Fare (5/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_50363_row0_col0, #T_50363_row9_col1, #T_50363_row16_col1, #T_50363_row20_col1, #T_50363_row21_col1, #T_50363_row26_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_50363_row0_col1, #T_50363_row1_col1, #T_50363_row2_col1, #T_50363_row10_col1, #T_50363_row25_col1, #T_50363_row28_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_50363_row1_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_50363_row2_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_50363_row3_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_50363_row3_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_50363_row4_col0, #T_50363_row5_col1, #T_50363_row13_col1, #T_50363_row17_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_50363_row4_col1, #T_50363_row27_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_50363_row5_col0, #T_50363_row14_col0, #T_50363_row22_col1, #T_50363_row24_col1, #T_50363_row27_col1, #T_50363_row29_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_50363_row6_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_50363_row6_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_50363_row7_col0, #T_50363_row21_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_50363_row7_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_50363_row8_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_50363_row8_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_50363_row9_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_50363_row10_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_50363_row11_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_50363_row11_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_50363_row12_col0 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_50363_row12_col1, #T_50363_row14_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_50363_row13_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_50363_row15_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_50363_row15_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_50363_row16_col0, #T_50363_row26_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_50363_row17_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_50363_row18_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_50363_row18_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_50363_row19_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_50363_row19_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_50363_row20_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_50363_row22_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_50363_row23_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_50363_row23_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_50363_row24_col0 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_50363_row25_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_50363_row28_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_50363_row29_col0 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_50363" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50363_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_50363_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50363_level0_row0" class="row_heading level0 row0" >x <= 6.496e+00</th>
#       <td id="T_50363_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_50363_row0_col1" class="data row0 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row1" class="row_heading level0 row1" >6.496e+00 < x <= 7.054e+00</th>
#       <td id="T_50363_row1_col0" class="data row1 col0" >0.077000</td>
#       <td id="T_50363_row1_col1" class="data row1 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row2" class="row_heading level0 row2" >7.054e+00 < x <= 7.225e+00</th>
#       <td id="T_50363_row2_col0" class="data row2 col0" >0.231000</td>
#       <td id="T_50363_row2_col1" class="data row2 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row3" class="row_heading level0 row3" >7.225e+00 < x <= 7.250e+00</th>
#       <td id="T_50363_row3_col0" class="data row3 col0" >0.182000</td>
#       <td id="T_50363_row3_col1" class="data row3 col1" >0.037000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row4" class="row_heading level0 row4" >7.250e+00 < x <= 7.750e+00</th>
#       <td id="T_50363_row4_col0" class="data row4 col0" >0.350000</td>
#       <td id="T_50363_row4_col1" class="data row4 col1" >0.067000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row5" class="row_heading level0 row5" >7.750e+00 < x <= 7.854e+00</th>
#       <td id="T_50363_row5_col0" class="data row5 col0" >0.333000</td>
#       <td id="T_50363_row5_col1" class="data row5 col1" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row6" class="row_heading level0 row6" >7.854e+00 < x <= 7.896e+00</th>
#       <td id="T_50363_row6_col0" class="data row6 col0" >0.143000</td>
#       <td id="T_50363_row6_col1" class="data row6 col1" >0.047000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row7" class="row_heading level0 row7" >7.896e+00 < x <= 8.029e+00</th>
#       <td id="T_50363_row7_col0" class="data row7 col0" >0.500000</td>
#       <td id="T_50363_row7_col1" class="data row7 col1" >0.027000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row8" class="row_heading level0 row8" >8.029e+00 < x <= 8.050e+00</th>
#       <td id="T_50363_row8_col0" class="data row8 col0" >0.097000</td>
#       <td id="T_50363_row8_col1" class="data row8 col1" >0.052000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row9" class="row_heading level0 row9" >8.050e+00 < x <= 8.662e+00</th>
#       <td id="T_50363_row9_col0" class="data row9 col0" >0.083000</td>
#       <td id="T_50363_row9_col1" class="data row9 col1" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row10" class="row_heading level0 row10" >8.662e+00 < x <= 9.500e+00</th>
#       <td id="T_50363_row10_col0" class="data row10 col0" >0.308000</td>
#       <td id="T_50363_row10_col1" class="data row10 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row11" class="row_heading level0 row11" >9.500e+00 < x <= 1.050e+01</th>
#       <td id="T_50363_row11_col0" class="data row11 col0" >0.368000</td>
#       <td id="T_50363_row11_col1" class="data row11 col1" >0.032000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row12" class="row_heading level0 row12" >1.050e+01 < x <= 1.288e+01</th>
#       <td id="T_50363_row12_col0" class="data row12 col0" >0.600000</td>
#       <td id="T_50363_row12_col1" class="data row12 col1" >0.025000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row13" class="row_heading level0 row13" >1.288e+01 < x <= 1.300e+01</th>
#       <td id="T_50363_row13_col0" class="data row13 col0" >0.458000</td>
#       <td id="T_50363_row13_col1" class="data row13 col1" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row14" class="row_heading level0 row14" >1.300e+01 < x <= 1.445e+01</th>
#       <td id="T_50363_row14_col0" class="data row14 col0" >0.333000</td>
#       <td id="T_50363_row14_col1" class="data row14 col1" >0.025000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row15" class="row_heading level0 row15" >1.445e+01 < x <= 1.600e+01</th>
#       <td id="T_50363_row15_col0" class="data row15 col0" >0.381000</td>
#       <td id="T_50363_row15_col1" class="data row15 col1" >0.035000</td>
#     </tr>
#     <tr>
#       <th id="T_50363_level0_row16" class="row_heading level0 row16" >1.600e+01 < x <= 1.875e+01</th>
#       <td id="T_50363_row16_col0" class="data row16 col0" >0.417000</td>
#       <td id="T_50363_row16_col1" class="data row16 col1" >0.020000</td>
#     </tr>
#     <tr>
#       <th
# Grouping modalities   : 100%|██████████| 27840/27840 [00:04<00:00, 6843.63it/s]
# Computing associations: 100%|██████████| 27840/27840 [00:06<00:00, 4015.39it/s]
# Testing robustness    :   0%|          | 0/27840 [00:04<?, ?it/s]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_a3012_row0_col0, #T_a3012_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a3012_row0_col1 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_a3012_row1_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_a3012_row1_col1, #T_a3012_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a3012" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3012_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_a3012_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3012_level0_row0" class="row_heading level0 row0" >x <= 9.500e+00</th>
#       <td id="T_a3012_row0_col0" class="data row0 col0" >0.222000</td>
#       <td id="T_a3012_row0_col1" class="data row0 col1" >0.379000</td>
#     </tr>
#     <tr>
#       <th id="T_a3012_level0_row1" class="row_heading level0 row1" >9.500e+00 < x <= 7.729e+01</th>
#       <td id="T_a3012_row1_col0" class="data row1 col0" >0.426000</td>
#       <td id="T_a3012_row1_col1" class="data row1 col1" >0.522000</td>
#     </tr>
#     <tr>
#       <th id="T_a3012_level0_row2" class="row_heading level0 row2" >7.729e+01 < x</th>
#       <td id="T_a3012_row2_col0" class="data row2 col0" >0.797000</td>
#       <td id="T_a3012_row2_col1" class="data row2 col1" >0.099000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_5ed9b_row0_col0, #T_5ed9b_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5ed9b_row0_col1 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_5ed9b_row1_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_5ed9b_row1_col1, #T_5ed9b_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5ed9b" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ed9b_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_5ed9b_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ed9b_level0_row0" class="row_heading level0 row0" >x <= 9.500e+00</th>
#       <td id="T_5ed9b_row0_col0" class="data row0 col0" >0.149000</td>
#       <td id="T_5ed9b_row0_col1" class="data row0 col1" >0.345000</td>
#     </tr>
#     <tr>
#       <th id="T_5ed9b_level0_row1" class="row_heading level0 row1" >9.500e+00 < x <= 7.729e+01</th>
#       <td id="T_5ed9b_row1_col0" class="data row1 col0" >0.472000</td>
#       <td id="T_5ed9b_row1_col1" class="data row1 col1" >0.549000</td>
#     </tr>
#     <tr>
#       <th id="T_5ed9b_level0_row2" class="row_heading level0 row2" >7.729e+01 < x</th>
#       <td id="T_5ed9b_row2_col0" class="data row2 col0" >0.710000</td>
#       <td id="T_5ed9b_row2_col1" class="data row2 col1" >0.106000</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
# ------
# [AutoCarver] Fit Parents/Children Aboard (6/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_9c870_row0_col0, #T_9c870_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9c870_row0_col1, #T_9c870_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9c870_row1_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9c870_row2_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9c870" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c870_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_9c870_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c870_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_9c870_row0_col0" class="data row0 col0" >0.345000</td>
#       <td id="T_9c870_row0_col1" class="data row0 col1" >0.737000</td>
#     </tr>
#     <tr>
#       <th id="T_9c870_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 1.000e+00</th>
#       <td id="T_9c870_row1_col0" class="data row1 col0" >0.506000</td>
#       <td id="T_9c870_row1_col1" class="data row1 col1" >0.146000</td>
#     </tr>
#     <tr>
#       <th id="T_9c870_level0_row2" class="row_heading level0 row2" >1.000e+00 < x</th>
#       <td id="T_9c870_row2_col0" class="data row2 col0" >0.493000</td>
#       <td id="T_9c870_row2_col1" class="data row2 col1" >0.116000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_34385_row0_col0, #T_34385_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_34385_row0_col1, #T_34385_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_34385_row1_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_34385_row2_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_34385" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34385_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_34385_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34385_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_34385_row0_col0" class="data row0 col0" >0.347000</td>
#       <td id="T_34385_row0_col1" class="data row0 col1" >0.805000</td>
#     </tr>
#     <tr>
#       <th id="T_34385_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 1.000e+00</th>
#       <td id="T_34385_row1_col0" class="data row1 col0" >0.677000</td>
#       <td id="T_34385_row1_col1" class="data row1 col1" >0.106000</td>
#     </tr>
#     <tr>
#       <th id="T_34385_level0_row2" class="row_heading level0 row2" >1.000e+00 < x</th>
#       <td id="T_34385_row2_col0" class="data row2 col0" >0.385000</td>
#       <td id="T_34385_row2_col1" class="data row2 col1" >0.089000</td>
#     </tr>
#   </tbody>
# </table>
# Grouping modalities   : 100%|██████████| 3/3 [00:00<?, ?it/s]
# Computing associations: 100%|██████████| 3/3 [00:00<00:00, 1497.61it/s]
# Testing robustness    :   0%|          | 0/3 [00:00<?, ?it/s]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_e8748_row0_col0, #T_e8748_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e8748_row0_col1, #T_e8748_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e8748" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8748_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_e8748_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8748_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_e8748_row0_col0" class="data row0 col0" >0.345000</td>
#       <td id="T_e8748_row0_col1" class="data row0 col1" >0.737000</td>
#     </tr>
#     <tr>
#       <th id="T_e8748_level0_row1" class="row_heading level0 row1" >0.000e+00 < x</th>
#       <td id="T_e8748_row1_col0" class="data row1 col0" >0.500000</td>
#       <td id="T_e8748_row1_col1" class="data row1 col1" >0.263000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_1f672_row0_col0, #T_1f672_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1f672_row0_col1, #T_1f672_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1f672" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f672_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_1f672_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f672_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_1f672_row0_col0" class="data row0 col0" >0.347000</td>
#       <td id="T_1f672_row0_col1" class="data row0 col1" >0.805000</td>
#     </tr>
#     <tr>
#       <th id="T_1f672_level0_row1" class="row_heading level0 row1" >0.000e+00 < x</th>
#       <td id="T_1f672_row1_col0" class="data row1 col0" >0.544000</td>
#       <td id="T_1f672_row1_col1" class="data row1 col1" >0.195000</td>
#     </tr>
#   </tbody>
# </table>
# ------

# %% [markdown]
# ## AutoCarver analysis
#
# ### Carving Summary

# %%
auto_carver.summary()
# Out:
#                                label                       content
# feature                 dtype
# Age                     float      0              [x <= 7.000e+00]
#                         float      1               [7.000e+00 < x]
# Fare                    float      0              [x <= 9.500e+00]
#                         float      1  [9.500e+00 < x <= 7.729e+01]
#                         float      2               [7.729e+01 < x]
# Parents/Children Aboard float      0              [x <= 0.000e+00]
#                         float      1               [0.000e+00 < x]
# Siblings/Spouses Aboard float      0              [x <= 0.000e+00]
#                         float      1  [0.000e+00 < x <= 2.000e+00]
#                         float      2               [2.000e+00 < x]
# Pclass                  str        0                        [1, 2]
#                         str        1                           [3]
# Sex                     str        0                        [male]
#                         str        1                      [female]

# %% [markdown]
# * As requested with ``output_dtype="float"``, output labels are integers of ranks of modalities
#
# * For quantitative feature ``Age``, the selected combination of modalities groups ages as follows:
#     * modality ``0``: lower or equal to 7 years old (``content==["x <= 7.000e+00"]``)
#     * modality ``1``: ages higher than 7 years old (``content==["7.000e+00 < x "]``)
#
# * For qualitative categorical feature ``Sex``, the selected combination of modalities has left modalities ``content=["male"]`` in modality ``0`` and ``content=["female"]`` in modality ``1`` (no combination possible)
#
# * For qualitative ordinal feature ``Pclass``, the selected combination of modalities groups classes 1 and 2 in modality ``0`` (``content==[1, 2]``) and class 3 in modality ``1`` (``content==[3]``). The user-provided ordering of modalities has been preserved.

# %% [markdown]
# ### Detailed overview of tested combinations

# %%
auto_carver.history(feature="Pclass")
# Out:
#                 combination  tschuprowt viability  \
# 0  [[1, 1], [2, 2], [3, 3]]    0.269965      None
# 1    [[1, 1, 2, 2], [3, 3]]    0.300144      True
# 2  [[1, 1], [2, 2], [3, 3]]    0.269965      None
# 3    [[1, 1], [2, 2, 3, 3]]    0.265643      None
#
#                           viability_message  grouping_nan
# 0                      [Raw X distribution]         False
# 1  [Combination robust between X and X_dev]         False
# 2                             [Not checked]         False
# 3                             [Not checked]         False

# %% [markdown]
# * The most associated combination (the first tested out, where ``viability_message!=["Raw X distribution"]``) groups ``Pclass==1`` with ``Pclass==2`` and leaves ``Pclass==3`` as its own modality
#
# * Tschuprow's T for this combination is ``0.300144`` (greater than the raw distribution, with ``0.269965``)
#
# * This combination has been tested as viable: ``viability_message==["Combination robust between X and X_dev"]``
#
# * Following combinations (less associated with the target) where not tested: ``viability_message==["Not checked"]``
#
# * For all combinations ``grouping_nan==False`` means that it is not a combination in which NaNs are being groupedwith other modalities (as requested with ``dropna=False``)

# %% [markdown]
# ## Saving and Loading AutoCarver

# %% [markdown]
# ### Saving
#
# All **Carvers** can safely be stored as a .json file.

# %%
import json

# storing as json file
with open('binay_carver.json', 'w') as my_carver_json:
    json.dump(auto_carver.to_json(), my_carver_json)

# %% [markdown]
# ### Loading
#
# **Carvers** can safely be loaded from a .json file.

# %%
import json

from AutoCarver import load_carver

# loading json file
with open('binay_carver.json', 'r') as my_carver_json:
    auto_carver = load_carver(json.load(my_carver_json))

# %% [markdown]
# ## Applying AutoCarver

# %%
dev_set_processed = auto_carver.transform(dev_set)

# %%
dev_set_processed[auto_carver.features].apply(lambda u: u.value_counts(dropna=False, normalize=True))
# Out:
#          Age  Siblings/Spouses Aboard    Pclass       Sex      Fare  \
# 0.0  0.05802                 0.682594  0.450512  0.665529  0.344710
# 1.0  0.94198                 0.269625  0.549488  0.334471  0.549488
# 2.0      NaN                 0.047782       NaN       NaN  0.105802
#
#      Parents/Children Aboard
# 0.0                 0.805461
# 1.0                 0.194539
# 2.0                      NaN

# %% [markdown]
# # Feature Selection
# ## Selectors settings

# %% [markdown]
# ### Features to select from
#
# Here all features have been carved using ``BinaryCarver``, hence all features are qualitative.

# %%
features = qualitative_features + quantitative_features + ordinal_features

# %% [markdown]
# ### Number of features to select
#
# The attribute ``n_best`` allows one to choose the number of features to be selected per data type (quantitative and qualitative).

# %%
n_best = 6  # here the number of features is low, ClassificationSelector will only be used to compute useful statistics

# %% [markdown]
# ## Using Selectors

# %%
from AutoCarver.selectors import ClassificationSelector

# select the most target associated qualitative features
feature_selector = ClassificationSelector(
    qualitative_features=features,
    n_best=n_best,
    verbose=True,  # displays statistics
)
best_features = feature_selector.select(train_set_processed, train_set_processed[target])
# Out:
# ------
# [Selector] Selecting from qualitative features: ['Age', 'Siblings/Spouses Aboard', 'Pclass', 'Sex', 'Fare', 'Parents/Children Aboard']
# ---
#
#  - [Selector] Association between X and y
# <style type="text/css">
# #T_8675c_row0_col1, #T_8675c_row1_col1, #T_8675c_row2_col1, #T_8675c_row2_col2, #T_8675c_row3_col1, #T_8675c_row4_col1, #T_8675c_row5_col1, #T_8675c_row5_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8675c_row0_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_8675c_row0_col5, #T_8675c_row4_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8675c_row1_col2, #T_8675c_row3_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_8675c_row1_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_8675c_row2_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_8675c_row3_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_8675c_row4_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_8675c_row5_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# </style>
# <table id="T_8675c" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8675c_level0_col0" class="col_heading level0 col0" >dtype</th>
#       <th id="T_8675c_level0_col1" class="col_heading level0 col1" >pct_nan</th>
#       <th id="T_8675c_level0_col2" class="col_heading level0 col2" >pct_mode</th>
#       <th id="T_8675c_level0_col3" class="col_heading level0 col3" >mode</th>
#       <th id="T_8675c_level0_col4" class="col_heading level0 col4" >chi2_statistic</th>
#       <th id="T_8675c_level0_col5" class="col_heading level0 col5" >tschuprowt_measure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8675c_level0_row0" class="row_heading level0 row0" >Sex</th>
#       <td id="T_8675c_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_8675c_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_8675c_row0_col2" class="data row0 col2" >0.636364</td>
#       <td id="T_8675c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8675c_row0_col4" class="data row0 col4" >169.204709</td>
#       <td id="T_8675c_row0_col5" class="data row0 col5" >0.533719</td>
#     </tr>
#     <tr>
#       <th id="T_8675c_level0_row1" class="row_heading level0 row1" >Pclass</th>
#       <td id="T_8675c_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_8675c_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_8675c_row1_col2" class="data row1 col2" >0.548822</td>
#       <td id="T_8675c_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_8675c_row1_col4" class="data row1 col4" >53.511433</td>
#       <td id="T_8675c_row1_col5" class="data row1 col5" >0.300144</td>
#     </tr>
#     <tr>
#       <th id="T_8675c_level0_row2" class="row_heading level0 row2" >Fare</th>
#       <td id="T_8675c_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_8675c_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_8675c_row2_col2" class="data row2 col2" >0.521886</td>
#       <td id="T_8675c_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_8675c_row2_col4" class="data row2 col4" >69.540284</td>
#       <td id="T_8675c_row2_col5" class="data row2 col5" >0.287718</td>
#     </tr>
#     <tr>
#       <th id="T_8675c_level0_row3" class="row_heading level0 row3" >Siblings/Spouses Aboard</th>
#       <td id="T_8675c_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_8675c_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_8675c_row3_col2" class="data row3 col2" >0.680135</td>
#       <td id="T_8675c_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_8675c_row3_col4" class="data row3 col4" >22.226931</td>
#       <td id="T_8675c_row3_col5" class="data row3 col5" >0.162663</td>
#     </tr>
#     <tr>
#       <th id="T_8675c_level0_row4" class="row_heading level0 row4" >Age</th>
#       <td id="T_8675c_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_8675c_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_8675c_row4_col2" class="data row4 col2" >0.932660</td>
#       <td id="T_8675c_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_8675c_row4_col4" class="data row4 col4" >13.889037</td>
#       <td id="T_8675c_row4_col5" class="data row4 col5" >0.152912</td>
#     </tr>
#     <tr>
#       <th id="T_8675c_level0_row5" class="row_heading level0 row5" >Parents/Children Aboard</th>
#       <td id="T_8675c_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_8675c_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_8675c_row5_col2" class="data row5 col2" >0.737374</td>
#       <td id="T_8675c_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_8675c_row5_col4" class="data row5 col4" >11.057602</td>
#       <td id="T_8675c_row5_col5" class="data row5 col5" >0.136439</td>
#     </tr>
#   </tbody>
# </table>
#  - [Selector] Association between X and y, filtered for inter-feature assocation
# <style type="text/css">
# #T_2a4d4_row0_col1, #T_2a4d4_row1_col1, #T_2a4d4_row2_col1, #T_2a4d4_row2_col2, #T_2a4d4_row3_col1, #T_2a4d4_row4_col1, #T_2a4d4_row5_col1, #T_2a4d4_row5_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2a4d4_row0_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_2a4d4_row0_col5, #T_2a4d4_row4_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2a4d4_row1_col2, #T_2a4d4_row3_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_2a4d4_row1_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_2a4d4_row2_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_2a4d4_row3_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_2a4d4_row4_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_2a4d4_row5_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# </style>
# <table id="T_2a4d4" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a4d4_level0_col0" class="col_heading level0 col0" >dtype</th>
#       <th id="T_2a4d4_level0_col1" class="col_heading level0 col1" >pct_nan</th>
#       <th id="T_2a4d4_level0_col2" class="col_heading level0 col2" >pct_mode</th>
#       <th id="T_2a4d4_level0_col3" class="col_heading level0 col3" >mode</th>
#       <th id="T_2a4d4_level0_col4" class="col_heading level0 col4" >chi2_statistic</th>
#       <th id="T_2a4d4_level0_col5" class="col_heading level0 col5" >tschuprowt_measure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a4d4_level0_row0" class="row_heading level0 row0" >Sex</th>
#       <td id="T_2a4d4_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_2a4d4_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_2a4d4_row0_col2" class="data row0 col2" >0.636364</td>
#       <td id="T_2a4d4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2a4d4_row0_col4" class="data row0 col4" >169.204709</td>
#       <td id="T_2a4d4_row0_col5" class="data row0 col5" >0.533719</td>
#     </tr>
#     <tr>
#       <th id="T_2a4d4_level0_row1" class="row_heading level0 row1" >Pclass</th>
#       <td id="T_2a4d4_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_2a4d4_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_2a4d4_row1_col2" class="data row1 col2" >0.548822</td>
#       <td id="T_2a4d4_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_2a4d4_row1_col4" class="data row1 col4" >53.511433</td>
#       <td id="T_2a4d4_row1_col5" class="data row1 col5" >0.300144</td>
#     </tr>
#     <tr>
#       <th id="T_2a4d4_level0_row2" class="row_heading level0 row2" >Fare</th>
#       <td id="T_2a4d4_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_2a4d4_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_2a4d4_row2_col2" class="data row2 col2" >0.521886</td>
#       <td id="T_2a4d4_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_2a4d4_row2_col4" class="data row2 col4" >69.540284</td>
#       <td id="T_2a4d4_row2_col5" class="data row2 col5" >0.287718</td>
#     </tr>
#     <tr>
#       <th id="T_2a4d4_level0_row3" class="row_heading level0 row3" >Siblings/Spouses Aboard</th>
#       <td id="T_2a4d4_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_2a4d4_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_2a4d4_row3_col2" class="data row3 col2" >0.680135</td>
#       <td id="T_2a4d4_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_2a4d4_row3_col4" class="data row3 col4" >22.226931</td>
#       <td id="T_2a4d4_row3_col5" class="data row3 col5" >0.162663</td>
#     </tr>
#     <tr>
#       <th id="T_2a4d4_level0_row4" class="row_heading level0 row4" >Age</th>
#       <td id="T_2a4d4_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_2a4d4_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_2a4d4_row4_col2" class="data row4 col2" >0.932660</td>
#       <td id="T_2a4d4_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_2a4d4_row4_col4" class="data row4 col4" >13.889037</td>
#       <td id="T_2a4d4_row4_col5" class="data row4 col5" >0.152912</td>
#     </tr>
#     <tr>
#       <th id="T_2a4d4_level0_row5" class="row_heading level0 row5" >Parents/Children Aboard</th>
#       <td id="T_2a4d4_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_2a4d4_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_2a4d4_row5_col2" class="data row5 col2" >0.737374</td>
#       <td id="T_2a4d4_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_2a4d4_row5_col4" class="data row5 col4" >11.057602</td>
#       <td id="T_2a4d4_row5_col5" class="data row5 col5" >0.136439</td>
#     </tr>
#   </tbody>
# </table>
#  - [Selector] Selected qualitative features: ['Sex', 'Pclass', 'Fare', 'Siblings/Spouses Aboard', 'Age', 'Parents/Children Aboard']
# ------

# %% [markdown]
# * Feature ``Sex`` is the most associated with the target ``Survived``. Tschuprow's T value is ``tschuprowt_measure=0.533719``
#
# * This feature has 0 % of NaNs (``pct_nan=0.0``) and its mode, ``0`` represents 64 % of observed data (``pct_nan=0.636364``)
#
# * Here, no feature where filtered out for there inter-feature association or over-represented values (no thresholds were set)
