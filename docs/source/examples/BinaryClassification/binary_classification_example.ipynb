# %% [markdown]
# # Setting things up

# %% [markdown]
# ## Installation

# %%
# !pip install AutoCarver[jupyter]
# Out:
# Requirement already satisfied: AutoCarver[jupyter] in c:\users\defra\.conda\envs\py39\lib\site-packages (5.4.2)
# Requirement already satisfied: statsmodels in c:\users\defra\.conda\envs\py39\lib\site-packages (from AutoCarver[jupyter]) (0.14.0)
# Requirement already satisfied: scikit-learn in c:\users\defra\.conda\envs\py39\lib\site-packages (from AutoCarver[jupyter]) (1.2.2)
# Requirement already satisfied: pandas in c:\users\defra\.conda\envs\py39\lib\site-packages (from AutoCarver[jupyter]) (1.5.3)
# Requirement already satisfied: tqdm in c:\users\defra\.conda\envs\py39\lib\site-packages (from AutoCarver[jupyter]) (4.65.0)
# Requirement already satisfied: numpy in c:\users\defra\.conda\envs\py39\lib\site-packages (from AutoCarver[jupyter]) (1.24.2)
# Requirement already satisfied: scipy in c:\users\defra\.conda\envs\py39\lib\site-packages (from AutoCarver[jupyter]) (1.10.1)
# Requirement already satisfied: ipython in c:\users\defra\.conda\envs\py39\lib\site-packages (from AutoCarver[jupyter]) (8.11.0)
# Requirement already satisfied: matplotlib-inline in c:\users\defra\.conda\envs\py39\lib\site-packages (from ipython->AutoCarver[jupyter]) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\defra\.conda\envs\py39\lib\site-packages (from ipython->AutoCarver[jupyter]) (2.14.0)
# Requirement already satisfied: stack-data in c:\users\defra\.conda\envs\py39\lib\site-packages (from ipython->AutoCarver[jupyter]) (0.6.2)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\defra\.conda\envs\py39\lib\site-packages (from ipython->AutoCarver[jupyter]) (3.0.38)
# Requirement already satisfied: colorama in c:\users\defra\.conda\envs\py39\lib\site-packages (from ipython->AutoCarver[jupyter]) (0.4.6)
# Requirement already satisfied: traitlets>=5 in c:\users\defra\.conda\envs\py39\lib\site-packages (from ipython->AutoCarver[jupyter]) (5.9.0)
# Requirement already satisfied: backcall in c:\users\defra\.conda\envs\py39\lib\site-packages (from ipython->AutoCarver[jupyter]) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\defra\.conda\envs\py39\lib\site-packages (from ipython->AutoCarver[jupyter]) (0.18.2)
# Requirement already satisfied: decorator in c:\users\defra\.conda\envs\py39\lib\site-packages (from ipython->AutoCarver[jupyter]) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\defra\.conda\envs\py39\lib\site-packages (from ipython->AutoCarver[jupyter]) (0.7.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\defra\.conda\envs\py39\lib\site-packages (from pandas->AutoCarver[jupyter]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\defra\.conda\envs\py39\lib\site-packages (from pandas->AutoCarver[jupyter]) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\defra\.conda\envs\py39\lib\site-packages (from scikit-learn->AutoCarver[jupyter]) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\defra\.conda\envs\py39\lib\site-packages (from scikit-learn->AutoCarver[jupyter]) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\defra\.conda\envs\py39\lib\site-packages (from statsmodels->AutoCarver[jupyter]) (23.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\defra\.conda\envs\py39\lib\site-packages (from statsmodels->AutoCarver[jupyter]) (0.5.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\defra\.conda\envs\py39\lib\site-packages (from jedi>=0.16->ipython->AutoCarver[jupyter]) (0.8.3)
# Requirement already satisfied: six in c:\users\defra\.conda\envs\py39\lib\site-packages (from patsy>=0.5.2->statsmodels->AutoCarver[jupyter]) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\defra\.conda\envs\py39\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->AutoCarver[jupyter]) (0.2.6)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\defra\.conda\envs\py39\lib\site-packages (from stack-data->ipython->AutoCarver[jupyter]) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\defra\.conda\envs\py39\lib\site-packages (from stack-data->ipython->AutoCarver[jupyter]) (1.2.0)
# Requirement already satisfied: pure-eval in c:\users\defra\.conda\envs\py39\lib\site-packages (from stack-data->ipython->AutoCarver[jupyter]) (0.2.2)

# %% [markdown]
# ## Titanic Data
#
# In this example notebook, we will use the Titanic dataset.
#
# The Titanic dataset is a well-known and frequently used dataset in the field of machine learning and data science. It provides information about the passengers on board the Titanic, the famous ship that sank on its maiden voyage in 1912. The dataset is often used for predictive modeling, classification, and regression tasks.
#
# The dataset includes various features such as passengers' names, ages, genders, ticket classes, cabin information, and whether they survived or not. The primary goal when working with the Titanic dataset is often to build predictive models that can infer whether a passenger survived or perished based on their individual characteristics (binary classification).

# %%
import pandas as pd

# URL to the Titanic dataset on Kaggle
titanic_url = "https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"

# Use pandas to read the CSV file directly from the URL
titanic_data = pd.read_csv(titanic_url)

# Display the first few rows of the dataset
titanic_data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# ## Target type and Carver selection

# %%
target = "Survived"

titanic_data[target].value_counts(dropna=False)
# Out:
# 0    545
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# The target ``"Survived"`` is a binary target of type ``int64`` used for a classification task. Hence we will use ``AutoCarver.BinaryCarver`` and ``AutoCarver.selectors.ClassificationSelector`` in following code blocks.

# %% [markdown]
# ## Data Sampling

# %%
from sklearn.model_selection import train_test_split

# stratified sampling by target
train_set, dev_set = train_test_split(titanic_data, test_size=0.33, random_state=42, stratify=titanic_data[target])

# %%
# checking target rate per dataset
train_set[target].mean(), dev_set[target].mean()
# Out:
# (0.38552188552188554, 0.3856655290102389)

# %% [markdown]
# # Picking up columns to Carve

# %%
train_set.head()
# Out:
#      Survived  Pclass                          Name     Sex   Age  \
# 617         0       3            Mr. Antoni Yasbeck    male  27.0
# 489         0       1     Mr. Harry Markland Molson    male  55.0
# 871         1       3      Miss. Adele Kiamie Najib  female  15.0
# 654         0       3  Mrs. John (Catherine) Bourke  female  32.0
# 653         0       3          Mr. Alexander Radeff    male  27.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 617                        1                        0  14.4542
# 489                        0                        0  30.5000
# 871                        0                        0   7.2250
# 654                        1                        1  15.5000
# 653                        0                        0   7.8958

# %%
# column data types
train_set.dtypes
# Out:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object

# %%
# values taken by Parents/Children Aboard
train_set["Parents/Children Aboard"].value_counts()
# Out:
# 0    438
# 1     87
# 2     60
# 3      3
# 5      3
# 4      2
# 6      1
# Name: Parents/Children Aboard, dtype: int64

# %%
# values taken by Pclass
train_set["Pclass"].value_counts()
# Out:
# 3    326
# 1    142
# 2    126
# Name: Pclass, dtype: int64

# %% [markdown]
# The feature ``"Pclass"`` is of type ``"int64"``, but it can be considered a qualitative ordinal feature rather than a quantitative discrete feature (ranking of named passenger classes). Thus we will add it to the list of ``ordinal_features`` and set the ordering of its values in ``values_orders`` (string values).
#
# ``"Sex"`` is the only quantitative categorical feature, it's added to the list of ``qualitative_features``.
#
# ``"Age"`` and ``"Fare"`` are quantitative continuous features, whilst ``"Siblings/Spouses Aboard"``, ``"Parents/Children Aboard"`` can be considered as quantitative discrete features. Thoses four features will be added to the list of ``quantitative_features``.

# %%
quantitative_features = ["Age", "Fare", "Siblings/Spouses Aboard", "Parents/Children Aboard"]
qualitative_features = ["Sex"]
ordinal_features = ["Pclass"]

values_orders = {
    "Pclass": ["1", "2", "3"]
}

# %% [markdown]
# # Using AutoCarver

# %% [markdown]
# ## AutoCarver settings
#
# ### Representativness of modalities
#
# The attribute ``min_freq`` allows one to choose the minimum frequency per basic modalities. It is used by **Discretizers**:
#
# - For quantitative features, it defines the number of quantiles to initialy discretize the features with.
#
# - For qualitative features, it defines the threshold under which a modality is grouped to either a default value or its closest modality.

# %%
min_freq = 0.02

# %% [markdown]
# **Tip:** should be set between ``0.02`` (slower, preciser, less robust) and ``0.05`` (faster, more robust)

# %% [markdown]
# ### Desired number of modalities
#
# The attribute ``max_n_mod`` allows one to choose the maximum number of modalities per carved feature. It is used by **Carvers** has the upper limit of number of modalities per consecutive combination of modalities.

# %%
max_n_mod = 5

# %% [markdown]
# **Tip:** should be set between ``3`` (faster, more robust) and ``7`` (slower, preciser, less robust)

# %% [markdown]
# ### Association metric
#
# The attribute ``sort_by`` allows one to choose the association metric used to sort combinations. Combinations of grouped modalities are ranked according to the specified modalities and the best ranked viable combination is returned by **Carvers**.

# %%
# For BinaryCarver, to be choosen amongst ["tschuprowt", "cramerv"]
sort_by = "tschuprowt"  # "cramerv"

# %% [markdown]
# **Tip:** use ``"tschuprowt"`` for more robust, or less output modalities, use ``"cramerv"`` for more output modalities.

# %% [markdown]
# ## Fitting AutoCarver

# %%
from AutoCarver import BinaryCarver

# intiating AutoCarver
auto_carver = BinaryCarver(
    quantitative_features=quantitative_features,
    qualitative_features=qualitative_features,
    ordinal_features=ordinal_features,
    values_orders=values_orders,
    min_freq=min_freq,
    max_n_mod=max_n_mod,
    sort_by=sort_by,
    verbose=True,  # showing statistics
    copy=True,
)

# fitting on training sample, a dev sample can be specified to evaluate carving robustness
train_set_processed = auto_carver.fit_transform(train_set, train_set[target], X_dev=dev_set, y_dev=dev_set[target])
# Out:
# ------
# [Discretizer] Fit Qualitative Features
# ---
#  - [StringDiscretizer] Fit ['Pclass']
#  - [OrdinalDiscretizer] Fit ['Pclass']
#  - [CategoricalDiscretizer] Fit ['Sex']
# ------
#
# ------
# [Discretizer] Fit Quantitative Features
# ---
#  - [ContinuousDiscretizer] Fit ['Fare', 'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Age']
#  - [OrdinalDiscretizer] Fit ['Fare', 'Siblings/Spouses Aboard', 'Age', 'Parents/Children Aboard']
# c:\Users\defra\.conda\envs\py39\lib\site-packages\AutoCarver\discretizers\discretizers.py:328: UserWarning:  - [QualitativeDiscretizer] Non-string features: ['Pclass']. Trying to convert them using type_discretizers.StringDiscretizer, otherwise convert them manually. Unexpected data types: [<class 'int'>].
#   warn(
# ------
#
#
# ------
# [AutoCarver] Fit Fare (1/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_687be_row0_col0, #T_687be_row9_col1, #T_687be_row16_col1, #T_687be_row20_col1, #T_687be_row21_col1, #T_687be_row26_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_687be_row0_col1, #T_687be_row1_col1, #T_687be_row2_col1, #T_687be_row10_col1, #T_687be_row25_col1, #T_687be_row28_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_687be_row1_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_687be_row2_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_687be_row3_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_687be_row3_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_687be_row4_col0, #T_687be_row5_col1, #T_687be_row13_col1, #T_687be_row17_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_687be_row4_col1, #T_687be_row27_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_687be_row5_col0, #T_687be_row14_col0, #T_687be_row22_col1, #T_687be_row24_col1, #T_687be_row27_col1, #T_687be_row29_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_687be_row6_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_687be_row6_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_687be_row7_col0, #T_687be_row21_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_687be_row7_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_687be_row8_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_687be_row8_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_687be_row9_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_687be_row10_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_687be_row11_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_687be_row11_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_687be_row12_col0 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_687be_row12_col1, #T_687be_row14_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_687be_row13_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_687be_row15_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_687be_row15_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_687be_row16_col0, #T_687be_row26_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_687be_row17_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_687be_row18_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_687be_row18_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_687be_row19_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_687be_row19_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_687be_row20_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_687be_row22_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_687be_row23_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_687be_row23_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_687be_row24_col0 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_687be_row25_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_687be_row28_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_687be_row29_col0 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_687be" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_687be_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_687be_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_687be_level0_row0" class="row_heading level0 row0" >x <= 6.496e+00</th>
#       <td id="T_687be_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_687be_row0_col1" class="data row0 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row1" class="row_heading level0 row1" >6.496e+00 < x <= 7.054e+00</th>
#       <td id="T_687be_row1_col0" class="data row1 col0" >0.077000</td>
#       <td id="T_687be_row1_col1" class="data row1 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row2" class="row_heading level0 row2" >7.054e+00 < x <= 7.225e+00</th>
#       <td id="T_687be_row2_col0" class="data row2 col0" >0.231000</td>
#       <td id="T_687be_row2_col1" class="data row2 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row3" class="row_heading level0 row3" >7.225e+00 < x <= 7.250e+00</th>
#       <td id="T_687be_row3_col0" class="data row3 col0" >0.182000</td>
#       <td id="T_687be_row3_col1" class="data row3 col1" >0.037000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row4" class="row_heading level0 row4" >7.250e+00 < x <= 7.750e+00</th>
#       <td id="T_687be_row4_col0" class="data row4 col0" >0.350000</td>
#       <td id="T_687be_row4_col1" class="data row4 col1" >0.067000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row5" class="row_heading level0 row5" >7.750e+00 < x <= 7.854e+00</th>
#       <td id="T_687be_row5_col0" class="data row5 col0" >0.333000</td>
#       <td id="T_687be_row5_col1" class="data row5 col1" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row6" class="row_heading level0 row6" >7.854e+00 < x <= 7.896e+00</th>
#       <td id="T_687be_row6_col0" class="data row6 col0" >0.143000</td>
#       <td id="T_687be_row6_col1" class="data row6 col1" >0.047000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row7" class="row_heading level0 row7" >7.896e+00 < x <= 8.029e+00</th>
#       <td id="T_687be_row7_col0" class="data row7 col0" >0.500000</td>
#       <td id="T_687be_row7_col1" class="data row7 col1" >0.027000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row8" class="row_heading level0 row8" >8.029e+00 < x <= 8.050e+00</th>
#       <td id="T_687be_row8_col0" class="data row8 col0" >0.097000</td>
#       <td id="T_687be_row8_col1" class="data row8 col1" >0.052000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row9" class="row_heading level0 row9" >8.050e+00 < x <= 8.662e+00</th>
#       <td id="T_687be_row9_col0" class="data row9 col0" >0.083000</td>
#       <td id="T_687be_row9_col1" class="data row9 col1" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row10" class="row_heading level0 row10" >8.662e+00 < x <= 9.500e+00</th>
#       <td id="T_687be_row10_col0" class="data row10 col0" >0.308000</td>
#       <td id="T_687be_row10_col1" class="data row10 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row11" class="row_heading level0 row11" >9.500e+00 < x <= 1.050e+01</th>
#       <td id="T_687be_row11_col0" class="data row11 col0" >0.368000</td>
#       <td id="T_687be_row11_col1" class="data row11 col1" >0.032000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row12" class="row_heading level0 row12" >1.050e+01 < x <= 1.288e+01</th>
#       <td id="T_687be_row12_col0" class="data row12 col0" >0.600000</td>
#       <td id="T_687be_row12_col1" class="data row12 col1" >0.025000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row13" class="row_heading level0 row13" >1.288e+01 < x <= 1.300e+01</th>
#       <td id="T_687be_row13_col0" class="data row13 col0" >0.458000</td>
#       <td id="T_687be_row13_col1" class="data row13 col1" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row14" class="row_heading level0 row14" >1.300e+01 < x <= 1.445e+01</th>
#       <td id="T_687be_row14_col0" class="data row14 col0" >0.333000</td>
#       <td id="T_687be_row14_col1" class="data row14 col1" >0.025000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row15" class="row_heading level0 row15" >1.445e+01 < x <= 1.600e+01</th>
#       <td id="T_687be_row15_col0" class="data row15 col0" >0.381000</td>
#       <td id="T_687be_row15_col1" class="data row15 col1" >0.035000</td>
#     </tr>
#     <tr>
#       <th id="T_687be_level0_row16" class="row_heading level0 row16" >1.600e+01 < x <= 1.875e+01</th>
#       <td id="T_687be_row16_col0" class="data row16 col0" >0.417000</td>
#       <td id="T_687be_row16_col1" class="data row16 col1" >0.020000</td>
#     </tr>
#     <tr>
#       <th
# Grouping modalities   : 100%|██████████| 27840/27840 [00:04<00:00, 6414.49it/s]
# Computing associations: 100%|██████████| 27840/27840 [00:06<00:00, 4380.26it/s]
# Testing robustness    :   0%|          | 0/27840 [00:04<?, ?it/s]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_b94ee_row0_col0, #T_b94ee_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b94ee_row0_col1 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_b94ee_row1_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_b94ee_row1_col1, #T_b94ee_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b94ee" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b94ee_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_b94ee_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b94ee_level0_row0" class="row_heading level0 row0" >x <= 9.500e+00</th>
#       <td id="T_b94ee_row0_col0" class="data row0 col0" >0.222000</td>
#       <td id="T_b94ee_row0_col1" class="data row0 col1" >0.379000</td>
#     </tr>
#     <tr>
#       <th id="T_b94ee_level0_row1" class="row_heading level0 row1" >9.500e+00 < x <= 7.729e+01</th>
#       <td id="T_b94ee_row1_col0" class="data row1 col0" >0.426000</td>
#       <td id="T_b94ee_row1_col1" class="data row1 col1" >0.522000</td>
#     </tr>
#     <tr>
#       <th id="T_b94ee_level0_row2" class="row_heading level0 row2" >7.729e+01 < x</th>
#       <td id="T_b94ee_row2_col0" class="data row2 col0" >0.797000</td>
#       <td id="T_b94ee_row2_col1" class="data row2 col1" >0.099000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_974d6_row0_col0, #T_974d6_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_974d6_row0_col1 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_974d6_row1_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_974d6_row1_col1, #T_974d6_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_974d6" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_974d6_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_974d6_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_974d6_level0_row0" class="row_heading level0 row0" >x <= 9.500e+00</th>
#       <td id="T_974d6_row0_col0" class="data row0 col0" >0.149000</td>
#       <td id="T_974d6_row0_col1" class="data row0 col1" >0.345000</td>
#     </tr>
#     <tr>
#       <th id="T_974d6_level0_row1" class="row_heading level0 row1" >9.500e+00 < x <= 7.729e+01</th>
#       <td id="T_974d6_row1_col0" class="data row1 col0" >0.472000</td>
#       <td id="T_974d6_row1_col1" class="data row1 col1" >0.549000</td>
#     </tr>
#     <tr>
#       <th id="T_974d6_level0_row2" class="row_heading level0 row2" >7.729e+01 < x</th>
#       <td id="T_974d6_row2_col0" class="data row2 col0" >0.710000</td>
#       <td id="T_974d6_row2_col1" class="data row2 col1" >0.106000</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
# ------
# [AutoCarver] Fit Siblings/Spouses Aboard (2/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_402ff_row0_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_402ff_row0_col1, #T_402ff_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_402ff_row1_col0 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_402ff_row1_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_402ff_row2_col1, #T_402ff_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_402ff_row3_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_402ff" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_402ff_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_402ff_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_402ff_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_402ff_row0_col0" class="data row0 col0" >0.361000</td>
#       <td id="T_402ff_row0_col1" class="data row0 col1" >0.680000</td>
#     </tr>
#     <tr>
#       <th id="T_402ff_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 1.000e+00</th>
#       <td id="T_402ff_row1_col0" class="data row1 col0" >0.500000</td>
#       <td id="T_402ff_row1_col1" class="data row1 col1" >0.232000</td>
#     </tr>
#     <tr>
#       <th id="T_402ff_level0_row2" class="row_heading level0 row2" >1.000e+00 < x <= 2.000e+00</th>
#       <td id="T_402ff_row2_col0" class="data row2 col0" >0.550000</td>
#       <td id="T_402ff_row2_col1" class="data row2 col1" >0.034000</td>
#     </tr>
#     <tr>
#       <th id="T_402ff_level0_row3" class="row_heading level0 row3" >2.000e+00 < x</th>
#       <td id="T_402ff_row3_col0" class="data row3 col0" >0.094000</td>
#       <td id="T_402ff_row3_col1" class="data row3 col1" >0.054000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_28539_row0_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_28539_row0_col1, #T_28539_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_28539_row1_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_28539_row2_col0, #T_28539_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_28539_row3_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_28539_row3_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_28539" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28539_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_28539_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28539_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_28539_row0_col0" class="data row0 col0" >0.320000</td>
#       <td id="T_28539_row0_col1" class="data row0 col1" >0.683000</td>
#     </tr>
#     <tr>
#       <th id="T_28539_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 1.000e+00</th>
#       <td id="T_28539_row1_col0" class="data row1 col0" >0.606000</td>
#       <td id="T_28539_row1_col1" class="data row1 col1" >0.242000</td>
#     </tr>
#     <tr>
#       <th id="T_28539_level0_row2" class="row_heading level0 row2" >1.000e+00 < x <= 2.000e+00</th>
#       <td id="T_28539_row2_col0" class="data row2 col0" >0.250000</td>
#       <td id="T_28539_row2_col1" class="data row2 col1" >0.027000</td>
#     </tr>
#     <tr>
#       <th id="T_28539_level0_row3" class="row_heading level0 row3" >2.000e+00 < x</th>
#       <td id="T_28539_row3_col0" class="data row3 col0" >0.286000</td>
#       <td id="T_28539_row3_col1" class="data row3 col1" >0.048000</td>
#     </tr>
#   </tbody>
# </table>
# Grouping modalities   : 100%|██████████| 7/7 [00:00<00:00, 3511.98it/s]
# Computing associations: 100%|██████████| 7/7 [00:00<00:00, 3449.26it/s]
# Testing robustness    :   0%|          | 0/7 [00:00<?, ?it/s]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_be17c_row0_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_be17c_row0_col1, #T_be17c_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_be17c_row1_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_be17c_row2_col0, #T_be17c_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_be17c" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be17c_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_be17c_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be17c_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_be17c_row0_col0" class="data row0 col0" >0.361000</td>
#       <td id="T_be17c_row0_col1" class="data row0 col1" >0.680000</td>
#     </tr>
#     <tr>
#       <th id="T_be17c_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 2.000e+00</th>
#       <td id="T_be17c_row1_col0" class="data row1 col0" >0.506000</td>
#       <td id="T_be17c_row1_col1" class="data row1 col1" >0.266000</td>
#     </tr>
#     <tr>
#       <th id="T_be17c_level0_row2" class="row_heading level0 row2" >2.000e+00 < x</th>
#       <td id="T_be17c_row2_col0" class="data row2 col0" >0.094000</td>
#       <td id="T_be17c_row2_col1" class="data row2 col1" >0.054000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_cea2e_row0_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_cea2e_row0_col1, #T_cea2e_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cea2e_row1_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_cea2e_row2_col0, #T_cea2e_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cea2e" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cea2e_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_cea2e_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cea2e_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_cea2e_row0_col0" class="data row0 col0" >0.320000</td>
#       <td id="T_cea2e_row0_col1" class="data row0 col1" >0.683000</td>
#     </tr>
#     <tr>
#       <th id="T_cea2e_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 2.000e+00</th>
#       <td id="T_cea2e_row1_col0" class="data row1 col0" >0.570000</td>
#       <td id="T_cea2e_row1_col1" class="data row1 col1" >0.270000</td>
#     </tr>
#     <tr>
#       <th id="T_cea2e_level0_row2" class="row_heading level0 row2" >2.000e+00 < x</th>
#       <td id="T_cea2e_row2_col0" class="data row2 col0" >0.286000</td>
#       <td id="T_cea2e_row2_col1" class="data row2 col1" >0.048000</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
# ------
# [AutoCarver] Fit Age (3/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_e33ec_row0_col0, #T_e33ec_row8_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e33ec_row0_col1, #T_e33ec_row16_col1, #T_e33ec_row20_col1, #T_e33ec_row28_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e33ec_row1_col0 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_e33ec_row1_col1, #T_e33ec_row9_col1, #T_e33ec_row14_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_e33ec_row2_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_e33ec_row2_col1, #T_e33ec_row6_col0, #T_e33ec_row19_col1, #T_e33ec_row22_col1, #T_e33ec_row25_col1, #T_e33ec_row26_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e33ec_row3_col0, #T_e33ec_row20_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_e33ec_row3_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_e33ec_row4_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_e33ec_row4_col1 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_e33ec_row5_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_e33ec_row5_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_e33ec_row6_col1, #T_e33ec_row13_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e33ec_row7_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_e33ec_row7_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_e33ec_row8_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_e33ec_row9_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_e33ec_row10_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_e33ec_row10_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e33ec_row11_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_e33ec_row11_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_e33ec_row12_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_e33ec_row12_col1, #T_e33ec_row27_col1 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_e33ec_row13_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_e33ec_row14_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_e33ec_row15_col0, #T_e33ec_row17_col0, #T_e33ec_row29_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_e33ec_row15_col1, #T_e33ec_row17_col1, #T_e33ec_row18_col1, #T_e33ec_row23_col1, #T_e33ec_row29_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_e33ec_row16_col0, #T_e33ec_row19_col0, #T_e33ec_row27_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_e33ec_row18_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_e33ec_row21_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_e33ec_row21_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_e33ec_row22_col0, #T_e33ec_row25_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e33ec_row23_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_e33ec_row24_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_e33ec_row24_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_e33ec_row26_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_e33ec_row28_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_e33ec_row30_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_e33ec_row30_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# </style>
# <table id="T_e33ec" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e33ec_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_e33ec_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e33ec_level0_row0" class="row_heading level0 row0" >x <= 2.000e+00</th>
#       <td id="T_e33ec_row0_col0" class="data row0 col0" >0.750000</td>
#       <td id="T_e33ec_row0_col1" class="data row0 col1" >0.027000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row1" class="row_heading level0 row1" >2.000e+00 < x <= 7.000e+00</th>
#       <td id="T_e33ec_row1_col0" class="data row1 col0" >0.625000</td>
#       <td id="T_e33ec_row1_col1" class="data row1 col1" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row2" class="row_heading level0 row2" >7.000e+00 < x <= 1.100e+01</th>
#       <td id="T_e33ec_row2_col0" class="data row2 col0" >0.167000</td>
#       <td id="T_e33ec_row2_col1" class="data row2 col1" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row3" class="row_heading level0 row3" >1.100e+01 < x <= 1.600e+01</th>
#       <td id="T_e33ec_row3_col0" class="data row3 col0" >0.440000</td>
#       <td id="T_e33ec_row3_col1" class="data row3 col1" >0.042000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row4" class="row_heading level0 row4" >1.600e+01 < x <= 1.800e+01</th>
#       <td id="T_e33ec_row4_col0" class="data row4 col0" >0.323000</td>
#       <td id="T_e33ec_row4_col1" class="data row4 col1" >0.052000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row5" class="row_heading level0 row5" >1.800e+01 < x <= 1.900e+01</th>
#       <td id="T_e33ec_row5_col0" class="data row5 col0" >0.391000</td>
#       <td id="T_e33ec_row5_col1" class="data row5 col1" >0.039000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row6" class="row_heading level0 row6" >1.900e+01 < x <= 2.050e+01</th>
#       <td id="T_e33ec_row6_col0" class="data row6 col0" >0.111000</td>
#       <td id="T_e33ec_row6_col1" class="data row6 col1" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row7" class="row_heading level0 row7" >2.050e+01 < x <= 2.100e+01</th>
#       <td id="T_e33ec_row7_col0" class="data row7 col0" >0.190000</td>
#       <td id="T_e33ec_row7_col1" class="data row7 col1" >0.035000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row8" class="row_heading level0 row8" >2.100e+01 < x <= 2.350e+01</th>
#       <td id="T_e33ec_row8_col0" class="data row8 col0" >0.419000</td>
#       <td id="T_e33ec_row8_col1" class="data row8 col1" >0.072000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row9" class="row_heading level0 row9" >2.350e+01 < x <= 2.400e+01</th>
#       <td id="T_e33ec_row9_col0" class="data row9 col0" >0.542000</td>
#       <td id="T_e33ec_row9_col1" class="data row9 col1" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row10" class="row_heading level0 row10" >2.400e+01 < x <= 2.500e+01</th>
#       <td id="T_e33ec_row10_col0" class="data row10 col0" >0.133000</td>
#       <td id="T_e33ec_row10_col1" class="data row10 col1" >0.025000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row11" class="row_heading level0 row11" >2.500e+01 < x <= 2.700e+01</th>
#       <td id="T_e33ec_row11_col0" class="data row11 col0" >0.467000</td>
#       <td id="T_e33ec_row11_col1" class="data row11 col1" >0.051000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row12" class="row_heading level0 row12" >2.700e+01 < x <= 2.850e+01</th>
#       <td id="T_e33ec_row12_col0" class="data row12 col0" >0.250000</td>
#       <td id="T_e33ec_row12_col1" class="data row12 col1" >0.034000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row13" class="row_heading level0 row13" >2.850e+01 < x <= 2.900e+01</th>
#       <td id="T_e33ec_row13_col0" class="data row13 col0" >0.444000</td>
#       <td id="T_e33ec_row13_col1" class="data row13 col1" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row14" class="row_heading level0 row14" >2.900e+01 < x <= 3.000e+01</th>
#       <td id="T_e33ec_row14_col0" class="data row14 col0" >0.292000</td>
#       <td id="T_e33ec_row14_col1" class="data row14 col1" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row15" class="row_heading level0 row15" >3.000e+01 < x <= 3.100e+01</th>
#       <td id="T_e33ec_row15_col0" class="data row15 col0" >0.385000</td>
#       <td id="T_e33ec_row15_col1" class="data row15 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_e33ec_level0_row16" class="row_heading level0 row16" >3.100e+01 < x <= 3.200e+01</th>
#       <td id="T_e33ec_row16_col0" class="data row16 col0" >0.500000</td>
#       <td
# Grouping modalities   : 100%|██████████| 31930/31930 [00:05<00:00, 6361.64it/s]
# Computing associations: 100%|██████████| 31930/31930 [00:07<00:00, 4450.87it/s]
# Testing robustness    :   0%|          | 1/31930 [00:05<45:05:40,  5.08s/it]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_88258_row0_col0, #T_88258_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_88258_row0_col1, #T_88258_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_88258" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88258_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_88258_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88258_level0_row0" class="row_heading level0 row0" >x <= 7.000e+00</th>
#       <td id="T_88258_row0_col0" class="data row0 col0" >0.675000</td>
#       <td id="T_88258_row0_col1" class="data row0 col1" >0.067000</td>
#     </tr>
#     <tr>
#       <th id="T_88258_level0_row1" class="row_heading level0 row1" >7.000e+00 < x</th>
#       <td id="T_88258_row1_col0" class="data row1 col0" >0.365000</td>
#       <td id="T_88258_row1_col1" class="data row1 col1" >0.933000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_c225a_row0_col0, #T_c225a_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c225a_row0_col1, #T_c225a_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c225a" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c225a_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_c225a_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c225a_level0_row0" class="row_heading level0 row0" >x <= 7.000e+00</th>
#       <td id="T_c225a_row0_col0" class="data row0 col0" >0.588000</td>
#       <td id="T_c225a_row0_col1" class="data row0 col1" >0.058000</td>
#     </tr>
#     <tr>
#       <th id="T_c225a_level0_row1" class="row_heading level0 row1" >7.000e+00 < x</th>
#       <td id="T_c225a_row1_col0" class="data row1 col0" >0.373000</td>
#       <td id="T_c225a_row1_col1" class="data row1 col1" >0.942000</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
# ------
# [AutoCarver] Fit Pclass (4/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_6f349_row0_col0, #T_6f349_row2_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6f349_row0_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_6f349_row1_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_6f349_row1_col1, #T_6f349_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6f349" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f349_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_6f349_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f349_level0_row0" class="row_heading level0 row0" >1, 1</th>
#       <td id="T_6f349_row0_col0" class="data row0 col0" >0.620000</td>
#       <td id="T_6f349_row0_col1" class="data row0 col1" >0.239000</td>
#     </tr>
#     <tr>
#       <th id="T_6f349_level0_row1" class="row_heading level0 row1" >2, 2</th>
#       <td id="T_6f349_row1_col0" class="data row1 col0" >0.468000</td>
#       <td id="T_6f349_row1_col1" class="data row1 col1" >0.212000</td>
#     </tr>
#     <tr>
#       <th id="T_6f349_level0_row2" class="row_heading level0 row2" >3, 3</th>
#       <td id="T_6f349_row2_col0" class="data row2 col0" >0.252000</td>
#       <td id="T_6f349_row2_col1" class="data row2 col1" >0.549000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_6e9bc_row0_col0, #T_6e9bc_row2_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6e9bc_row0_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_6e9bc_row1_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_6e9bc_row1_col1, #T_6e9bc_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6e9bc" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e9bc_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_6e9bc_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e9bc_level0_row0" class="row_heading level0 row0" >1, 1</th>
#       <td id="T_6e9bc_row0_col0" class="data row0 col0" >0.649000</td>
#       <td id="T_6e9bc_row0_col1" class="data row0 col1" >0.253000</td>
#     </tr>
#     <tr>
#       <th id="T_6e9bc_level0_row1" class="row_heading level0 row1" >2, 2</th>
#       <td id="T_6e9bc_row1_col0" class="data row1 col0" >0.483000</td>
#       <td id="T_6e9bc_row1_col1" class="data row1 col1" >0.198000</td>
#     </tr>
#     <tr>
#       <th id="T_6e9bc_level0_row2" class="row_heading level0 row2" >3, 3</th>
#       <td id="T_6e9bc_row2_col0" class="data row2 col0" >0.230000</td>
#       <td id="T_6e9bc_row2_col1" class="data row2 col1" >0.549000</td>
#     </tr>
#   </tbody>
# </table>
# Grouping modalities   : 100%|██████████| 3/3 [00:00<00:00, 3006.67it/s]
# Computing associations: 100%|██████████| 3/3 [00:00<00:00, 2804.30it/s]
# Testing robustness    :   0%|          | 0/3 [00:00<?, ?it/s]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_a31bb_row0_col0, #T_a31bb_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a31bb_row0_col1, #T_a31bb_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a31bb" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a31bb_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_a31bb_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a31bb_level0_row0" class="row_heading level0 row0" >1 to 2</th>
#       <td id="T_a31bb_row0_col0" class="data row0 col0" >0.549000</td>
#       <td id="T_a31bb_row0_col1" class="data row0 col1" >0.451000</td>
#     </tr>
#     <tr>
#       <th id="T_a31bb_level0_row1" class="row_heading level0 row1" >3, 3</th>
#       <td id="T_a31bb_row1_col0" class="data row1 col0" >0.252000</td>
#       <td id="T_a31bb_row1_col1" class="data row1 col1" >0.549000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_7c717_row0_col0, #T_7c717_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7c717_row0_col1, #T_7c717_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7c717" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c717_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_7c717_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c717_level0_row0" class="row_heading level0 row0" >1 to 2</th>
#       <td id="T_7c717_row0_col0" class="data row0 col0" >0.576000</td>
#       <td id="T_7c717_row0_col1" class="data row0 col1" >0.451000</td>
#     </tr>
#     <tr>
#       <th id="T_7c717_level0_row1" class="row_heading level0 row1" >3, 3</th>
#       <td id="T_7c717_row1_col0" class="data row1 col0" >0.230000</td>
#       <td id="T_7c717_row1_col1" class="data row1 col1" >0.549000</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
# ------
# [AutoCarver] Fit Parents/Children Aboard (5/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_53ae7_row0_col0, #T_53ae7_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_53ae7_row0_col1, #T_53ae7_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_53ae7_row1_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_53ae7_row2_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_53ae7" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53ae7_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_53ae7_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53ae7_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_53ae7_row0_col0" class="data row0 col0" >0.345000</td>
#       <td id="T_53ae7_row0_col1" class="data row0 col1" >0.737000</td>
#     </tr>
#     <tr>
#       <th id="T_53ae7_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 1.000e+00</th>
#       <td id="T_53ae7_row1_col0" class="data row1 col0" >0.506000</td>
#       <td id="T_53ae7_row1_col1" class="data row1 col1" >0.146000</td>
#     </tr>
#     <tr>
#       <th id="T_53ae7_level0_row2" class="row_heading level0 row2" >1.000e+00 < x</th>
#       <td id="T_53ae7_row2_col0" class="data row2 col0" >0.493000</td>
#       <td id="T_53ae7_row2_col1" class="data row2 col1" >0.116000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_8ed0f_row0_col0, #T_8ed0f_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8ed0f_row0_col1, #T_8ed0f_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8ed0f_row1_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_8ed0f_row2_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8ed0f" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ed0f_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_8ed0f_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ed0f_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_8ed0f_row0_col0" class="data row0 col0" >0.347000</td>
#       <td id="T_8ed0f_row0_col1" class="data row0 col1" >0.805000</td>
#     </tr>
#     <tr>
#       <th id="T_8ed0f_level0_row1" class="row_heading level0 row1" >0.000e+00 < x <= 1.000e+00</th>
#       <td id="T_8ed0f_row1_col0" class="data row1 col0" >0.677000</td>
#       <td id="T_8ed0f_row1_col1" class="data row1 col1" >0.106000</td>
#     </tr>
#     <tr>
#       <th id="T_8ed0f_level0_row2" class="row_heading level0 row2" >1.000e+00 < x</th>
#       <td id="T_8ed0f_row2_col0" class="data row2 col0" >0.385000</td>
#       <td id="T_8ed0f_row2_col1" class="data row2 col1" >0.089000</td>
#     </tr>
#   </tbody>
# </table>
# Grouping modalities   : 100%|██████████| 3/3 [00:00<00:00, 3006.67it/s]
# Computing associations: 100%|██████████| 3/3 [00:00<00:00, 3008.83it/s]
# Testing robustness    :   0%|          | 0/3 [00:00<?, ?it/s]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_57fe7_row0_col0, #T_57fe7_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_57fe7_row0_col1, #T_57fe7_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_57fe7" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57fe7_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_57fe7_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57fe7_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_57fe7_row0_col0" class="data row0 col0" >0.345000</td>
#       <td id="T_57fe7_row0_col1" class="data row0 col1" >0.737000</td>
#     </tr>
#     <tr>
#       <th id="T_57fe7_level0_row1" class="row_heading level0 row1" >0.000e+00 < x</th>
#       <td id="T_57fe7_row1_col0" class="data row1 col0" >0.500000</td>
#       <td id="T_57fe7_row1_col1" class="data row1 col1" >0.263000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_2e540_row0_col0, #T_2e540_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2e540_row0_col1, #T_2e540_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2e540" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e540_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_2e540_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e540_level0_row0" class="row_heading level0 row0" >x <= 0.000e+00</th>
#       <td id="T_2e540_row0_col0" class="data row0 col0" >0.347000</td>
#       <td id="T_2e540_row0_col1" class="data row0 col1" >0.805000</td>
#     </tr>
#     <tr>
#       <th id="T_2e540_level0_row1" class="row_heading level0 row1" >0.000e+00 < x</th>
#       <td id="T_2e540_row1_col0" class="data row1 col0" >0.544000</td>
#       <td id="T_2e540_row1_col1" class="data row1 col1" >0.195000</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
# ------
# [AutoCarver] Fit Sex (6/6)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_8e816_row0_col0, #T_8e816_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8e816_row0_col1, #T_8e816_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8e816" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e816_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_8e816_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e816_level0_row0" class="row_heading level0 row0" >male</th>
#       <td id="T_8e816_row0_col0" class="data row0 col0" >0.188000</td>
#       <td id="T_8e816_row0_col1" class="data row0 col1" >0.636000</td>
#     </tr>
#     <tr>
#       <th id="T_8e816_level0_row1" class="row_heading level0 row1" >female</th>
#       <td id="T_8e816_row1_col0" class="data row1 col0" >0.731000</td>
#       <td id="T_8e816_row1_col1" class="data row1 col1" >0.364000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_620b1_row0_col0, #T_620b1_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_620b1_row0_col1, #T_620b1_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_620b1" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_620b1_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_620b1_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_620b1_level0_row0" class="row_heading level0 row0" >male</th>
#       <td id="T_620b1_row0_col0" class="data row0 col0" >0.195000</td>
#       <td id="T_620b1_row0_col1" class="data row0 col1" >0.666000</td>
#     </tr>
#     <tr>
#       <th id="T_620b1_level0_row1" class="row_heading level0 row1" >female</th>
#       <td id="T_620b1_row1_col0" class="data row1 col0" >0.765000</td>
#       <td id="T_620b1_row1_col1" class="data row1 col1" >0.334000</td>
#     </tr>
#   </tbody>
# </table>
# Grouping modalities   : 100%|██████████| 1/1 [00:00<00:00, 1003.42it/s]
# Computing associations: 100%|██████████| 1/1 [00:00<00:00, 1001.27it/s]
# Testing robustness    :   0%|          | 0/1 [00:00<?, ?it/s]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_70b59_row0_col0, #T_70b59_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_70b59_row0_col1, #T_70b59_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_70b59" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70b59_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_70b59_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70b59_level0_row0" class="row_heading level0 row0" >male</th>
#       <td id="T_70b59_row0_col0" class="data row0 col0" >0.188000</td>
#       <td id="T_70b59_row0_col1" class="data row0 col1" >0.636000</td>
#     </tr>
#     <tr>
#       <th id="T_70b59_level0_row1" class="row_heading level0 row1" >female</th>
#       <td id="T_70b59_row1_col0" class="data row1 col0" >0.731000</td>
#       <td id="T_70b59_row1_col1" class="data row1 col1" >0.364000</td>
#     </tr>
#   </tbody>
# </table>
#     <style type="text/css">
# #T_23802_row0_col0, #T_23802_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_23802_row0_col1, #T_23802_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_23802" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23802_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_23802_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23802_level0_row0" class="row_heading level0 row0" >male</th>
#       <td id="T_23802_row0_col0" class="data row0 col0" >0.195000</td>
#       <td id="T_23802_row0_col1" class="data row0 col1" >0.666000</td>
#     </tr>
#     <tr>
#       <th id="T_23802_level0_row1" class="row_heading level0 row1" >female</th>
#       <td id="T_23802_row1_col0" class="data row1 col0" >0.765000</td>
#       <td id="T_23802_row1_col1" class="data row1 col1" >0.334000</td>
#     </tr>
#   </tbody>
# </table>
# ------

# %%
# from ucimlrepo import fetch_ucirepo 
  
# # fetch dataset 
# breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17) 
  
# # data (as pandas dataframes) 
# X = breast_cancer_wisconsin_diagnostic.data.features 
# y = breast_cancer_wisconsin_diagnostic.data.targets 
  
# # metadata 
# print(breast_cancer_wisconsin_diagnostic.metadata) 
  
# # variable information 
# print(breast_cancer_wisconsin_diagnostic.variables)
# Out:
# {'uci_id': 17, 'name': 'Breast Cancer Wisconsin (Diagnostic)', 'repository_url': 'https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic', 'data_url': 'https://archive.ics.uci.edu/static/public/17/data.csv', 'abstract': 'Diagnostic Wisconsin Breast Cancer Database.', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 569, 'num_features': 30, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['Diagnosis'], 'index_col': ['ID'], 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1993, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C5DW2B', 'creators': ['William Wolberg', 'Olvi Mangasarian', 'Nick Street', 'W. Street'], 'intro_paper': {'title': 'Nuclear feature extraction for breast tumor diagnosis', 'authors': 'W. Street, W. Wolberg, O. Mangasarian', 'published_in': 'Electronic imaging', 'year': 1993, 'url': 'https://www.semanticscholar.org/paper/53f0fbb425bc14468eb3bf96b2e1d41ba8087f36', 'doi': '10.1117/12.148698'}, 'additional_info': {'summary': 'Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.  They describe characteristics of the cell nuclei present in the image. A few of the images can be found at http://www.cs.wisc.edu/~street/images/\r\n\r\nSeparating plane described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.\r\n\r\nThe actual linear program used to obtain the separating plane in the 3-dimensional space is that described in: [K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].\r\n\r\nThis database is also available through the UW CS ftp server:\r\nftp ftp.cs.wisc.edu\r\ncd math-prog/cpo-dataset/machine-learn/WDBC/', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': '1) ID number\r\n2) Diagnosis (M = malignant, B = benign)\r\n3-32)\r\n\r\nTen real-valued features are computed for each cell nucleus:\r\n\r\n\ta) radius (mean of distances from center to points on the perimeter)\r\n\tb) texture (standard deviation of gray-scale values)\r\n\tc) perimeter\r\n\td) area\r\n\te) smoothness (local variation in radius lengths)\r\n\tf) compactness (perimeter^2 / area - 1.0)\r\n\tg) concavity (severity of concave portions of the contour)\r\n\th) concave points (number of concave portions of the contour)\r\n\ti) symmetry \r\n\tj) fractal dimension ("coastline approximation" - 1)', 'citation': None}}
#                   name     role         type demographic description units  \
# 0                   ID       ID  Categorical        None        None  None
# 1            Diagnosis   Target  Categorical        None        None  None
# 2              radius1  Feature   Continuous        None        None  None
# 3             texture1  Feature   Continuous        None        None  None
# 4           perimeter1  Feature   Continuous        None        None  None
# 5                area1  Feature   Continuous        None        None  None
# 6          smoothness1  Feature   Continuous        None        None  None
# 7         compactness1  Feature   Continuous        None        None  None
# 8           concavity1  Feature   Continuous        None        None  None
# 9      concave_points1  Feature   Continuous        None        None  None
# 10           symmetry1  Feature   Continuous        None        None  None
# 11  fractal_dimension1  Feature   Continuous        None        None  None
# 12             radius2  Feature   Continuous        None        None  None
# 13            texture2  Feature   Continuous        None        None  None
# 14          perimeter2  Feature   Continuous        None        None  None
# 15               area2  Feature   Continuous        None        None  None
# 16         smoothness2  Feature   Continuous        None        None  None
# 17        compactness2  Feature   Continuous        None        None  None
# 18          concavity2  Feature   Continuous        None        None  None
# 19     concave_points2  Feature   Continuous        None        None  None
# 20           symmetry2  Feature   Continuous        None        None  None
# 21  fractal_dimension2  Feature   Continuous        None        None  None
# 22             radius3  Feature   Continuous        None        None  None
# 23            texture3  Feature   Continuous        None        None  None
# 24          perimeter3  Feature   Continuous        None        None  None
# 25               area3  Feature   Continuous        None        None  None
# 26         smoothness3  Feature   Continuous        None        None  None
# 27        compactness3  Feature   Continuous        None        None  None
# 28          concavity3  Feature   Continuous        None        None  None
# 29     concave_points3  Feature   Continuous        None        None  None
# 30           symmetry3  Feature   Continuous        None        None  None
# 31  fractal_dimension3  Feature   Continuous        None        None  None
#
#    missing_values
# 0              no
# 1              no
# 2              no
# 3              no
# 4              no
# 5              no
# 6              no
# 7              no
# 8              no
# 9              no
# 10             no
# 11             no
# 12             no
# 13             no
# 14             no
# 15             no
# 16             no
# 17             no
# 18             no
# 19             no
# 20             no
# 21             no
# 22             no
# 23             no
# 24             no
# 25             no
# 26             no
# 27             no
# 28             no
# 29             no
# 30             no
# 31             no
