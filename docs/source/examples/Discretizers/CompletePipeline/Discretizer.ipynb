# %% [markdown]
# # About
#
# Welcome to this notebook where we will explore the Census Adult Income dataset, a rich source of socio-economic information derived from the 1994 U.S. Census Bureau database. Our focus in this analysis is on employing a robust Python data discretization pipeline: **Discretizer**. This versatile tool is able to discretize various types of data, both quantitative and qualitative, making it an ideal companion for preprocessing tasks.
#
# Data discretization is a crucial step in preparing datasets for machine learning models. It involves transforming continuous or categorical variables into discrete bins, allowing for improved interpretability, handling non-linearity, and addressing potential outliers. The **Discretizer** we will employ is designed to handle a diverse range of data types, including quantitative variables such as age and education level, as well as qualitative variables like marital status and occupation.
#
# Throughout this notebook, we will delve into the intricacies of the Census Adult Income dataset, exploring the distribution of features and employing the Discretizer to discretize the data effectively. By the end of this preprocessing journey, we aim to create a dataset that is well-suited for subsequent machine learning tasks, enabling the development of robust models for predicting income levels based on socio-economic attributes.
#
# Let's embark on this exploration and witness the power of **Discretizer** in preparing our data for insightful analysis and accurate modeling.
#
# # Setting things up
# ## Installation

# %%
# %pip install autocarver

# %% [markdown]
# ## Census Data
#
# In this example notebook, we will use the Census dataset.
#
# The Census Adult Income dataset, commonly referred to as the "Adult" dataset, is a well-known dataset in the realm of machine learning and data analysis. It is frequently used for tasks related to classification and predictive modeling. The dataset is derived from the 1994 U.S. Census Bureau database and contains a diverse set of features that aim to predict whether an individual earns more than $50,000 annually, making it a binary classification problem.
#
# The features in the Adult dataset include demographic information such as age, education level, marital status, occupation, and work-related details like hours worked per week. The primary objective when working with this dataset is typically to build a predictive model capable of discerning between individuals with annual incomes above and below the $50,000 threshold.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
adult = fetch_ucirepo(id=2) 
  
# data (as pandas dataframes) 
adult_data = adult.data.features 
adult_data = adult_data.join(adult.data.targets)
  
# Display the first few rows of the dataset
adult_data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %% [markdown]
# ## Target type

# %%
target = "income"

# cleaning target
adult_data[target] = adult_data[target].apply(lambda u: u.replace(".", ""))

adult_data[target].value_counts(dropna=False)
# Out:
# income
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64

# %% [markdown]
# The target ``"income"`` is a binary target of type ``str`` used in a classification task.

# %% [markdown]
# ## Data Sampling

# %%
from sklearn.model_selection import train_test_split

# stratified sampling by target
train_set, dev_set = train_test_split(adult_data, test_size=0.20, random_state=42, stratify=adult_data[target])

# checking target rate per dataset
train_set[target].value_counts(normalize=True), dev_set[target].value_counts(normalize=True)
# Out:
# c:\Users\defra\.conda\envs\py39\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\defra\.conda\envs\py39\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# (income
#  <=50K    0.76073
#  >50K     0.23927
#  Name: proportion, dtype: float64,
#  income
#  <=50K    0.760672
#  >50K     0.239328
#  Name: proportion, dtype: float64)

# %% [markdown]
# ## Picking up columns to Discretize

# %%
train_set.head()
# Out:
#        age     workclass  fnlwgt  education  education-num  \
# 34495   37       Private  193106  Bachelors             13
# 18591   56  Self-emp-inc  216636       12th              8
# 12562   53       Private  126977    HS-grad              9
# 552     72       Private  205343       11th              7
# 3479    46     State-gov  106705    Masters             14
#
#            marital-status       occupation   relationship   race     sex  \
# 34495       Never-married            Sales  Not-in-family  White  Female
# 18591  Married-civ-spouse  Exec-managerial        Husband  White    Male
# 12562           Separated     Craft-repair  Not-in-family  White    Male
# 552               Widowed     Adm-clerical      Unmarried  White  Female
# 3479        Never-married  Exec-managerial  Not-in-family  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 34495             0             0              30  United-States  <=50K
# 18591             0          1651              40  United-States  <=50K
# 12562             0             0              35  United-States  <=50K
# 552               0             0              40  United-States  <=50K
# 3479              0             0              38  United-States  <=50K

# %%
n = ""
for f in train_set.groupby("education-num")["education"].apply(lambda u: f'"{u.unique()[0]}", '):
    n += f
print(n)
# Out:
# "Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th", "HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm", "Bachelors", "Masters", "Prof-school", "Doctorate",

# %%
# column data types
train_set.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
n = ''
for f in train_set:
    n += f'"{f}", '
print(n)
# Out:
# "age", "workclass", "fnlwgt", "education", "education-num", "marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country", "income",

# %% [markdown]
# * ``"education"`` is  the only qualitative ordinal feature. It will be added to the list of ``ordinal_features`` and ``values_orders`` has to be set.
#
# * ``"sex"``, ``"marital-status"``, ``"occupation"``, ``"relationship"``, ``"race"``, ``"native-country"`` and ``"workclass"`` are quantitative categorical features. Those features will be added to the list of ``qualitative_features``.
#
# * ``"capital-gain"`` and ``"capital-loss"`` are quantitative continuous features, whilst ``"education-num"``, ``"Age"`` and ``"hours-per-week"`` can be considered as quantitative discrete features. Those features will be added to the list of ``quantitative_features``.
#
# * ``"fnlwgt"`` is the weighting column. It is not currently usable in **AutoCarver**

# %%
# lists of features per data type
quantitative_features = ["capital-gain", "capital-loss", "education-num", "hours-per-week", "age"]
qualitative_features = ["sex", "workclass", "marital-status", "occupation", "relationship", "race", "native-country", "income"]
ordinal_features = ["education"]
weighting = ["fnlwgt"]

# user-specified ordering for ordinal features
values_orders = {
    "education": ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th", "HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm", "Bachelors", "Masters", "Prof-school", "Doctorate"]
}

# %% [markdown]
# # Using Discretizer
# ## Discretizer Settings
# ### Representativness of modalities
#
# The attribute ``min_freq`` allows one to choose the minimum frequency per basic modalities. It is used by **Discretizers**:
#
# - For quantitative features, it defines the number of quantiles to initialy discretize the features with.
#
# - For qualitative features, it defines the threshold under which a modality is grouped to either a default value or its closest modality.

# %%
min_freq = 0.02

# %% [markdown]
# **Tip:** should be set between ``0.01`` (slower, preciser, less robust) and ``0.2`` (faster, more robust)

# %% [markdown]
# ## Fitting Discretizer

# %% [markdown]
# * First, all qualitative features are discretized:
#     1. Using ``StringDiscretizer`` to convert them to ``str`` if not already the case
#     2. For qualitative ordinal features: using ``OrdinalDiscretizer`` for under-represented values (less frequent than ``min_freq=0.05``) to be grouped with its closest modality
#     3. For qualitative categorical features: using ``CategoricalDiscretizer`` for under-represented values (less frequent than ``min_freq=0.05``) to be grouped with a default value (``str_default="__OTHER__"``)
#
# * Second, all quantitative features are discretized:
#     1. Using ``ContinuousDiscretizer`` for quantile discretization that keeps track of over-represented values (more frequent than ``min_freq=0.05``)
#     2. Using ``OrdinalDiscretizer`` for any remaining under-represented values (less frequent than ``min_freq/2=0.025``) to be grouped with its closest modality

# %%
from AutoCarver import BinaryCarver

# intiating AutoCarver
auto_carver = BinaryCarver(
    quantitative_features=quantitative_features,
    qualitative_features=qualitative_features,
    ordinal_features=ordinal_features,
    values_orders=values_orders,
    sort_by="tschuprowt",
    min_freq=min_freq,
    verbose=True,  # showing statistics
    copy=True,  # whether or not to return a copy of the input dataset
)

# fitting on training sample, a dev sample can be specified to evaluate carving robustness
train_set_processed = auto_carver.fit_transform(train_set, (train_set[target] == ">50K").astype(int))
# Out:
# ------
# [Discretizer] Fit Qualitative Features
# ---
#  - [OrdinalDiscretizer] Fit ['education']
#  - [CategoricalDiscretizer] Fit ['sex', 'race', 'workclass', 'occupation', 'relationship', 'marital-status', 'native-country', 'income']
# ------
#
# ------
# [Discretizer] Fit Quantitative Features
# ---
#  - [ContinuousDiscretizer] Fit ['age', 'hours-per-week', 'education-num', 'capital-loss', 'capital-gain']
#  - [OrdinalDiscretizer] Fit ['age', 'hours-per-week', 'education-num', 'capital-loss', 'capital-gain']
# ------
#
#
# ------
# [AutoCarver] Fit education (1/14)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_b6237_row0_col0, #T_b6237_row1_col1, #T_b6237_row9_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b6237_row0_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_b6237_row1_col0, #T_b6237_row2_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b6237_row2_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_b6237_row3_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_b6237_row3_col1, #T_b6237_row9_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b6237_row4_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_b6237_row4_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_b6237_row5_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_b6237_row5_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_b6237_row6_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_b6237_row6_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_b6237_row7_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_b6237_row7_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_b6237_row8_col0 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_b6237_row8_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b6237" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6237_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_b6237_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6237_level0_row0" class="row_heading level0 row0" >7th-8th to 9th</th>
#       <td id="T_b6237_row0_col0" class="data row0 col0" >0.0527</td>
#       <td id="T_b6237_row0_col1" class="data row0 col1" >0.0530</td>
#     </tr>
#     <tr>
#       <th id="T_b6237_level0_row1" class="row_heading level0 row1" >10th</th>
#       <td id="T_b6237_row1_col0" class="data row1 col0" >0.0578</td>
#       <td id="T_b6237_row1_col1" class="data row1 col1" >0.0284</td>
#     </tr>
#     <tr>
#       <th id="T_b6237_level0_row2" class="row_heading level0 row2" >12th, 11th</th>
#       <td id="T_b6237_row2_col0" class="data row2 col0" >0.0560</td>
#       <td id="T_b6237_row2_col1" class="data row2 col1" >0.0508</td>
#     </tr>
#     <tr>
#       <th id="T_b6237_level0_row3" class="row_heading level0 row3" >HS-grad</th>
#       <td id="T_b6237_row3_col0" class="data row3 col0" >0.1582</td>
#       <td id="T_b6237_row3_col1" class="data row3 col1" >0.3220</td>
#     </tr>
#     <tr>
#       <th id="T_b6237_level0_row4" class="row_heading level0 row4" >Some-college</th>
#       <td id="T_b6237_row4_col0" class="data row4 col0" >0.1919</td>
#       <td id="T_b6237_row4_col1" class="data row4 col1" >0.2237</td>
#     </tr>
#     <tr>
#       <th id="T_b6237_level0_row5" class="row_heading level0 row5" >Assoc-voc</th>
#       <td id="T_b6237_row5_col0" class="data row5 col0" >0.2468</td>
#       <td id="T_b6237_row5_col1" class="data row5 col1" >0.0424</td>
#     </tr>
#     <tr>
#       <th id="T_b6237_level0_row6" class="row_heading level0 row6" >Assoc-acdm</th>
#       <td id="T_b6237_row6_col0" class="data row6 col0" >0.2602</td>
#       <td id="T_b6237_row6_col1" class="data row6 col1" >0.0333</td>
#     </tr>
#     <tr>
#       <th id="T_b6237_level0_row7" class="row_heading level0 row7" >Bachelors</th>
#       <td id="T_b6237_row7_col0" class="data row7 col0" >0.4135</td>
#       <td id="T_b6237_row7_col1" class="data row7 col1" >0.1633</td>
#     </tr>
#     <tr>
#       <th id="T_b6237_level0_row8" class="row_heading level0 row8" >Masters</th>
#       <td id="T_b6237_row8_col0" class="data row8 col0" >0.5504</td>
#       <td id="T_b6237_row8_col1" class="data row8 col1" >0.0545</td>
#     </tr>
#     <tr>
#       <th id="T_b6237_level0_row9" class="row_heading level0 row9" >Doctorate, Prof-school</th>
#       <td id="T_b6237_row9_col0" class="data row9 col0" >0.7478</td>
#       <td id="T_b6237_row9_col1" class="data row9 col1" >0.0287</td>
#     </tr>
#   </tbody>
# </table>
# Grouping modalities   : 100%|██████████| 255/255 [00:00<00:00, 9360.40it/s]
# Computing associations: 100%|██████████| 255/255 [00:00<00:00, 3893.47it/s]
# Testing robustness    :   0%|          | 0/255 [00:00<?, ?it/s]
#  - [AutoCarver] Carved distribution
# <style type="text/css">
# #T_92316_row0_col0, #T_92316_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_92316_row0_col1, #T_92316_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_92316" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92316_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_92316_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92316_level0_row0" class="row_heading level0 row0" >7th-8th to 10th</th>
#       <td id="T_92316_row0_col0" class="data row0 col0" >0.1596</td>
#       <td id="T_92316_row0_col1" class="data row0 col1" >0.7535</td>
#     </tr>
#     <tr>
#       <th id="T_92316_level0_row1" class="row_heading level0 row1" >Bachelors to Masters</th>
#       <td id="T_92316_row1_col0" class="data row1 col0" >0.4828</td>
#       <td id="T_92316_row1_col1" class="data row1 col1" >0.2465</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
# ------
# [AutoCarver] Fit age (2/14)
# ---
#
#  - [AutoCarver] Raw distribution
# <style type="text/css">
# #T_93183_row0_col0, #T_93183_row2_col0, #T_93183_row36_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_93183_row0_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_93183_row1_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_93183_row1_col1, #T_93183_row12_col0 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_93183_row2_col1, #T_93183_row3_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_93183_row3_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_93183_row4_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_93183_row4_col1, #T_93183_row8_col1, #T_93183_row14_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_93183_row5_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_93183_row5_col1, #T_93183_row39_col0 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_93183_row6_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_93183_row6_col1, #T_93183_row17_col0, #T_93183_row21_col1 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_93183_row7_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_93183_row7_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_93183_row8_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_93183_row9_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_93183_row9_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_93183_row10_col0, #T_93183_row41_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_93183_row10_col1, #T_93183_row16_col0 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_93183_row11_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_93183_row11_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_93183_row12_col1 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_93183_row13_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_93183_row13_col1, #T_93183_row16_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_93183_row14_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_93183_row15_col0 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_93183_row15_col1 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_93183_row17_col1 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_93183_row18_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_93183_row18_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_93183_row19_col0 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_93183_row19_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_93183_row20_col0, #T_93183_row36_col0 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_93183_row20_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_93183_row21_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_93183_row22_col0 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_93183_row22_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_93183_row23_col0 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_93183_row23_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_93183_row24_col0 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_93183_row24_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_93183_row25_col0 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_93183_row25_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_93183_row26_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_93183_row26_col1, #T_93183_row27_col1, #T_93183_row29_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_93183_row27_col0 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_93183_row28_col0 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_93183_row28_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_93183_row29_col0, #T_93183_row34_col0 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_93183_row30_col0 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_93183_row30_col1, #T_93183_row31_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_93183_row31_col1, #T_93183_row32_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_93183_row32_col0 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_93183_row33_col0 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_93183_row33_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_93183_row34_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_93183_row35_col0 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_93183_row35_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_93183_row37_col0 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_93183_row37_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_93183_row38_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_93183_row38_col1 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_93183_row39_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_93183_row40_col0 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_93183_row40_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_93183_row41_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_93183_row42_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_93183_row42_col1 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# </style>
# <table id="T_93183" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93183_level0_col0" class="col_heading level0 col0" >target_rate</th>
#       <th id="T_93183_level0_col1" class="col_heading level0 col1" >frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93183_level0_row0" class="row_heading level0 row0" >x <= 1.800e+01</th>
#       <td id="T_93183_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_93183_row0_col1" class="data row0 col1" >0.0285</td>
#     </tr>
#     <tr>
#       <th id="T_93183_level0_row1" class="row_heading level0 row1" >1.800e+01 < x <= 1.900e+01</th>
#       <td id="T_93183_row1_col0" class="data row1 col0" >0.0023</td>
#       <td id="T_93183_row1_col1" class="data row1 col1" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_93183_level0_row2" class="row_heading level0 row2" >1.900e+01 < x <= 2.000e+01</th>
#       <td id="T_93183_row2_col0" class="data row2 col0" >0.0011</td>
#       <td id="T_93183_row2_col1" class="data row2 col1" >0.0229</td>
#     </tr>
#     <tr>
#       <th id="T_93183_level0_row3" class="row_heading level0 row3" >2.000e+01 < x <= 2.100e+01</th>
#       <td id="T_93183_row3_col0" class="data row3 col0" >0.0056</td>
#       <td id="T_93183_row3_col1" class="data row3 col1" >0.0229</td>
#     </tr>
#     <tr>
#       <th id="T_93183_level0_row4" class="row_heading level0 row4" >2.100e+01 < x <= 2.200e+01</th>
#       <td id="T_93183_row4_col0" class="data row4 col0" >0.0118</td>
#       <td id="T_93183_row4_col1" class="data row4 col1" >0.0239</td>
#     </tr>
#     <tr>
#       <th id="T_93183_level0_row5" class="row_heading level0 row5" >2.200e+01 < x <= 2.300e+01</th>
#       <td id="T_93183_row5_col0" class="data row5 col0" >0.0142</td>
#       <td id="T_93183_row5_col1" class="data row5 col1" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_93183_level0_row6" class="row_heading level0 row6" >2.300e+01 < x <= 2.400e+01</th>
#       <td id="T_93183_row6_col0" class="data row6 col0" >0.0386</td>
#       <td id="T_93183_row6_col1" class="data row6 col1" >0.0245</td>
#     </tr>
#     <tr>
#       <th id="T_93183_level0_row7" class="row_heading level0 row7" >2.400e+01 < x <= 2.500e+01</th>
#       <td id="T_93183_row7_col0" class="data row7 col0" >0.0665</td>
#       <td id="T_93183_row7_col1" class="data row7 col1" >0.0242</td>
#     </tr>
#     <tr>
#       <th id="T_93183_level0_row8" class="row_heading level0 row8" >2.500e+01 < x <= 2.600e+01</th>
#       <td id="T_93183_row8_col0" class="data row8 col0" >0.0802</td>
#       <td id="T_93183_row8_col1" class="data row8 col1" >0.0239</td>
#     </tr>
#     <tr>
#       <th id="T_93183_level0_row9" class="row_heading level0 row9" >2.600e+01 < x <= 2.700e+01</th>
#       <td id="T_93183_row9_co
# Grouping modalities   :  46%|████▌     | 56793/124313 [00:08<00:08, 7560.64it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\defra\Desktop\git\PROJECTS\AutoCarver\docs\source\examples\Discretizers\CompletePipeline\Discretizer.ipynb Cell 22 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/defra/Desktop/git/PROJECTS/AutoCarver/docs/source/examples/Discretizers/CompletePipeline/Discretizer.ipynb#X53sZmlsZQ%3D%3D?line=3'>4</a> auto_carver = BinaryCarver(
#       <a href='vscode-notebook-cell:/c%3A/Users/defra/Desktop/git/PROJECTS/AutoCarver/docs/source/examples/Discretizers/CompletePipeline/Discretizer.ipynb#X53sZmlsZQ%3D%3D?line=4'>5</a>     quantitative_features=quantitative_features,
#       <a href='vscode-notebook-cell:/c%3A/Users/defra/Desktop/git/PROJECTS/AutoCarver/docs/source/examples/Discretizers/CompletePipeline/Discretizer.ipynb#X53sZmlsZQ%3D%3D?line=5'>6</a>     qualitative_features=qualitative_features,
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/defra/Desktop/git/PROJECTS/AutoCarver/docs/source/examples/Discretizers/CompletePipeline/Discretizer.ipynb#X53sZmlsZQ%3D%3D?line=11'>12</a>     copy=True,  # whether or not to return a copy of the input dataset
#      <a href='vscode-notebook-cell:/c%3A/Users/defra/Desktop/git/PROJECTS/AutoCarver/docs/source/examples/Discretizers/CompletePipeline/Discretizer.ipynb#X53sZmlsZQ%3D%3D?line=12'>13</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/defra/Desktop/git/PROJECTS/AutoCarver/docs/source/examples/Discretizers/CompletePipeline/Discretizer.ipynb#X53sZmlsZQ%3D%3D?line=14'>15</a> # fitting on training sample, a dev sample can be specified to evaluate carving robustness
# ---> <a href='vscode-notebook-cell:/c%3A/Users/defra/Desktop/git/PROJECTS/AutoCarver/docs/source/examples/Discretizers/CompletePipeline/Discretizer.ipynb#X53sZmlsZQ%3D%3D?line=15'>16</a> train_set_processed = auto_carver.fit_transform(train_set, (train_set[target] == ">50K").astype(int))
#
# File c:\Users\defra\.conda\envs\py39\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\Users\defra\.conda\envs\py39\lib\site-packages\sklearn\base.py:881, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     878     return self.fit(X, **fit_params).transform(X)
#     879 else:
#     880     # fit method of arity 2 (supervised transformation)
# --> 881     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\defra\.conda\envs\py39\lib\site-packages\AutoCarver\carvers\binary_carver.py:274, in BinaryCarver.fit(self, X, y, X_dev, y_dev)
#     271 x_copy, x_dev_copy = self._prepare_data(X, y, X_dev, y_dev)
#     273 # Fitting BaseCarver
# --> 274 super().fit(x_copy, y, X_dev=x_dev_copy, y_dev=y_dev)
#     276 return self
#
# File c:\Users\defra\.conda\envs\py39\lib\site-packages\AutoCarver\carvers\base_carver.py:333, in BaseCarver.fit(self, X, y, X_dev, y_dev)
#     330     print(f"\n------\n[AutoCarver] Fit {feature} ({n+1}/{len(all_features)})\n---")
#     332 # carving the feature
# --> 333 labels_orders = self._carve_feature(feature, xaggs, xaggs_dev, labels_orders)
#     335 if self.verbose:  # verbose if requested
#     336     print("------\n")
#
# File c:\Users\defra\.conda\envs\py39\lib\site-packages\AutoCarver\carvers\base_carver.py:395, in BaseCarver._carve_feature(self, feature, xaggs, xaggs_dev, labels_orders)
#     388     self._print_xagg(
#     389         xagg=self._index_mapper(feature, labels_orders, xagg),
#     390         xagg_dev=self._index_mapper(feature, labels_orders, xagg_dev),
#     391         message="Raw distribution",
#     392     )
#     394     # getting best combination
# --> 395     best_combination = self._get_best_combination(feature, order, xagg, xagg_dev=xagg_dev)
#     397 # checking that a suitable combination has been found
#     398 if best_combination is not None:
#
# File c:\Users\defra\.conda\envs\py39\lib\site-packages\AutoCarver\carvers\base_carver.py:494, in BaseCarver._get_best_combination(self, feature, order, xagg, xagg_dev)
#     491 combinations = consecutive_combinations(raw_order, self.max_n_mod, min_group_size=1)
#     493 # getting most associated combination
# --> 494 best_association, order = self._get_best_association(
#     495     feature,
#     496     order,
#     497     raw_xagg,
#     498     combinations,
#     499     xagg_dev=raw_xagg_dev,
#     500 )
#     502 # applying best_combination to order and xtabs
#     503 if best_association is not None:
#
# File c:\Users\defra\.conda\envs\py39\lib\site-packages\AutoCarver\carvers\base_carver.py:571, in BaseCarver._get_best_association(self, feature, order, xagg, combinations, xagg_dev, dropna)
#     566 indices_to_groupby = [
#     567     self._combination_formatter(combination) for combination in combinations
#     568 ]
#     570 # grouping tab by its indices
# --> 571 grouped_xaggs = [
#     572     self._grouper(xagg, index_to_groupby)
#     573     for index_to_groupby in tqdm(
#     574         indices_to_groupby, disable=not self.verbose, desc="Grouping modalities   "
#     575     )
#     576 ]
#     578 # computing associations for each tabs
#     579 n_obs = xagg.apply(sum).sum()  # number of observations for xtabs
#
# File c:\Users\defra\.conda\envs\py39\lib\site-packages\AutoCarver\carvers\base_carver.py:572, in <listcomp>(.0)
#     566 indices_to_groupby = [
#     567     self._combination_formatter(combination) for combination in combinations
#     568 ]
#     570 # grouping tab by its indices
#     571 grouped_xaggs = [
# --> 572     self._grouper(xagg, index_to_groupby)
#     573     for index_to_groupby in tqdm(
#     574         indices_to_groupby, disable=not self.verbose, desc="Grouping modalities   "
#     575     )
#     576 ]
#     578 # computing associations for each tabs
#     579 n_obs = xagg.apply(sum).sum()  # number of observations for xtabs
#
# File c:\Users\defra\.conda\envs\py39\lib\site-packages\AutoCarver\carvers\binary_carver.py:183, in BinaryCarver._grouper(self, xtab, groupby)
#     180 summed_values = zeros((len(unique_indices), len(xtab.columns)))
#     182 # for each unique_index found in index_values sums xtab.Values at corresponding position in summed_values
# --> 183 add.at(summed_values, searchsorted(unique_indices, index_values), xtab.values)
#     185 # converting back to dataframe
#     186 return DataFrame(summed_values, index=unique_indices, columns=xtab.columns)
#
# KeyboardInterrupt:

# %%
from AutoCarver.discretizers import Discretizer

# intiating AutoCarver
discretizer = Discretizer(
    quantitative_features=quantitative_features,
    qualitative_features=qualitative_features,
    ordinal_features=ordinal_features,
    values_orders=values_orders,
    min_freq=min_freq,
    verbose=True,  # showing statistics
    copy=True,  # whether or not to return a copy of the input dataset
)

# fitting on training sample
train_set_processed = discretizer.fit_transform(train_set, (train_set[target] == ">50K").astype(int))
# Out:
# ------
# [Discretizer] Fit Qualitative Features
# ---
#  - [OrdinalDiscretizer] Fit ['education']
#  - [CategoricalDiscretizer] Fit ['marital-status', 'sex', 'workclass', 'occupation', 'relationship', 'race', 'native-country', 'income']
# ------
#
# ------
# [Discretizer] Fit Quantitative Features
# ---
#  - [ContinuousDiscretizer] Fit ['age', 'hours-per-week', 'education-num', 'capital-loss', 'capital-gain']
#  - [OrdinalDiscretizer] Fit ['age', 'hours-per-week', 'education-num', 'capital-loss', 'capital-gain']
# ------
