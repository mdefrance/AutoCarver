# %% [markdown]
# # Setting things up
#
# ## About this notebook
#
# In this notebook, we embark on a journey to refine the Iris Dataset for optimal performance in multiclass classification tasks, leveraging the capabilities of the ``MulticlassCarver`` pipeline. Recognized for its association-maximizing discretization, ``MulticlassCarver`` is a versatile Python tool that gracefully handles diverse data types—be they quantitative or qualitative. Our specific objective is to prepare the dataset for multiclass classification, illuminating the distinctive characteristics of Iris flower species.
#
# The Iris Dataset, a classic in the realm of machine learning, presents features such as sepal and petal dimensions for three different Iris species. By employing ``MulticlassCarver``, our goal is to discretize both quantitative and qualitative features seamlessly, tailoring them for effective representation in our multiclass classification models.
#
# Throughout this notebook, we'll unravel the intricacies of ``MulticlassCarver``'s discretization pipeline, showcasing its adaptability to various data types. Whether it involves transforming petal lengths or encoding species information, ``MulticlassCarver`` ensures that each feature is finely tuned for our multiclass classification tasks.
#
# Join us in this exploration as we harness the power of ``MulticlassCarver`` to preprocess the Iris Dataset. Through effective feature engineering and discretization, our aim is to create a dataset that not only distinguishes between Iris species but also sets the stage for the development of accurate and impactful multiclass classification models.
#
# Let's dive in and uncover the potential of ``MulticlassCarver`` in transforming the Iris Dataset for optimal predictive modeling.
#
#
# ## Installation

# %%
# %pip install AutoCarver[jupyter]

# %% [markdown]
# ## Iris Data
#
# In this example notebook, we will use the Iris dataset.
#
# The Iris dataset is a classic and widely used dataset in the field of machine learning and pattern recognition. It was introduced by the British biologist and statistician Sir Ronald A. Fisher in 1936 and has since become a benchmark dataset for various classification and clustering tasks.
#
# The dataset consists of measurements from 150 iris flowers, belonging to three different species: setosa, versicolor, and virginica. Four features are included for each flower: sepal length, sepal width, petal length, and petal width, all measured in centimeters.
#
# The primary objective of the Iris dataset is typically to classify iris flowers into one of the three species based on these four features (multiclass classification).

# %%
from sklearn import datasets

# Load dataset directly from sklearn
iris = datasets.load_iris(as_frame=True)

# conversion to pandas
iris_data = iris["data"]
iris_data["iris_type"] = list(map(lambda u: iris["target_names"][u], iris["target"]))

# Display the first few rows of the dataset
iris_data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   iris_type
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa

# %% [markdown]
# ## Target type and Carver selection

# %%
target = "iris_type"

iris_data[target].value_counts(dropna=False)
# Out:
# iris_type
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# The target ``"iris_type"`` is a multiclass target of type ``str`` used in a classification task. Hence we will use ``AutoCarver.MulticlassCarver`` and ``AutoCarver.selectors.ClassificationSelector`` in following code blocks.

# %% [markdown]
# ## Data Sampling

# %%
from sklearn.model_selection import train_test_split

# stratified sampling by target
train_set, dev_set = train_test_split(iris_data, test_size=0.33, random_state=42, stratify=iris_data[target])

# checking target rate per dataset
train_set[target].value_counts(dropna=False, normalize=True), dev_set[target].value_counts(dropna=False, normalize=True)
# Out:
# (iris_type
#  setosa        0.34
#  virginica     0.33
#  versicolor    0.33
#  Name: proportion, dtype: float64,
#  iris_type
#  virginica     0.34
#  versicolor    0.34
#  setosa        0.32
#  Name: proportion, dtype: float64)

# %% [markdown]
# ## Picking up columns to Carve

# %%
train_set.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 136                6.3               3.4                5.6               2.4
# 17                 5.1               3.5                1.4               0.3
# 142                5.8               2.7                5.1               1.9
# 59                 5.2               2.7                3.9               1.4
# 6                  4.6               3.4                1.4               0.3
#
#       iris_type
# 136   virginica
# 17       setosa
# 142   virginica
# 59   versicolor
# 6        setosa

# %%
# column data types
train_set.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# iris_type                str
# dtype: object

# %%
print(iris["feature_names"])
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %% [markdown]
# All features are quantitative continuous features. Those features will be added to the list of ``quantitative_features``.

# %%
from AutoCarver import Features

# lists of features per data type
features = Features(quantitatives=["sepal length (cm)", "sepal width (cm)", "petal length (cm)", "petal width (cm)"])

# %% [markdown]
# # Using AutoCarver

# %% [markdown]
# ## AutoCarver settings
#
# ### Representativness of modalities
#
# The attribute ``min_freq`` allows one to choose the minimum frequency per basic modalities. It is used by **Discretizers**:
#
# - For quantitative features, it defines the number of quantiles to initialy discretize the features with.
#
# - For qualitative features, it defines the threshold under which a modality is grouped to either a default value or its closest modality.

# %%
min_freq = 0.05

# %% [markdown]
# **Tip:** should be set between ``0.01`` (slower, preciser, less robust) and ``0.2`` (faster, more robust)

# %% [markdown]
# ### Desired number of modalities
#
# The attribute ``max_n_mod`` allows one to choose the maximum number of modalities per carved feature. It is used by **Carvers** has the upper limit of number of modalities per consecutive combination of modalities.

# %%
max_n_mod = 5

# %% [markdown]
# **Tip:** should be set between ``3`` (faster, more robust) and ``7`` (slower, preciser, less robust)

# %% [markdown]
# ### Grouping NaNs
#
# The attribute ``dropna`` allows one to choose whether or not ``nan`` should be grouped with another modality. If set to ``True``, **Carvers** will first find the most suitable combination of non-NaN values, and then test out all possible combinations with ``nan``.

# %%
dropna = False  # anyway, there are no nan in this dataset

# %% [markdown]
# #### Type of output carved features
#
# The attribute ``ordinal_encoding`` allows one to choose the output type:
#
# * Use ``True`` for integer output of ranked modalities (default)
# * Use ``False`` for string output of modalities

# %%
ordinal_encoding = True

# %% [markdown]
# ## Fitting AutoCarver
#
# * First, all quantitative features are discretized:
#     1. Using ``ContinuousDiscretizer`` for quantile discretization that keeps track of over-represented values (more frequent than ``min_freq``)
#     2. Using ``OrdinalDiscretizer`` for any remaining under-represented values (less frequent than ``min_freq/2``) to be grouped with its closest modality
#
# * Second, all features are carved following this recipe, for all classes of ``train_set[target]`` (except one):
#     1. The raw distribution is printed out on provided ``train_set`` and ``dev_set``. It's the output of the discretization step
#     2. Grouping modalities: all consecutive combinations of modalities are applied to ``train_set``
#     3. Computing associations: the association metric (Tschruprow's T, by default) is computed with the provided target ``train_set[target]``
#     4. Combinations are sorted in descending order by association value
#     5. Testing robustness: finds the first combination that checks the following:
#         - Representativness of modalities on ``train_set`` and ``dev_set`` (all should be more frequent than ``min_freq/2``)
#         - Distinct target rates per consecutive modalities on ``train_set`` and ``dev_set``
#         - No inversion of target rates between ``train_set`` and ``dev_set`` (same ordering of modalities by target rate)
#     6. (Optional) If requested via ``dropna=True``, and if any, all combinations of modalities with ``nan`` are applied to ``train_set`` and steps 3. and 4. are run
#     7. The carved distribution is printed out on provided ``train_set`` and ``dev_set``. It's the output of the carving step

# %%
from AutoCarver import MulticlassCarver
from AutoCarver.discretizers.utils.base_discretizer import DiscretizerConfig

# intiating AutoCarver
auto_carver = MulticlassCarver(
    features=features,
    max_n_mod=max_n_mod,
    min_freq=min_freq,
    config=DiscretizerConfig(ordinal_encoding=ordinal_encoding, dropna=dropna, verbose=True, copy=True),
)

# fitting on training sample, a dev sample can be specified to evaluate carving robustness
train_set_processed = auto_carver.fit_transform(train_set, train_set[target], X_dev=dev_set, y_dev=dev_set[target])
# Out:
# WARNING: can't set copy=True for MulticlassCarver (no inplace DataFrame.assign).
#
# ---------
# [MulticlassCarver] Fit y=versicolor (1/2)
# ------
# ------
# --- [QuantitativeDiscretizer] Fit Features(['sepal length (cm)__y=versicolor', 'sepal width (cm)__y=versicolor', 'petal length (cm)__y=versicolor', 'petal width (cm)__y=versicolor'])
#  - [ContinuousDiscretizer] Fit Features(['sepal length (cm)__y=versicolor', 'sepal width (cm)__y=versicolor', 'petal length (cm)__y=versicolor', 'petal width (cm)__y=versicolor'])
# ------
#
# ---------
# ------ [BinaryCarver] Fit Features(['sepal length (cm)__y=versicolor', 'sepal width (cm)__y=versicolor', 'petal length (cm)__y=versicolor', 'petal width (cm)__y=versicolor'])
# --- [BinaryCarver] Fit Quantitative('sepal length (cm)__y=versicolor') (1/4)
#  [BinaryCarver] Raw distribution
# <style type="text/css">
# #T_cba5a_row0_col0, #T_cba5a_row1_col0, #T_cba5a_row2_col0, #T_cba5a_row3_col0, #T_cba5a_row4_col0, #T_cba5a_row8_col0, #T_cba5a_row9_col0, #T_cba5a_row25_col0, #T_cba5a_row26_col0, #T_cba5a_row27_col0, #T_cba5a_row28_col0, #T_cba5a_row29_col1, #T_cba5a_row29_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_cba5a_row0_col1, #T_cba5a_row0_col2, #T_cba5a_row18_col0, #T_cba5a_row20_col1, #T_cba5a_row20_col2, #T_cba5a_row24_col1, #T_cba5a_row24_col2, #T_cba5a_row26_col1, #T_cba5a_row26_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_cba5a_row1_col1, #T_cba5a_row1_col2, #T_cba5a_row4_col1, #T_cba5a_row4_col2, #T_cba5a_row7_col1, #T_cba5a_row7_col2, #T_cba5a_row9_col1, #T_cba5a_row9_col2, #T_cba5a_row11_col1, #T_cba5a_row11_col2, #T_cba5a_row14_col1, #T_cba5a_row14_col2, #T_cba5a_row15_col1, #T_cba5a_row15_col2, #T_cba5a_row16_col1, #T_cba5a_row16_col2, #T_cba5a_row17_col1, #T_cba5a_row17_col2, #T_cba5a_row22_col1, #T_cba5a_row22_col2, #T_cba5a_row23_col1, #T_cba5a_row23_col2, #T_cba5a_row25_col1, #T_cba5a_row25_col2, #T_cba5a_row27_col1, #T_cba5a_row27_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_cba5a_row2_col1, #T_cba5a_row2_col2, #T_cba5a_row5_col0, #T_cba5a_row8_col1, #T_cba5a_row8_col2, #T_cba5a_row28_col1, #T_cba5a_row28_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_cba5a_row3_col1, #T_cba5a_row3_col2, #T_cba5a_row13_col1, #T_cba5a_row13_col2 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_cba5a_row5_col1, #T_cba5a_row5_col2, #T_cba5a_row16_col0, #T_cba5a_row18_col1, #T_cba5a_row18_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cba5a_row6_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_cba5a_row6_col1, #T_cba5a_row6_col2, #T_cba5a_row10_col1, #T_cba5a_row10_col2, #T_cba5a_row21_col1, #T_cba5a_row21_col2 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_cba5a_row7_col0, #T_cba5a_row22_col0, #T_cba5a_row23_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_cba5a_row10_col0, #T_cba5a_row11_col0, #T_cba5a_row14_col0, #T_cba5a_row15_col0, #T_cba5a_row17_col0, #T_cba5a_row21_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_cba5a_row12_col0, #T_cba5a_row20_col0, #T_cba5a_row24_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_cba5a_row12_col1, #T_cba5a_row12_col2, #T_cba5a_row19_col1, #T_cba5a_row19_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_cba5a_row13_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_cba5a_row19_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_cba5a_row29_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cba5a" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cba5a_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_cba5a_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_cba5a_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cba5a_level0_row0" class="row_heading level0 row0" >x <= 4.400e+00</th>
#       <td id="T_cba5a_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_cba5a_row0_col1" class="data row0 col1" >0.0200</td>
#       <td id="T_cba5a_row0_col2" class="data row0 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row1" class="row_heading level0 row1" >4.400e+00 < x <= 4.600e+00</th>
#       <td id="T_cba5a_row1_col0" class="data row1 col0" >0.0000</td>
#       <td id="T_cba5a_row1_col1" class="data row1 col1" >0.0300</td>
#       <td id="T_cba5a_row1_col2" class="data row1 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row2" class="row_heading level0 row2" >4.600e+00 < x <= 4.700e+00</th>
#       <td id="T_cba5a_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_cba5a_row2_col1" class="data row2 col1" >0.0100</td>
#       <td id="T_cba5a_row2_col2" class="data row2 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row3" class="row_heading level0 row3" >4.700e+00 < x <= 4.800e+00</th>
#       <td id="T_cba5a_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_cba5a_row3_col1" class="data row3 col1" >0.0500</td>
#       <td id="T_cba5a_row3_col2" class="data row3 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row4" class="row_heading level0 row4" >4.800e+00 < x <= 4.900e+00</th>
#       <td id="T_cba5a_row4_col0" class="data row4 col0" >0.0000</td>
#       <td id="T_cba5a_row4_col1" class="data row4 col1" >0.0300</td>
#       <td id="T_cba5a_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row5" class="row_heading level0 row5" >4.900e+00 < x <= 5.000e+00</th>
#       <td id="T_cba5a_row5_col0" class="data row5 col0" >0.1429</td>
#       <td id="T_cba5a_row5_col1" class="data row5 col1" >0.0700</td>
#       <td id="T_cba5a_row5_col2" class="data row5 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row6" class="row_heading level0 row6" >5.000e+00 < x <= 5.100e+00</th>
#       <td id="T_cba5a_row6_col0" class="data row6 col0" >0.1667</td>
#       <td id="T_cba5a_row6_col1" class="data row6 col1" >0.0600</td>
#       <td id="T_cba5a_row6_col2" class="data row6 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row7" class="row_heading level0 row7" >5.100e+00 < x <= 5.200e+00</th>
#       <td id="T_cba5a_row7_col0" class="data row7 col0" >0.3333</td>
#       <td id="T_cba5a_row7_col1" class="data row7 col1" >0.0300</td>
#       <td id="T_cba5a_row7_col2" class="data row7 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row8" class="row_heading level0 row8" >5.200e+00 < x <= 5.300e+00</th>
#       <td id="T_cba5a_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_cba5a_row8_col1" class="data row8 col1" >0.0100</td>
#       <td id="T_cba5a_row8_col2" class="data row8 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row9" class="row_heading level0 row9" >5.300e+00 < x <= 5.400e+00</th>
#       <td id="T_cba5a_row9_col0" class="data row9 col0" >0.0000</td>
#       <td id="T_cba5a_row9_col1" class="data row9 col1" >0.0300</td>
#       <td id="T_cba5a_row9_col2" class="data row9 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row10" class="row_heading level0 row10" >5.400e+00 < x <= 5.500e+00</th>
#       <td id="T_cba5a_row10_col0" class="data row10 col0" >0.6667</td>
#       <td id="T_cba5a_row10_col1" class="data row10 col1" >0.0600</td>
#       <td id="T_cba5a_row10_col2" class="data row10 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row11" class="row_heading level0 row11" >5.500e+00 < x <= 5.600e+00</th>
#       <td id="T_cba5a_row11_col0" class="data row11 col0" >0.6667</td>
#       <td id="T_cba5a_row11_col1" class="data row11 col1" >0.0300</td>
#       <td id="T_cba5a_row11_col2" class="data row11 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row12" class="row_heading level0 row12" >5.600e+00 < x <= 5.700e+00</th>
#       <td id="T_cba5a_row12_col0" class="data row12 col0" >0.5000</td>
#       <td id="T_cba5a_row12_col1" class="data row12 col1" >0.0400</td>
#       <td id="T_cba5a_row12_col2" class="data row12 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row13" class="row_heading level0 row13" >5.700e+00 < x <= 5.800e+00</th>
#       <td id="T_cba5a_row13_col0" class="data row13 col0" >0.4000</td>
#       <td id="T_cba5a_row13_col1" class="data row13 col1" >0.0500</td>
#       <td id="T_cba5a_row13_col2" class="data row13 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row14" class="row_heading level0 row14" >5.800e+00 < x <= 5.900e+00</th>
#       <td id="T_cba5a_row14_col0" class="data row14 col0" >0.6667</td>
#       <td id="T_cba5a_row14_col1" class="data row14 col1" >0.0300</td>
#       <td id="T_cba5a_row14_col2" class="data row14 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cba5a_level0_row15" class="row_heading level0 row15" >5.900e+00 < x
#  [BinaryCarver] Carved distribution
# <style type="text/css">
# #T_7d325_row0_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_7d325_row0_col1, #T_7d325_row0_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_7d325_row1_col0, #T_7d325_row1_col1, #T_7d325_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7d325_row2_col0, #T_7d325_row2_col1, #T_7d325_row2_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7d325" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d325_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_7d325_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_7d325_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d325_level0_row0" class="row_heading level0 row0" >x <= 5.40e+00</th>
#       <td id="T_7d325_row0_col0" class="data row0 col0" >0.0882</td>
#       <td id="T_7d325_row0_col1" class="data row0 col1" >0.3400</td>
#       <td id="T_7d325_row0_col2" class="data row0 col2" >34</td>
#     </tr>
#     <tr>
#       <th id="T_7d325_level0_row1" class="row_heading level0 row1" >5.40e+00 < x <= 7.10e+00</th>
#       <td id="T_7d325_row1_col0" class="data row1 col0" >0.5263</td>
#       <td id="T_7d325_row1_col1" class="data row1 col1" >0.5700</td>
#       <td id="T_7d325_row1_col2" class="data row1 col2" >57</td>
#     </tr>
#     <tr>
#       <th id="T_7d325_level0_row2" class="row_heading level0 row2" >7.10e+00 < x</th>
#       <td id="T_7d325_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_7d325_row2_col1" class="data row2 col1" >0.0900</td>
#       <td id="T_7d325_row2_col2" class="data row2 col2" >9</td>
#     </tr>
#   </tbody>
# </table>
#           <style type="text/css">
# #T_bbd6b_row0_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_bbd6b_row0_col1, #T_bbd6b_row0_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_bbd6b_row1_col0, #T_bbd6b_row1_col1, #T_bbd6b_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bbd6b_row2_col0, #T_bbd6b_row2_col1, #T_bbd6b_row2_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bbd6b" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_bbd6b_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_bbd6b_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_bbd6b_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bbd6b_row0_col0" class="data row0 col0" >0.1667</td>
#       <td id="T_bbd6b_row0_col1" class="data row0 col1" >0.3600</td>
#       <td id="T_bbd6b_row0_col2" class="data row0 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_bbd6b_row1_col0" class="data row1 col0" >0.4667</td>
#       <td id="T_bbd6b_row1_col1" class="data row1 col1" >0.6000</td>
#       <td id="T_bbd6b_row1_col2" class="data row1 col2" >30</td>
#     </tr>
#     <tr>
#       <td id="T_bbd6b_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_bbd6b_row2_col1" class="data row2 col1" >0.0400</td>
#       <td id="T_bbd6b_row2_col2" class="data row2 col2" >2</td>
#     </tr>
#   </tbody>
# </table>
# --- [BinaryCarver] Fit Quantitative('sepal width (cm)__y=versicolor') (2/4)
#  [BinaryCarver] Raw distribution
# <style type="text/css">
# #T_b2993_row0_col0, #T_b2993_row2_col0, #T_b2993_row8_col1, #T_b2993_row8_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b2993_row0_col1, #T_b2993_row0_col2, #T_b2993_row11_col0, #T_b2993_row12_col0, #T_b2993_row13_col0, #T_b2993_row14_col0, #T_b2993_row15_col0, #T_b2993_row15_col1, #T_b2993_row15_col2, #T_b2993_row16_col0, #T_b2993_row17_col0, #T_b2993_row18_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b2993_row1_col0, #T_b2993_row7_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_b2993_row1_col1, #T_b2993_row1_col2, #T_b2993_row2_col1, #T_b2993_row2_col2, #T_b2993_row14_col1, #T_b2993_row14_col2, #T_b2993_row17_col1, #T_b2993_row17_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_b2993_row3_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_b2993_row3_col1, #T_b2993_row3_col2, #T_b2993_row16_col1, #T_b2993_row16_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_b2993_row4_col0 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_b2993_row4_col1, #T_b2993_row4_col2, #T_b2993_row11_col1, #T_b2993_row11_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b2993_row5_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_b2993_row5_col1, #T_b2993_row5_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_b2993_row6_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_b2993_row6_col1, #T_b2993_row6_col2, #T_b2993_row9_col1, #T_b2993_row9_col2, #T_b2993_row10_col1, #T_b2993_row10_col2 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_b2993_row7_col1, #T_b2993_row7_col2, #T_b2993_row12_col1, #T_b2993_row12_col2, #T_b2993_row13_col1, #T_b2993_row13_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_b2993_row8_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_b2993_row9_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_b2993_row10_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_b2993_row18_col1, #T_b2993_row18_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b2993" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2993_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_b2993_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_b2993_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2993_level0_row0" class="row_heading level0 row0" >x <= 2.000e+00</th>
#       <td id="T_b2993_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_b2993_row0_col1" class="data row0 col1" >0.0100</td>
#       <td id="T_b2993_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row1" class="row_heading level0 row1" >2.000e+00 < x <= 2.200e+00</th>
#       <td id="T_b2993_row1_col0" class="data row1 col0" >0.6667</td>
#       <td id="T_b2993_row1_col1" class="data row1 col1" >0.0300</td>
#       <td id="T_b2993_row1_col2" class="data row1 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row2" class="row_heading level0 row2" >2.200e+00 < x <= 2.400e+00</th>
#       <td id="T_b2993_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_b2993_row2_col1" class="data row2 col1" >0.0300</td>
#       <td id="T_b2993_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row3" class="row_heading level0 row3" >2.400e+00 < x <= 2.500e+00</th>
#       <td id="T_b2993_row3_col0" class="data row3 col0" >0.6000</td>
#       <td id="T_b2993_row3_col1" class="data row3 col1" >0.0500</td>
#       <td id="T_b2993_row3_col2" class="data row3 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row4" class="row_heading level0 row4" >2.500e+00 < x <= 2.600e+00</th>
#       <td id="T_b2993_row4_col0" class="data row4 col0" >0.7500</td>
#       <td id="T_b2993_row4_col1" class="data row4 col1" >0.0400</td>
#       <td id="T_b2993_row4_col2" class="data row4 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row5" class="row_heading level0 row5" >2.600e+00 < x <= 2.700e+00</th>
#       <td id="T_b2993_row5_col0" class="data row5 col0" >0.5714</td>
#       <td id="T_b2993_row5_col1" class="data row5 col1" >0.0700</td>
#       <td id="T_b2993_row5_col2" class="data row5 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row6" class="row_heading level0 row6" >2.700e+00 < x <= 2.800e+00</th>
#       <td id="T_b2993_row6_col0" class="data row6 col0" >0.4444</td>
#       <td id="T_b2993_row6_col1" class="data row6 col1" >0.0900</td>
#       <td id="T_b2993_row6_col2" class="data row6 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row7" class="row_heading level0 row7" >2.800e+00 < x <= 2.900e+00</th>
#       <td id="T_b2993_row7_col0" class="data row7 col0" >0.6667</td>
#       <td id="T_b2993_row7_col1" class="data row7 col1" >0.0600</td>
#       <td id="T_b2993_row7_col2" class="data row7 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row8" class="row_heading level0 row8" >2.900e+00 < x <= 3.000e+00</th>
#       <td id="T_b2993_row8_col0" class="data row8 col0" >0.2857</td>
#       <td id="T_b2993_row8_col1" class="data row8 col1" >0.1400</td>
#       <td id="T_b2993_row8_col2" class="data row8 col2" >14</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row9" class="row_heading level0 row9" >3.000e+00 < x <= 3.100e+00</th>
#       <td id="T_b2993_row9_col0" class="data row9 col0" >0.3333</td>
#       <td id="T_b2993_row9_col1" class="data row9 col1" >0.0900</td>
#       <td id="T_b2993_row9_col2" class="data row9 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row10" class="row_heading level0 row10" >3.100e+00 < x <= 3.200e+00</th>
#       <td id="T_b2993_row10_col0" class="data row10 col0" >0.2222</td>
#       <td id="T_b2993_row10_col1" class="data row10 col1" >0.0900</td>
#       <td id="T_b2993_row10_col2" class="data row10 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row11" class="row_heading level0 row11" >3.200e+00 < x <= 3.300e+00</th>
#       <td id="T_b2993_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_b2993_row11_col1" class="data row11 col1" >0.0400</td>
#       <td id="T_b2993_row11_col2" class="data row11 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row12" class="row_heading level0 row12" >3.300e+00 < x <= 3.400e+00</th>
#       <td id="T_b2993_row12_col0" class="data row12 col0" >0.0000</td>
#       <td id="T_b2993_row12_col1" class="data row12 col1" >0.0600</td>
#       <td id="T_b2993_row12_col2" class="data row12 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row13" class="row_heading level0 row13" >3.400e+00 < x <= 3.500e+00</th>
#       <td id="T_b2993_row13_col0" class="data row13 col0" >0.0000</td>
#       <td id="T_b2993_row13_col1" class="data row13 col1" >0.0600</td>
#       <td id="T_b2993_row13_col2" class="data row13 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row14" class="row_heading level0 row14" >3.500e+00 < x <= 3.600e+00</th>
#       <td id="T_b2993_row14_col0" class="data row14 col0" >0.0000</td>
#       <td id="T_b2993_row14_col1" class="data row14 col1" >0.0300</td>
#       <td id="T_b2993_row14_col2" class="data row14 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row15" class="row_heading level0 row15" >3.600e+00 < x <= 3.700e+00</th>
#       <td id="T_b2993_row15_col0" class="data row15 col0" >0.0000</td>
#       <td id="T_b2993_row15_col1" class="data row15 col1" >0.0100</td>
#       <td id="T_b2993_row15_col2" class="data row15 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b2993_level0_row16" class="row_heading level0 row16" >3.700e+00 < x <= 3.800e+00</th>
#       <td id="T_b2993_row16_col0" class="data row16 col0" >0.0000</td>
#       <td id="T_b2993_row16_col1" class="data row16 col1" >0.0500</td>
#       <td id="T_b2993_row16_col2" class="data row16 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_b2
#  [BinaryCarver] Carved distribution
# <style type="text/css">
# #T_18a16_row0_col0, #T_18a16_row1_col1, #T_18a16_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_18a16_row0_col1, #T_18a16_row0_col2, #T_18a16_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_18a16" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18a16_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_18a16_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_18a16_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18a16_level0_row0" class="row_heading level0 row0" >x <= 2.9e+00</th>
#       <td id="T_18a16_row0_col0" class="data row0 col0" >0.6316</td>
#       <td id="T_18a16_row0_col1" class="data row0 col1" >0.3800</td>
#       <td id="T_18a16_row0_col2" class="data row0 col2" >38</td>
#     </tr>
#     <tr>
#       <th id="T_18a16_level0_row1" class="row_heading level0 row1" >2.9e+00 < x</th>
#       <td id="T_18a16_row1_col0" class="data row1 col0" >0.1452</td>
#       <td id="T_18a16_row1_col1" class="data row1 col1" >0.6200</td>
#       <td id="T_18a16_row1_col2" class="data row1 col2" >62</td>
#     </tr>
#   </tbody>
# </table>
#           <style type="text/css">
# #T_2bc46_row0_col0, #T_2bc46_row1_col1, #T_2bc46_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2bc46_row0_col1, #T_2bc46_row0_col2, #T_2bc46_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2bc46" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_2bc46_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_2bc46_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_2bc46_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2bc46_row0_col0" class="data row0 col0" >0.5263</td>
#       <td id="T_2bc46_row0_col1" class="data row0 col1" >0.3800</td>
#       <td id="T_2bc46_row0_col2" class="data row0 col2" >19</td>
#     </tr>
#     <tr>
#       <td id="T_2bc46_row1_col0" class="data row1 col0" >0.2258</td>
#       <td id="T_2bc46_row1_col1" class="data row1 col1" >0.6200</td>
#       <td id="T_2bc46_row1_col2" class="data row1 col2" >31</td>
#     </tr>
#   </tbody>
# </table>
# --- [BinaryCarver] Fit Quantitative('petal length (cm)__y=versicolor') (3/4)
#  [BinaryCarver] Raw distribution
# <style type="text/css">
# #T_50c5f_row0_col0, #T_50c5f_row0_col1, #T_50c5f_row0_col2, #T_50c5f_row1_col0, #T_50c5f_row2_col0, #T_50c5f_row3_col0, #T_50c5f_row4_col0, #T_50c5f_row5_col0, #T_50c5f_row12_col1, #T_50c5f_row12_col2, #T_50c5f_row17_col0, #T_50c5f_row19_col0, #T_50c5f_row20_col0, #T_50c5f_row21_col0, #T_50c5f_row22_col0, #T_50c5f_row23_col0, #T_50c5f_row24_col0, #T_50c5f_row25_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_50c5f_row1_col1, #T_50c5f_row1_col2, #T_50c5f_row5_col1, #T_50c5f_row5_col2, #T_50c5f_row6_col1, #T_50c5f_row6_col2, #T_50c5f_row9_col1, #T_50c5f_row9_col2, #T_50c5f_row13_col1, #T_50c5f_row13_col2, #T_50c5f_row14_col1, #T_50c5f_row14_col2, #T_50c5f_row15_col1, #T_50c5f_row15_col2, #T_50c5f_row17_col1, #T_50c5f_row17_col2, #T_50c5f_row21_col1, #T_50c5f_row21_col2, #T_50c5f_row22_col1, #T_50c5f_row22_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_50c5f_row2_col1, #T_50c5f_row2_col2, #T_50c5f_row6_col0, #T_50c5f_row7_col0, #T_50c5f_row8_col0, #T_50c5f_row9_col0, #T_50c5f_row10_col0, #T_50c5f_row11_col0, #T_50c5f_row12_col0, #T_50c5f_row13_col0, #T_50c5f_row14_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_50c5f_row3_col1, #T_50c5f_row3_col2 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_50c5f_row4_col1, #T_50c5f_row4_col2, #T_50c5f_row8_col1, #T_50c5f_row8_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_50c5f_row7_col1, #T_50c5f_row7_col2, #T_50c5f_row10_col1, #T_50c5f_row10_col2, #T_50c5f_row19_col1, #T_50c5f_row19_col2, #T_50c5f_row24_col1, #T_50c5f_row24_col2, #T_50c5f_row25_col1, #T_50c5f_row25_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_50c5f_row11_col1, #T_50c5f_row11_col2, #T_50c5f_row16_col1, #T_50c5f_row16_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_50c5f_row15_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_50c5f_row16_col0, #T_50c5f_row18_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_50c5f_row18_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_50c5f_row18_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_50c5f_row20_col1, #T_50c5f_row20_col2, #T_50c5f_row23_col1, #T_50c5f_row23_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# </style>
# <table id="T_50c5f" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50c5f_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_50c5f_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_50c5f_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50c5f_level0_row0" class="row_heading level0 row0" >x <= 1.100e+00</th>
#       <td id="T_50c5f_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_50c5f_row0_col1" class="data row0 col1" >0.0100</td>
#       <td id="T_50c5f_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row1" class="row_heading level0 row1" >1.100e+00 < x <= 1.300e+00</th>
#       <td id="T_50c5f_row1_col0" class="data row1 col0" >0.0000</td>
#       <td id="T_50c5f_row1_col1" class="data row1 col1" >0.0300</td>
#       <td id="T_50c5f_row1_col2" class="data row1 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row2" class="row_heading level0 row2" >1.300e+00 < x <= 1.400e+00</th>
#       <td id="T_50c5f_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_50c5f_row2_col1" class="data row2 col1" >0.1100</td>
#       <td id="T_50c5f_row2_col2" class="data row2 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row3" class="row_heading level0 row3" >1.400e+00 < x <= 1.500e+00</th>
#       <td id="T_50c5f_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_50c5f_row3_col1" class="data row3 col1" >0.0900</td>
#       <td id="T_50c5f_row3_col2" class="data row3 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row4" class="row_heading level0 row4" >1.500e+00 < x <= 1.600e+00</th>
#       <td id="T_50c5f_row4_col0" class="data row4 col0" >0.0000</td>
#       <td id="T_50c5f_row4_col1" class="data row4 col1" >0.0700</td>
#       <td id="T_50c5f_row4_col2" class="data row4 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row5" class="row_heading level0 row5" >1.600e+00 < x <= 1.900e+00</th>
#       <td id="T_50c5f_row5_col0" class="data row5 col0" >0.0000</td>
#       <td id="T_50c5f_row5_col1" class="data row5 col1" >0.0300</td>
#       <td id="T_50c5f_row5_col2" class="data row5 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row6" class="row_heading level0 row6" >1.900e+00 < x <= 3.500e+00</th>
#       <td id="T_50c5f_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_50c5f_row6_col1" class="data row6 col1" >0.0300</td>
#       <td id="T_50c5f_row6_col2" class="data row6 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row7" class="row_heading level0 row7" >3.500e+00 < x <= 3.700e+00</th>
#       <td id="T_50c5f_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_50c5f_row7_col1" class="data row7 col1" >0.0200</td>
#       <td id="T_50c5f_row7_col2" class="data row7 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row8" class="row_heading level0 row8" >3.700e+00 < x <= 4.000e+00</th>
#       <td id="T_50c5f_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_50c5f_row8_col1" class="data row8 col1" >0.0700</td>
#       <td id="T_50c5f_row8_col2" class="data row8 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row9" class="row_heading level0 row9" >4.000e+00 < x <= 4.200e+00</th>
#       <td id="T_50c5f_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_50c5f_row9_col1" class="data row9 col1" >0.0300</td>
#       <td id="T_50c5f_row9_col2" class="data row9 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row10" class="row_heading level0 row10" >4.200e+00 < x <= 4.300e+00</th>
#       <td id="T_50c5f_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_50c5f_row10_col1" class="data row10 col1" >0.0200</td>
#       <td id="T_50c5f_row10_col2" class="data row10 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row11" class="row_heading level0 row11" >4.300e+00 < x <= 4.400e+00</th>
#       <td id="T_50c5f_row11_col0" class="data row11 col0" >1.0000</td>
#       <td id="T_50c5f_row11_col1" class="data row11 col1" >0.0400</td>
#       <td id="T_50c5f_row11_col2" class="data row11 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row12" class="row_heading level0 row12" >4.400e+00 < x <= 4.500e+00</th>
#       <td id="T_50c5f_row12_col0" class="data row12 col0" >1.0000</td>
#       <td id="T_50c5f_row12_col1" class="data row12 col1" >0.0100</td>
#       <td id="T_50c5f_row12_col2" class="data row12 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row13" class="row_heading level0 row13" >4.500e+00 < x <= 4.600e+00</th>
#       <td id="T_50c5f_row13_col0" class="data row13 col0" >1.0000</td>
#       <td id="T_50c5f_row13_col1" class="data row13 col1" >0.0300</td>
#       <td id="T_50c5f_row13_col2" class="data row13 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row14" class="row_heading level0 row14" >4.600e+00 < x <= 4.700e+00</th>
#       <td id="T_50c5f_row14_col0" class="data row14 col0" >1.0000</td>
#       <td id="T_50c5f_row14_col1" class="data row14 col1" >0.0300</td>
#       <td id="T_50c5f_row14_col2" class="data row14 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row15" class="row_heading level0 row15" >4.700e+00 < x <= 4.800e+00</th>
#       <td id="T_50c5f_row15_col0" class="data row15 col0" >0.6667</td>
#       <td id="T_50c5f_row15_col1" class="data row15 col1" >0.0300</td>
#       <td id="T_50c5f_row15_col2" class="data row15 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_50c5f_level0_row16" class="row_heading level0 row16" >4.800e+00 < x <= 4.900e+00</th>
#       <td id="T_50c5f_row16_col0" class="data row16 co
#  [BinaryCarver] Carved distribution
# <style type="text/css">
# #T_7ca63_row0_col0, #T_7ca63_row1_col1, #T_7ca63_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7ca63_row0_col1, #T_7ca63_row0_col2 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_7ca63_row1_col0, #T_7ca63_row2_col1, #T_7ca63_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7ca63_row2_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7ca63" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ca63_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_7ca63_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_7ca63_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ca63_level0_row0" class="row_heading level0 row0" >x <= 1.90e+00</th>
#       <td id="T_7ca63_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_7ca63_row0_col1" class="data row0 col1" >0.3400</td>
#       <td id="T_7ca63_row0_col2" class="data row0 col2" >34</td>
#     </tr>
#     <tr>
#       <th id="T_7ca63_level0_row1" class="row_heading level0 row1" >1.90e+00 < x <= 4.80e+00</th>
#       <td id="T_7ca63_row1_col0" class="data row1 col0" >0.9677</td>
#       <td id="T_7ca63_row1_col1" class="data row1 col1" >0.3100</td>
#       <td id="T_7ca63_row1_col2" class="data row1 col2" >31</td>
#     </tr>
#     <tr>
#       <th id="T_7ca63_level0_row2" class="row_heading level0 row2" >4.80e+00 < x</th>
#       <td id="T_7ca63_row2_col0" class="data row2 col0" >0.0857</td>
#       <td id="T_7ca63_row2_col1" class="data row2 col1" >0.3500</td>
#       <td id="T_7ca63_row2_col2" class="data row2 col2" >35</td>
#     </tr>
#   </tbody>
# </table>
#           <style type="text/css">
# #T_e029b_row0_col0, #T_e029b_row0_col1, #T_e029b_row0_col2, #T_e029b_row2_col1, #T_e029b_row2_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e029b_row1_col0, #T_e029b_row1_col1, #T_e029b_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e029b_row2_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e029b" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_e029b_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_e029b_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_e029b_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e029b_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_e029b_row0_col1" class="data row0 col1" >0.3200</td>
#       <td id="T_e029b_row0_col2" class="data row0 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_e029b_row1_col0" class="data row1 col0" >0.8889</td>
#       <td id="T_e029b_row1_col1" class="data row1 col1" >0.3600</td>
#       <td id="T_e029b_row1_col2" class="data row1 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_e029b_row2_col0" class="data row2 col0" >0.0625</td>
#       <td id="T_e029b_row2_col1" class="data row2 col1" >0.3200</td>
#       <td id="T_e029b_row2_col2" class="data row2 col2" >16</td>
#     </tr>
#   </tbody>
# </table>
# --- [BinaryCarver] Fit Quantitative('petal width (cm)__y=versicolor') (4/4)
#  [BinaryCarver] Raw distribution
# <style type="text/css">
# #T_6c228_row0_col0, #T_6c228_row1_col0, #T_6c228_row2_col0, #T_6c228_row3_col0, #T_6c228_row4_col0, #T_6c228_row13_col0, #T_6c228_row14_col0, #T_6c228_row15_col0, #T_6c228_row16_col0, #T_6c228_row17_col0, #T_6c228_row18_col0, #T_6c228_row19_col0, #T_6c228_row20_col1, #T_6c228_row20_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6c228_row0_col1, #T_6c228_row0_col2, #T_6c228_row2_col1, #T_6c228_row2_col2, #T_6c228_row7_col1, #T_6c228_row7_col2, #T_6c228_row17_col1, #T_6c228_row17_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_6c228_row1_col1, #T_6c228_row1_col2, #T_6c228_row5_col0, #T_6c228_row6_col0, #T_6c228_row7_col0, #T_6c228_row8_col0, #T_6c228_row9_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6c228_row3_col1, #T_6c228_row3_col2, #T_6c228_row9_col1, #T_6c228_row9_col2, #T_6c228_row15_col1, #T_6c228_row15_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_6c228_row4_col1, #T_6c228_row4_col2, #T_6c228_row16_col1, #T_6c228_row16_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_6c228_row5_col1, #T_6c228_row5_col2, #T_6c228_row13_col1, #T_6c228_row13_col2, #T_6c228_row14_col1, #T_6c228_row14_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_6c228_row6_col1, #T_6c228_row6_col2, #T_6c228_row11_col1, #T_6c228_row11_col2, #T_6c228_row18_col1, #T_6c228_row18_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_6c228_row8_col1, #T_6c228_row8_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_6c228_row10_col0 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_6c228_row10_col1, #T_6c228_row10_col2, #T_6c228_row12_col1, #T_6c228_row12_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_6c228_row11_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_6c228_row12_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_6c228_row19_col1, #T_6c228_row19_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_6c228_row20_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6c228" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c228_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_6c228_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_6c228_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c228_level0_row0" class="row_heading level0 row0" >x <= 1.000e-01</th>
#       <td id="T_6c228_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_6c228_row0_col1" class="data row0 col1" >0.0500</td>
#       <td id="T_6c228_row0_col2" class="data row0 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row1" class="row_heading level0 row1" >1.000e-01 < x <= 2.000e-01</th>
#       <td id="T_6c228_row1_col0" class="data row1 col0" >0.0000</td>
#       <td id="T_6c228_row1_col1" class="data row1 col1" >0.1700</td>
#       <td id="T_6c228_row1_col2" class="data row1 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row2" class="row_heading level0 row2" >2.000e-01 < x <= 3.000e-01</th>
#       <td id="T_6c228_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_6c228_row2_col1" class="data row2 col1" >0.0500</td>
#       <td id="T_6c228_row2_col2" class="data row2 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row3" class="row_heading level0 row3" >3.000e-01 < x <= 4.000e-01</th>
#       <td id="T_6c228_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_6c228_row3_col1" class="data row3 col1" >0.0600</td>
#       <td id="T_6c228_row3_col2" class="data row3 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row4" class="row_heading level0 row4" >4.000e-01 < x <= 6.000e-01</th>
#       <td id="T_6c228_row4_col0" class="data row4 col0" >0.0000</td>
#       <td id="T_6c228_row4_col1" class="data row4 col1" >0.0100</td>
#       <td id="T_6c228_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row5" class="row_heading level0 row5" >6.000e-01 < x <= 1.000e+00</th>
#       <td id="T_6c228_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_6c228_row5_col1" class="data row5 col1" >0.0400</td>
#       <td id="T_6c228_row5_col2" class="data row5 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row6" class="row_heading level0 row6" >1.000e+00 < x <= 1.100e+00</th>
#       <td id="T_6c228_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_6c228_row6_col1" class="data row6 col1" >0.0200</td>
#       <td id="T_6c228_row6_col2" class="data row6 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row7" class="row_heading level0 row7" >1.100e+00 < x <= 1.200e+00</th>
#       <td id="T_6c228_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_6c228_row7_col1" class="data row7 col1" >0.0500</td>
#       <td id="T_6c228_row7_col2" class="data row7 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row8" class="row_heading level0 row8" >1.200e+00 < x <= 1.300e+00</th>
#       <td id="T_6c228_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_6c228_row8_col1" class="data row8 col1" >0.0800</td>
#       <td id="T_6c228_row8_col2" class="data row8 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row9" class="row_heading level0 row9" >1.300e+00 < x <= 1.400e+00</th>
#       <td id="T_6c228_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_6c228_row9_col1" class="data row9 col1" >0.0600</td>
#       <td id="T_6c228_row9_col2" class="data row9 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row10" class="row_heading level0 row10" >1.400e+00 < x <= 1.500e+00</th>
#       <td id="T_6c228_row10_col0" class="data row10 col0" >0.8571</td>
#       <td id="T_6c228_row10_col1" class="data row10 col1" >0.0700</td>
#       <td id="T_6c228_row10_col2" class="data row10 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row11" class="row_heading level0 row11" >1.500e+00 < x <= 1.600e+00</th>
#       <td id="T_6c228_row11_col0" class="data row11 col0" >0.5000</td>
#       <td id="T_6c228_row11_col1" class="data row11 col1" >0.0200</td>
#       <td id="T_6c228_row11_col2" class="data row11 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row12" class="row_heading level0 row12" >1.600e+00 < x <= 1.800e+00</th>
#       <td id="T_6c228_row12_col0" class="data row12 col0" >0.1429</td>
#       <td id="T_6c228_row12_col1" class="data row12 col1" >0.0700</td>
#       <td id="T_6c228_row12_col2" class="data row12 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row13" class="row_heading level0 row13" >1.800e+00 < x <= 1.900e+00</th>
#       <td id="T_6c228_row13_col0" class="data row13 col0" >0.0000</td>
#       <td id="T_6c228_row13_col1" class="data row13 col1" >0.0400</td>
#       <td id="T_6c228_row13_col2" class="data row13 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row14" class="row_heading level0 row14" >1.900e+00 < x <= 2.000e+00</th>
#       <td id="T_6c228_row14_col0" class="data row14 col0" >0.0000</td>
#       <td id="T_6c228_row14_col1" class="data row14 col1" >0.0400</td>
#       <td id="T_6c228_row14_col2" class="data row14 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row15" class="row_heading level0 row15" >2.000e+00 < x <= 2.100e+00</th>
#       <td id="T_6c228_row15_col0" class="data row15 col0" >0.0000</td>
#       <td id="T_6c228_row15_col1" class="data row15 col1" >0.0600</td>
#       <td id="T_6c228_row15_col2" class="data row15 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row16" class="row_heading level0 row16" >2.100e+00 < x <= 2.200e+00</th>
#       <td id="T_6c228_row16_col0" class="data row16 col0" >0.0000</td>
#       <td id="T_6c228_row16_col1" class="data row16 col1" >0.0100</td>
#       <td id="T_6c228_row16_col2" class="data row16 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6c228_level0_row17" class=
#  [BinaryCarver] Carved distribution
# <style type="text/css">
# #T_d5621_row0_col0, #T_d5621_row2_col1, #T_d5621_row2_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d5621_row0_col1, #T_d5621_row0_col2, #T_d5621_row1_col0, #T_d5621_row1_col1, #T_d5621_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d5621_row2_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d5621" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5621_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_d5621_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_d5621_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5621_level0_row0" class="row_heading level0 row0" >x <= 6.00e-01</th>
#       <td id="T_d5621_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_d5621_row0_col1" class="data row0 col1" >0.3400</td>
#       <td id="T_d5621_row0_col2" class="data row0 col2" >34</td>
#     </tr>
#     <tr>
#       <th id="T_d5621_level0_row1" class="row_heading level0 row1" >6.00e-01 < x <= 1.60e+00</th>
#       <td id="T_d5621_row1_col0" class="data row1 col0" >0.9412</td>
#       <td id="T_d5621_row1_col1" class="data row1 col1" >0.3400</td>
#       <td id="T_d5621_row1_col2" class="data row1 col2" >34</td>
#     </tr>
#     <tr>
#       <th id="T_d5621_level0_row2" class="row_heading level0 row2" >1.60e+00 < x</th>
#       <td id="T_d5621_row2_col0" class="data row2 col0" >0.0312</td>
#       <td id="T_d5621_row2_col1" class="data row2 col1" >0.3200</td>
#       <td id="T_d5621_row2_col2" class="data row2 col2" >32</td>
#     </tr>
#   </tbody>
# </table>
#           <style type="text/css">
# #T_4be8d_row0_col0, #T_4be8d_row0_col1, #T_4be8d_row0_col2, #T_4be8d_row2_col1, #T_4be8d_row2_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4be8d_row1_col0, #T_4be8d_row1_col1, #T_4be8d_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4be8d_row2_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4be8d" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_4be8d_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_4be8d_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_4be8d_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4be8d_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_4be8d_row0_col1" class="data row0 col1" >0.3200</td>
#       <td id="T_4be8d_row0_col2" class="data row0 col2" >16</td>
#     </tr>
#     <tr>
#       <td id="T_4be8d_row1_col0" class="data row1 col0" >0.8889</td>
#       <td id="T_4be8d_row1_col1" class="data row1 col1" >0.3600</td>
#       <td id="T_4be8d_row1_col2" class="data row1 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_4be8d_row2_col0" class="data row2 col0" >0.0625</td>
#       <td id="T_4be8d_row2_col1" class="data row2 col1" >0.3200</td>
#       <td id="T_4be8d_row2_col2" class="data row2 col2" >16</td>
#     </tr>
#   </tbody>
# </table>
# ---------
#
#
# ---------
# [MulticlassCarver] Fit y=virginica (2/2)
# ------
# ------
# --- [QuantitativeDiscretizer] Fit Features(['sepal length (cm)__y=virginica', 'sepal width (cm)__y=virginica', 'petal length (cm)__y=virginica', 'petal width (cm)__y=virginica'])
#  - [ContinuousDiscretizer] Fit Features(['sepal length (cm)__y=virginica', 'sepal width (cm)__y=virginica', 'petal length (cm)__y=virginica', 'petal width (cm)__y=virginica'])
# ------
#
# ---------
# ------ [BinaryCarver] Fit Features(['sepal length (cm)__y=virginica', 'sepal width (cm)__y=virginica', 'petal length (cm)__y=virginica', 'petal width (cm)__y=virginica'])
# --- [BinaryCarver] Fit Quantitative('sepal length (cm)__y=virginica') (1/4)
#  [BinaryCarver] Raw distribution
# <style type="text/css">
# #T_87375_row0_col0, #T_87375_row1_col0, #T_87375_row2_col0, #T_87375_row3_col0, #T_87375_row4_col0, #T_87375_row5_col0, #T_87375_row6_col0, #T_87375_row7_col0, #T_87375_row8_col0, #T_87375_row9_col0, #T_87375_row10_col0, #T_87375_row16_col0, #T_87375_row29_col1, #T_87375_row29_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_87375_row0_col1, #T_87375_row0_col2, #T_87375_row20_col1, #T_87375_row20_col2, #T_87375_row24_col1, #T_87375_row24_col2, #T_87375_row26_col1, #T_87375_row26_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_87375_row1_col1, #T_87375_row1_col2, #T_87375_row4_col1, #T_87375_row4_col2, #T_87375_row7_col1, #T_87375_row7_col2, #T_87375_row9_col1, #T_87375_row9_col2, #T_87375_row11_col1, #T_87375_row11_col2, #T_87375_row14_col1, #T_87375_row14_col2, #T_87375_row15_col1, #T_87375_row15_col2, #T_87375_row16_col1, #T_87375_row16_col2, #T_87375_row17_col1, #T_87375_row17_col2, #T_87375_row22_col1, #T_87375_row22_col2, #T_87375_row23_col1, #T_87375_row23_col2, #T_87375_row25_col1, #T_87375_row25_col2, #T_87375_row27_col1, #T_87375_row27_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_87375_row2_col1, #T_87375_row2_col2, #T_87375_row8_col1, #T_87375_row8_col2, #T_87375_row28_col1, #T_87375_row28_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_87375_row3_col1, #T_87375_row3_col2, #T_87375_row13_col1, #T_87375_row13_col2, #T_87375_row18_col0 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_87375_row5_col1, #T_87375_row5_col2, #T_87375_row18_col1, #T_87375_row18_col2, #T_87375_row25_col0, #T_87375_row26_col0, #T_87375_row27_col0, #T_87375_row28_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_87375_row6_col1, #T_87375_row6_col2, #T_87375_row10_col1, #T_87375_row10_col2, #T_87375_row21_col1, #T_87375_row21_col2 {
#   background-color: #e26952;
# ...
#       <td id="T_bf1f1_row7_col1" class="data row7 col1" >0.0200</td>
#       <td id="T_bf1f1_row7_col2" class="data row7 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bf1f1_level0_row8" class="row_heading level0 row8" >3.700e+00 < x <= 4.000e+00</th>
#       <td id="T_bf1f1_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_bf1f1_row8_col1" class="data row8 col1" >0.0700</td>
#       <td id="T_bf1f1_row8_col2" class="data row8 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_bf1f1_level0_row9" class="row_heading level0 row9" >4.000e+00 < x <= 4.200e+00</th>
#       <td id="T_bf1f1_row9_col0" class="data row9 col0" >0.0000</td>
#       <td id="T_bf1f1_row9_col1" class="data row9 col1" >0.0300</td>
#       <td id="T_bf1f1_row9_col2" class="data row9 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bf1f1_level0_row10" class="row_heading level0 row10" >4.200e+00 < x <= 4.300e+00</th>
#       <td id="T_bf1f1_row10_col0" class="data row10 col0" >0.0000</td>
#       <td id="T_bf1f1_row10_col1" class="data row10 col1" >0.0200</td>
#       <td id="T_bf1f1_row10_col2" class="data row10 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bf1f1_level0_row11" class="row_heading level0 row11" >4.300e+00 < x <= 4.400e+00</th>
#       <td id="T_bf1f1_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_bf1f1_row11_col1" class="data row11 col1" >0.0400</td>
#       <td id="T_bf1f1_row11_col2" class="data row11 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bf1f1_level0_row12" class="row_heading level0 row12" >4.400e+00 < x <= 4.500e+00</th>
#       <td id="T_bf1f1_row12_col0" class="data row12 col0" >0.0000</td>
#       <td id="T_bf1f1_row12_col1" class="data row12 col1" >0.0100</td>
#       <td id="T_bf1f1_row12_col2" class="data row12 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bf1f1_level0_row13" class="row_heading level0 row13" >4.500e+00 < x <= 4.600e+00</th>
#       <td id="T_bf1f1_row13_col0" class="data row13 col0" >0.0000</td>
#       <td id="T_bf1f1_row13_col1" class="data row13 col1" >0.0300</td>
#       <td id="T_bf1f1_row13_col2" class="data row13 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bf1f1_level0_row14" class="row_heading level0 row14" >4.600e+00 < x <= 4.700e+00</th>
#       <td id="T_bf1f1_row14_col0" class="data row14 col0" >0.0000</td>
#       <td id="T_bf1f1_row14_col1" class="data row14 col1" >0.0300</td>
#       <td id="T_bf1f1_row14_col2" class="data row14 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bf1f1_level0_row15" class="row_heading level0 row15" >4.700e+00 < x <= 4.800e+00</th>
#       <td id="T_bf1f1_row15_col0" class="data row15 col0" >0.3333</td>
#       <td id="T_bf1f1_row15_col1" class="data row15 col1" >0.0300</td>
#       <td id="T_bf1f1_row15_col2" class="data row15 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bf1f1_level0_row16" class="row_heading level0 row16" >4.800e+00 < x <= 4.900e+00</th>
#       <td id="T_bf1f1_row16_col0" class="data row16 co
#  [BinaryCarver] Carved distribution
# <style type="text/css">
# #T_2d672_row0_col0, #T_2d672_row1_col1, #T_2d672_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2d672_row0_col1, #T_2d672_row0_col2, #T_2d672_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2d672" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d672_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_2d672_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_2d672_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d672_level0_row0" class="row_heading level0 row0" >x <= 4.8e+00</th>
#       <td id="T_2d672_row0_col0" class="data row0 col0" >0.0154</td>
#       <td id="T_2d672_row0_col1" class="data row0 col1" >0.6500</td>
#       <td id="T_2d672_row0_col2" class="data row0 col2" >65</td>
#     </tr>
#     <tr>
#       <th id="T_2d672_level0_row1" class="row_heading level0 row1" >4.8e+00 < x</th>
#       <td id="T_2d672_row1_col0" class="data row1 col0" >0.9143</td>
#       <td id="T_2d672_row1_col1" class="data row1 col1" >0.3500</td>
#       <td id="T_2d672_row1_col2" class="data row1 col2" >35</td>
#     </tr>
#   </tbody>
# </table>
#           <style type="text/css">
# #T_7446e_row0_col0, #T_7446e_row1_col1, #T_7446e_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7446e_row0_col1, #T_7446e_row0_col2, #T_7446e_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7446e" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_7446e_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_7446e_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_7446e_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7446e_row0_col0" class="data row0 col0" >0.0588</td>
#       <td id="T_7446e_row0_col1" class="data row0 col1" >0.6800</td>
#       <td id="T_7446e_row0_col2" class="data row0 col2" >34</td>
#     </tr>
#     <tr>
#       <td id="T_7446e_row1_col0" class="data row1 col0" >0.9375</td>
#       <td id="T_7446e_row1_col1" class="data row1 col1" >0.3200</td>
#       <td id="T_7446e_row1_col2" class="data row1 col2" >16</td>
#     </tr>
#   </tbody>
# </table>
# --- [BinaryCarver] Fit Quantitative('petal width (cm)__y=virginica') (4/4)
#  [BinaryCarver] Raw distribution
# <style type="text/css">
# #T_8827f_row0_col0, #T_8827f_row1_col0, #T_8827f_row2_col0, #T_8827f_row3_col0, #T_8827f_row4_col0, #T_8827f_row5_col0, #T_8827f_row6_col0, #T_8827f_row7_col0, #T_8827f_row8_col0, #T_8827f_row9_col0, #T_8827f_row20_col1, #T_8827f_row20_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8827f_row0_col1, #T_8827f_row0_col2, #T_8827f_row2_col1, #T_8827f_row2_col2, #T_8827f_row7_col1, #T_8827f_row7_col2, #T_8827f_row17_col1, #T_8827f_row17_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_8827f_row1_col1, #T_8827f_row1_col2, #T_8827f_row13_col0, #T_8827f_row14_col0, #T_8827f_row15_col0, #T_8827f_row16_col0, #T_8827f_row17_col0, #T_8827f_row18_col0, #T_8827f_row19_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8827f_row3_col1, #T_8827f_row3_col2, #T_8827f_row9_col1, #T_8827f_row9_col2, #T_8827f_row15_col1, #T_8827f_row15_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_8827f_row4_col1, #T_8827f_row4_col2, #T_8827f_row16_col1, #T_8827f_row16_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_8827f_row5_col1, #T_8827f_row5_col2, #T_8827f_row13_col1, #T_8827f_row13_col2, #T_8827f_row14_col1, #T_8827f_row14_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_8827f_row6_col1, #T_8827f_row6_col2, #T_8827f_row11_col1, #T_8827f_row11_col2, #T_8827f_row18_col1, #T_8827f_row18_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_8827f_row8_col1, #T_8827f_row8_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_8827f_row10_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_8827f_row10_col1, #T_8827f_row10_col2, #T_8827f_row12_col1, #T_8827f_row12_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_8827f_row11_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_8827f_row12_col0 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_8827f_row19_col1, #T_8827f_row19_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_8827f_row20_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8827f" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8827f_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_8827f_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_8827f_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8827f_level0_row0" class="row_heading level0 row0" >x <= 1.000e-01</th>
#       <td id="T_8827f_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_8827f_row0_col1" class="data row0 col1" >0.0500</td>
#       <td id="T_8827f_row0_col2" class="data row0 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row1" class="row_heading level0 row1" >1.000e-01 < x <= 2.000e-01</th>
#       <td id="T_8827f_row1_col0" class="data row1 col0" >0.0000</td>
#       <td id="T_8827f_row1_col1" class="data row1 col1" >0.1700</td>
#       <td id="T_8827f_row1_col2" class="data row1 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row2" class="row_heading level0 row2" >2.000e-01 < x <= 3.000e-01</th>
#       <td id="T_8827f_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_8827f_row2_col1" class="data row2 col1" >0.0500</td>
#       <td id="T_8827f_row2_col2" class="data row2 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row3" class="row_heading level0 row3" >3.000e-01 < x <= 4.000e-01</th>
#       <td id="T_8827f_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_8827f_row3_col1" class="data row3 col1" >0.0600</td>
#       <td id="T_8827f_row3_col2" class="data row3 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row4" class="row_heading level0 row4" >4.000e-01 < x <= 6.000e-01</th>
#       <td id="T_8827f_row4_col0" class="data row4 col0" >0.0000</td>
#       <td id="T_8827f_row4_col1" class="data row4 col1" >0.0100</td>
#       <td id="T_8827f_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row5" class="row_heading level0 row5" >6.000e-01 < x <= 1.000e+00</th>
#       <td id="T_8827f_row5_col0" class="data row5 col0" >0.0000</td>
#       <td id="T_8827f_row5_col1" class="data row5 col1" >0.0400</td>
#       <td id="T_8827f_row5_col2" class="data row5 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row6" class="row_heading level0 row6" >1.000e+00 < x <= 1.100e+00</th>
#       <td id="T_8827f_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_8827f_row6_col1" class="data row6 col1" >0.0200</td>
#       <td id="T_8827f_row6_col2" class="data row6 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row7" class="row_heading level0 row7" >1.100e+00 < x <= 1.200e+00</th>
#       <td id="T_8827f_row7_col0" class="data row7 col0" >0.0000</td>
#       <td id="T_8827f_row7_col1" class="data row7 col1" >0.0500</td>
#       <td id="T_8827f_row7_col2" class="data row7 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row8" class="row_heading level0 row8" >1.200e+00 < x <= 1.300e+00</th>
#       <td id="T_8827f_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_8827f_row8_col1" class="data row8 col1" >0.0800</td>
#       <td id="T_8827f_row8_col2" class="data row8 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row9" class="row_heading level0 row9" >1.300e+00 < x <= 1.400e+00</th>
#       <td id="T_8827f_row9_col0" class="data row9 col0" >0.0000</td>
#       <td id="T_8827f_row9_col1" class="data row9 col1" >0.0600</td>
#       <td id="T_8827f_row9_col2" class="data row9 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row10" class="row_heading level0 row10" >1.400e+00 < x <= 1.500e+00</th>
#       <td id="T_8827f_row10_col0" class="data row10 col0" >0.1429</td>
#       <td id="T_8827f_row10_col1" class="data row10 col1" >0.0700</td>
#       <td id="T_8827f_row10_col2" class="data row10 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row11" class="row_heading level0 row11" >1.500e+00 < x <= 1.600e+00</th>
#       <td id="T_8827f_row11_col0" class="data row11 col0" >0.5000</td>
#       <td id="T_8827f_row11_col1" class="data row11 col1" >0.0200</td>
#       <td id="T_8827f_row11_col2" class="data row11 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row12" class="row_heading level0 row12" >1.600e+00 < x <= 1.800e+00</th>
#       <td id="T_8827f_row12_col0" class="data row12 col0" >0.8571</td>
#       <td id="T_8827f_row12_col1" class="data row12 col1" >0.0700</td>
#       <td id="T_8827f_row12_col2" class="data row12 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row13" class="row_heading level0 row13" >1.800e+00 < x <= 1.900e+00</th>
#       <td id="T_8827f_row13_col0" class="data row13 col0" >1.0000</td>
#       <td id="T_8827f_row13_col1" class="data row13 col1" >0.0400</td>
#       <td id="T_8827f_row13_col2" class="data row13 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row14" class="row_heading level0 row14" >1.900e+00 < x <= 2.000e+00</th>
#       <td id="T_8827f_row14_col0" class="data row14 col0" >1.0000</td>
#       <td id="T_8827f_row14_col1" class="data row14 col1" >0.0400</td>
#       <td id="T_8827f_row14_col2" class="data row14 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row15" class="row_heading level0 row15" >2.000e+00 < x <= 2.100e+00</th>
#       <td id="T_8827f_row15_col0" class="data row15 col0" >1.0000</td>
#       <td id="T_8827f_row15_col1" class="data row15 col1" >0.0600</td>
#       <td id="T_8827f_row15_col2" class="data row15 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row16" class="row_heading level0 row16" >2.100e+00 < x <= 2.200e+00</th>
#       <td id="T_8827f_row16_col0" class="data row16 col0" >1.0000</td>
#       <td id="T_8827f_row16_col1" class="data row16 col1" >0.0100</td>
#       <td id="T_8827f_row16_col2" class="data row16 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8827f_level0_row17" class=
#  [BinaryCarver] Carved distribution
# <style type="text/css">
# #T_ce55e_row0_col0, #T_ce55e_row1_col1, #T_ce55e_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ce55e_row0_col1, #T_ce55e_row0_col2, #T_ce55e_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ce55e" style='display:inline'>
#   <caption>X distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce55e_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_ce55e_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_ce55e_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce55e_level0_row0" class="row_heading level0 row0" >x <= 1.5e+00</th>
#       <td id="T_ce55e_row0_col0" class="data row0 col0" >0.0152</td>
#       <td id="T_ce55e_row0_col1" class="data row0 col1" >0.6600</td>
#       <td id="T_ce55e_row0_col2" class="data row0 col2" >66</td>
#     </tr>
#     <tr>
#       <th id="T_ce55e_level0_row1" class="row_heading level0 row1" >1.5e+00 < x</th>
#       <td id="T_ce55e_row1_col0" class="data row1 col0" >0.9412</td>
#       <td id="T_ce55e_row1_col1" class="data row1 col1" >0.3400</td>
#       <td id="T_ce55e_row1_col2" class="data row1 col2" >34</td>
#     </tr>
#   </tbody>
# </table>
#           <style type="text/css">
# #T_19a62_row0_col0, #T_19a62_row1_col1, #T_19a62_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_19a62_row0_col1, #T_19a62_row0_col2, #T_19a62_row1_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_19a62" style='display:inline'>
#   <caption>X_dev distribution</caption>
#   <thead>
#     <tr>
#       <th id="T_19a62_level0_col0" class="col_heading level0 col0" >target_mean</th>
#       <th id="T_19a62_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_19a62_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_19a62_row0_col0" class="data row0 col0" >0.0625</td>
#       <td id="T_19a62_row0_col1" class="data row0 col1" >0.6400</td>
#       <td id="T_19a62_row0_col2" class="data row0 col2" >32</td>
#     </tr>
#     <tr>
#       <td id="T_19a62_row1_col0" class="data row1 col0" >0.8333</td>
#       <td id="T_19a62_row1_col1" class="data row1 col1" >0.3600</td>
#       <td id="T_19a62_row1_col2" class="data row1 col2" >18</td>
#     </tr>
#   </tbody>
# </table>
# ---------

# %% [markdown]
# ## AutoCarver analysis
#
# ### Carving Summary

# %%
auto_carver.summary
# Out:
#                                                                                                         content  \
# feature                                         count cramerv  tschuprowt n_mod label
# Quantitative('sepal length (cm)__y=versicolor') 34.0  0.483288 0.406395   3     0                 x <= 5.40e+00
#                                                 57.0  0.483288 0.406395   3     1      5.40e+00 < x <= 7.10e+00
#                                                 9.0   0.483288 0.406395   3     2                  7.10e+00 < x
# Quantitative('sepal width (cm)__y=versicolor')  38.0  0.480207 0.480207   2     0                  x <= 2.9e+00
#                                                 62.0  0.480207 0.480207   2     1                   2.9e+00 < x
# Quantitative('petal length (cm)__y=versicolor') 34.0  0.912237 0.767096   3     0                 x <= 1.90e+00
#                                                 31.0  0.912237 0.767096   3     1      1.90e+00 < x <= 4.80e+00
#                                                 35.0  0.912237 0.767096   3     2                  4.80e+00 < x
# Quantitative('petal width (cm)__y=versicolor')  34.0  0.933300 0.784809   3     0                 x <= 6.00e-01
#                                                                                 1      6.00e-01 < x <= 1.60e+00
#                                                 32.0  0.933300 0.784809   3     2                  1.60e+00 < x
# Quantitative('sepal length (cm)__y=virginica')  64.0  0.559144 0.559144   2     0                  x <= 6.2e+00
#                                                 36.0  0.559144 0.559144   2     1                   6.2e+00 < x
# Quantitative('sepal width (cm)__y=virginica')   7.0   0.266452 0.224058   3     0                 x <= 2.40e+00
#                                                 67.0  0.266452 0.224058   3     1      2.40e+00 < x <= 3.30e+00
#                                                 26.0  0.266452 0.224058   3     2                  3.30e+00 < x
# Quantitative('petal length (cm)__y=virginica')  65.0  0.889524 0.889524   2     0                  x <= 4.8e+00
#                                                 35.0  0.889524 0.889524   2     1                   4.8e+00 < x
# Quantitative('petal width (cm)__y=virginica')   66.0  0.910463 0.910463   2     0                  x <= 1.5e+00
#                                                 34.0  0.910463 0.910463   2     1                   1.5e+00 < x
#
#                                                                                        target_mean  \
# feature                                         count cramerv  tschuprowt n_mod label
# Quantitative('sepal length (cm)__y=versicolor') 34.0  0.483288 0.406395   3     0         0.088235
#                                                 57.0  0.483288 0.406395   3     1         0.526316
#                                                 9.0   0.483288 0.406395   3     2         0.000000
# Quantitative('sepal width (cm)__y=versicolor')  38.0  0.480207 0.480207   2     0         0.631579
#                                                 62.0  0.480207 0.480207   2     1         0.145161
# Quantitative('petal length (cm)__y=versicolor') 34.0  0.912237 0.767096   3     0         0.000000
#                                                 31.0  0.912237 0.767096   3     1         0.967742
#                                                 35.0  0.912237 0.767096   3     2         0.085714
# Quantitative('petal width (cm)__y=versicolor')  34.0  0.933300 0.784809   3     0         0.000000
#                                                                                 1         0.941176
#                                                 32.0  0.933300 0.784809   3     2         0.031250
# Quantitative('sepal length (cm)__y=virginica')  64.0  0.559144 0.559144   2     0         0.125000
#                                                 36.0  0.559144 0.559144   2     1         0.694444
# Quantitative('sepal width (cm)__y=virginica')   7.0   0.266452 0.224058   3     0         0.142857
#                                                 67.0  0.266452 0.224058   3     1         0.417910
#                                                 26.0  0.266452 0.224058   3     2         0.153846
# Quantitative('petal length (cm)__y=virginica')  65.0  0.889524 0.889524   2     0         0.015385
#                                                 35.0  0.889524 0.889524   2     1         0.914286
# Quantitative('petal width (cm)__y=virginica')   66.0  0.910463 0.910463   2     0         0.015152
#                                                 34.0  0.910463 0.910463   2     1         0.941176
#
#                                                                                        frequency  \
# feature                                         count cramerv  tschuprowt n_mod label
# Quantitative('sepal length (cm)__y=versicolor') 34.0  0.483288 0.406395   3     0           0.34
#                                                 57.0  0.483288 0.406395   3     1           0.57
#                                                 9.0   0.483288 0.406395   3     2           0.09
# Quantitative('sepal width (cm)__y=versicolor')  38.0  0.480207 0.480207   2     0           0.38
#                                                 62.0  0.480207 0.480207   2     1           0.62
# Quantitative('petal length (cm)__y=versicolor') 34.0  0.912237 0.767096   3     0           0.34
#                                                 31.0  0.912237 0.767096   3     1           0.31
#                                                 35.0  0.912237 0.767096   3     2           0.35
# Quantitative('petal width (cm)__y=versicolor')  34.0  0.933300 0.784809   3     0           0.34
#                                                                                 1           0.34
#                                                 32.0  0.933300 0.784809   3     2           0.32
# Quantitative('sepal length (cm)__y=virginica')  64.0  0.559144 0.559144   2     0           0.64
#                                                 36.0  0.559144 0.559144   2     1           0.36
# Quantitative('sepal width (cm)__y=virginica')   7.0   0.266452 0.224058   3     0           0.07
#                                                 67.0  0.266452 0.224058   3     1           0.67
#                                                 26.0  0.266452 0.224058   3     2           0.26
# Quantitative('petal length (cm)__y=virginica')  65.0  0.889524 0.889524   2     0           0.65
#                                                 35.0  0.889524 0.889524   2     1           0.35
# Quantitative('petal width (cm)__y=virginica')   66.0  0.910463 0.910463   2     0           0.66
#                                                 34.0  0.910463 0.910463   2     1           0.34
#
#                                                                                        dropped  \
# feature                                         count cramerv  tschuprowt n_mod label
# Quantitative('sepal length (cm)__y=versicolor') 34.0  0.483288 0.406395   3     0        False
#                                                 57.0  0.483288 0.406395   3     1        False
#                                                 9.0   0.483288 0.406395   3     2        False
# Quantitative('sepal width (cm)__y=versicolor')  38.0  0.480207 0.480207   2     0        False
#                                                 62.0  0.480207 0.480207   2     1        False
# Quantitative('petal length (cm)__y=versicolor') 34.0  0.912237 0.767096   3     0        False
#                                                 31.0  0.912237 0.767096   3     1        False
#                                                 35.0  0.912237 0.767096   3     2        False
# Quantitative('petal width (cm)__y=versicolor')  34.0  0.933300 0.784809   3     0        False
#                                                                                 1        False
#                                                 32.0  0.933300 0.784809   3     2        False
# Quantitative('sepal length (cm)__y=virginica')  64.0  0.559144 0.559144   2     0        False
#                                                 36.0  0.559144 0.559144   2     1        False
# Quantitative('sepal width (cm)__y=virginica')   7.0   0.266452 0.224058   3     0        False
#                                                 67.0  0.266452 0.224058   3     1        False
#                                                 26.0  0.266452 0.224058   3     2        False
# Quantitative('petal length (cm)__y=virginica')  65.0  0.889524 0.889524   2     0        False
#                                                 35.0  0.889524 0.889524   2     1        False
# Quantitative('petal width (cm)__y=virginica')   66.0  0.910463 0.910463   2     0        False
#                                                 34.0  0.910463 0.910463   2     1        False
#
#                                                                                       dropped_reason
# feature                                         count cramerv  tschuprowt n_mod label
# Quantitative('sepal length (cm)__y=versicolor') 34.0  0.483288 0.406395   3     0               None
#                                                 57.0  0.483288 0.406395   3     1               None
#                                                 9.0   0.483288 0.406395   3     2               None
# Quantitative('sepal width (cm)__y=versicolor')  38.0  0.480207 0.480207   2     0               None
#                                                 62.0  0.480207 0.480207   2     1               None
# Quantitative('petal length (cm)__y=versicolor') 34.0  0.912237 0.767096   3     0               None
#                                                 31.0  0.912237 0.767096   3     1               None
#                                                 35.0  0.912237 0.767096   3     2               None
# Quantitative('petal width (cm)__y=versicolor')  34.0  0.933300 0.784809   3     0               None
#                                                                                 1               None
#                                                 32.0  0.933300 0.784809   3     2               None
# Quantitative('sepal length (cm)__y=virginica')  64.0  0.559144 0.559144   2     0               None
#                                                 36.0  0.559144 0.559144   2     1               None
# Quantitative('sepal width (cm)__y=virginica')   7.0   0.266452 0.224058   3     0               None
#                                                 67.0  0.266452 0.224058   3     1               None
#                                                 26.0  0.266452 0.224058   3     2               None
# Quantitative('petal length (cm)__y=virginica')  65.0  0.889524 0.889524   2     0               None
#                                                 35.0  0.889524 0.889524   2     1               None
# Quantitative('petal width (cm)__y=virginica')   66.0  0.910463 0.910463   2     0               None
#                                                 34.0  0.910463 0.910463   2     1               None

# %% [markdown]
# * As requested with ``ordinal_encoding=True``, output labels are integers of modalities
#
# * Features have been carved for two distinct binary targets:
#     * ``y=versicolor``: dummy of target ``iris_type`` taking value ``"versicolor"``
#     * ``y=virginica``: dummy of target ``iris_type`` taking value ``"virginica"``
#
# * For quantitative feature ``petal width (cm)``, for ``y=virginica``, the selected combination of modalities groups petal widths as follows:
#     * label ``0``: lower or equal to 1.5cm (``content="x <= 1.5e+00"``)
#     * label ``1``: higher than 1.5cm (``content="1.5e+00 < x"``)
#
# ### Detailed overview of tested combinations

# %%
features['sepal length (cm)__y=versicolor'].history.head(7)
# Out:
#                                       info   cramerv  tschuprowt  \
# 0  Raw distribution (n_mod=30>max_n_mod=5)  0.590426    0.254429
# 1      Best for tschuprowt and max_n_mod=5  0.483288    0.406395
#
#                                          combination  n_mod  dropna  \
# 0  {'x <= 4.400e+00': 'x <= 4.400e+00', '4.400e+0...     30   False
# 1  {'x <= 4.400e+00': 'x <= 4.400e+00', '4.400e+0...      3   False
#
#                           train viable                           dev
# 0                           NaN    NaN                           NaN
# 1  {'viable': True, 'info': ''}   True  {'viable': True, 'info': ''}

# %%
features['sepal length (cm)__y=versicolor'].history.dev[1]
# Out:
# {'viable': True, 'info': ''}

# %% [markdown]
# * The most associated combination of feature ``sepal length (cm)__y=versicolor`` (the first tested out, where ``info!="Raw distribution"``) did not pass the viability tests. When looking in ``history.dev``:
#     * ``"Non-representative modality for min_freq=5.00%"``: tells us that a modality is unstable between ``train_set`` and ``dev_set``
#
# * For feature ``sepal length (cm)__y=versicolor``, the 4th combination is the first to pass the tests:
#     - ``info="Best for tschuprowt and max_n_mod=5"``
#     - Tschuprow's T with ``ìris_type`` is ``0.390543`` for this combination (by default, combinations are ranked according to this statistic)
#     - Following combinations (less associated with the target) where not tested: ``info="Not checked"``
#
# * For all combinations ``dropna=False`` means that it is not a combination in which ``nan``s are being groupedwith other modalities (as requested with ``dropna=False``)

# %% [markdown]
# ## Saving and Loading AutoCarver

# %% [markdown]
# ### Saving
#
# All **Carvers** can safely be stored as a .json file.

# %%
auto_carver.save("multiclass_carver.json")

# %% [markdown]
# ### Loading
#
# **Carvers** can safely be loaded from a .json file.

# %%
from AutoCarver import MulticlassCarver

auto_carver = MulticlassCarver.load("multiclass_carver.json")
# Out:
# WARNING: can't set copy=True for MulticlassCarver (no inplace DataFrame.assign).

# %% [markdown]
# ## Applying AutoCarver

# %%
dev_set_processed = auto_carver.transform(dev_set)

# %%
dev_set_processed[auto_carver.features].apply(lambda u: u.value_counts(dropna=False, normalize=True))
# Out:
#      sepal length (cm)__y=versicolor  sepal width (cm)__y=versicolor  \
# 0.0                             0.36                            0.38
# 1.0                             0.60                            0.62
# 2.0                             0.04                             NaN
#
#      petal length (cm)__y=versicolor  petal width (cm)__y=versicolor  \
# 0.0                             0.32                            0.32
# 1.0                             0.36                            0.36
# 2.0                             0.32                            0.32
#
#      sepal length (cm)__y=virginica  sepal width (cm)__y=virginica  \
# 0.0                             0.7                           0.08
# 1.0                             0.3                           0.70
# 2.0                             NaN                           0.22
#
#      petal length (cm)__y=virginica  petal width (cm)__y=virginica
# 0.0                            0.68                           0.64
# 1.0                            0.32                           0.36
# 2.0                             NaN                            NaN

# %% [markdown]
# # Feature Selection
# ## Selectors settings

# %% [markdown]
# ### Features to select from
#
# Here all features have been carved using ``MulticlassCarver``, hence all features are qualitative.

# %% [markdown]
# ### Number of features to select
#
# The attribute ``n_best`` allows one to choose the number of features to be selected per data type (quantitative and qualitative).

# %%
n_best_per_type = 4  # here the number of features is low, ClassificationSelector will only be used to compute useful statistics

# %% [markdown]
# ## Using Selectors

# %%
from AutoCarver.selectors import ClassificationSelector
from AutoCarver.discretizers.utils.base_discretizer import DiscretizerConfig

# select the most target associated qualitative features
feature_selector = ClassificationSelector(
    features=features,
    n_best_per_type=n_best_per_type,
    config=DiscretizerConfig(verbose=True),  # displays statistics
)
best_features = feature_selector.select(train_set_processed, train_set_processed[target])
best_features
# Out:
#  [ClassificationSelector] Selected Qualitative Features
# <style type="text/css">
# #T_64d6a_row0_col3, #T_64d6a_row1_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_64d6a_row0_col5, #T_64d6a_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_64d6a_row1_col3 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_64d6a_row2_col3 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_64d6a_row2_col5 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_64d6a_row3_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_64d6a_row3_col5 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_64d6a_row4_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_64d6a_row4_col5 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_64d6a_row5_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_64d6a_row5_col5 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_64d6a_row6_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_64d6a_row6_col5 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_64d6a_row7_col5 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# </style>
# <table id="T_64d6a" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64d6a_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_64d6a_level0_col1" class="col_heading level0 col1" >Nan</th>
#       <th id="T_64d6a_level0_col2" class="col_heading level0 col2" >Mode</th>
#       <th id="T_64d6a_level0_col3" class="col_heading level0 col3" >TschuprowtMeasure</th>
#       <th id="T_64d6a_level0_col4" class="col_heading level0 col4" >TschuprowtRank</th>
#       <th id="T_64d6a_level0_col5" class="col_heading level0 col5" >TschuprowtFilter</th>
#       <th id="T_64d6a_level0_col6" class="col_heading level0 col6" >TschuprowtWith</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64d6a_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_64d6a_row0_col0" class="data row0 col0" >Quantitative('petal width (cm)__y=versicolor')</td>
#       <td id="T_64d6a_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_64d6a_row0_col2" class="data row0 col2" >0.3400</td>
#       <td id="T_64d6a_row0_col3" class="data row0 col3" >0.9558</td>
#       <td id="T_64d6a_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_64d6a_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_64d6a_row0_col6" class="data row0 col6" >itself</td>
#     </tr>
#     <tr>
#       <th id="T_64d6a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_64d6a_row1_col0" class="data row1 col0" >Quantitative('petal length (cm)__y=versicolor')</td>
#       <td id="T_64d6a_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_64d6a_row1_col2" class="data row1 col2" >0.3500</td>
#       <td id="T_64d6a_row1_col3" class="data row1 col3" >0.9421</td>
#       <td id="T_64d6a_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_64d6a_row1_col5" class="data row1 col5" >0.9018</td>
#       <td id="T_64d6a_row1_col6" class="data row1 col6" >petal width (cm)__y=versicolor</td>
#     </tr>
#     <tr>
#       <th id="T_64d6a_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_64d6a_row2_col0" class="data row2 col0" >Quantitative('petal width (cm)__y=virginica')</td>
#       <td id="T_64d6a_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_64d6a_row2_col2" class="data row2 col2" >0.6600</td>
#       <td id="T_64d6a_row2_col3" class="data row2 col3" >0.7857</td>
#       <td id="T_64d6a_row2_col4" class="data row2 col4" >2.0000</td>
#       <td id="T_64d6a_row2_col5" class="data row2 col5" >0.8049</td>
#       <td id="T_64d6a_row2_col6" class="data row2 col6" >petal width (cm)__y=versicolor</td>
#     </tr>
#     <tr>
#       <th id="T_64d6a_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_64d6a_row3_col0" class="data row3 col0" >Quantitative('petal length (cm)__y=virginica')</td>
#       <td id="T_64d6a_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_64d6a_row3_col2" class="data row3 col2" >0.6500</td>
#       <td id="T_64d6a_row3_col3" class="data row3 col3" >0.7695</td>
#       <td id="T_64d6a_row3_col4" class="data row3 col4" >3.0000</td>
#       <td id="T_64d6a_row3_col5" class="data row3 col5" >0.8675</td>
#       <td id="T_64d6a_row3_col6" class="data row3 col6" >petal width (cm)__y=virginica</td>
#     </tr>
#     <tr>
#       <th id="T_64d6a_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_64d6a_row4_col0" class="data row4 col0" >Quantitative('sepal length (cm)__y=versicolor')</td>
#       <td id="T_64d6a_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_64d6a_row4_col2" class="data row4 col2" >0.5700</td>
#       <td id="T_64d6a_row4_col3" class="data row4 col3" >0.6713</td>
#       <td id="T_64d6a_row4_col4" class="data row4 col4" >4.0000</td>
#       <td id="T_64d6a_row4_col5" class="data row4 col5" >0.6649</td>
#       <td id="T_64d6a_row4_col6" class="data row4 col6" >petal length (cm)__y=versicolor</td>
#     </tr>
#     <tr>
#       <th id="T_64d6a_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_64d6a_row5_col0" class="data row5 col0" >Quantitative('sepal length (cm)__y=virginica')</td>
#       <td id="T_64d6a_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_64d6a_row5_col2" class="data row5 col2" >0.6400</td>
#       <td id="T_64d6a_row5_col3" class="data row5 col3" >0.5441</td>
#       <td id="T_64d6a_row5_col4" class="data row5 col4" >5.0000</td>
#       <td id="T_64d6a_row5_col5" class="data row5 col5" >0.6071</td>
#       <td id="T_64d6a_row5_col6" class="data row5 col6" >petal length (cm)__y=virginica</td>
#     </tr>
#     <tr>
#       <th id="T_64d6a_level0_row6" class="row_heading level0 row6" >1</th>
#       <td id="T_64d6a_row6_col0" class="data row6 col0" >Quantitative('sepal width (cm)__y=versicolor')</td>
#       <td id="T_64d6a_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_64d6a_row6_col2" class="data row6 col2" >0.6200</td>
#       <td id="T_64d6a_row6_col3" class="data row6 col3" >0.4950</td>
#       <td id="T_64d6a_row6_col4" class="data row6 col4" >6.0000</td>
#       <td id="T_64d6a_row6_col5" class="data row6 col5" >0.5042</td>
#       <td id="T_64d6a_row6_col6" class="data row6 col6" >petal width (cm)__y=versicolor</td>
#     </tr>
#     <tr>
#       <th id="T_64d6a_level0_row7" class="row_heading level0 row7" >5</th>
#       <td id="T_64d6a_row7_col0" class="data row7 col0" >Quantitative('sepal width (cm)__y=virginica')</td>
#       <td id="T_64d6a_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_64d6a_row7_col2" class="data row7 col2" >0.6700</td>
#       <td id="T_64d6a_row7_col3" class="data row7 col3" >0.4868</td>
#       <td id="T_64d6a_row7_col4" class="data row7 col4" >7.0000</td>
#       <td id="T_64d6a_row7_col5" class="data row7 col5" >0.5107</td>
#       <td id="T_64d6a_row7_col6" class="data row7 col6" >petal width (cm)__y=versicolor</td>
#     </tr>
#   </tbody>
# </table>
# Features(['petal width (cm)__y=versicolor', 'petal length (cm)__y=versicolor', 'petal width (cm)__y=virginica', 'petal length (cm)__y=virginica'])

# %%
train_set_processed[best_features].head()
# Out:
#      petal width (cm)__y=versicolor  petal length (cm)__y=versicolor  \
# 136                             2.0                              2.0
# 17                              0.0                              0.0
# 142                             2.0                              2.0
# 59                              1.0                              1.0
# 6                               0.0                              0.0
#
#      petal width (cm)__y=virginica  petal length (cm)__y=virginica
# 136                            1.0                             1.0
# 17                             0.0                             0.0
# 142                            1.0                             1.0
# 59                             0.0                             0.0
# 6                              0.0                             0.0

# %% [markdown]
# * Feature ``petal width (cm)_versicolor`` is the most associated with the target ``iris_type``:
#     - Tschuprow's T value is ``TschuprowtMeasure=0.9558``
#     - Its has 0 % of NaNs (``NanMeasure=0.0``)
#     - Its mode, ``0``, represents 31 % of observed data (``pct_nan=0.3100``)
#
# * Feature ``petal length (cm)__y=versicolor`` is strongly associated to feature ``petal width (cm)_versicolor``:
#     - Tschuprow's T value is ``TschuprowtFilter=0.9274`` for ``TschuprowtWith=petal width (cm)_versicolor``
#
# * Here, no feature where filtered out for there inter-feature association or over-represented values (no thresholds were set)

# %% [markdown]
# # Modeling
# Fitting model on train data

# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder

# Encode string labels to integers
label_encoder = LabelEncoder()
train_set_processed[target] = label_encoder.fit_transform(train_set[target])

model = XGBClassifier(objective='multi:softmax')
model.fit(train_set_processed[best_features], train_set_processed[target])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# Saving model

# %%
model.save_model("multiclass_xgboost.json")

# %% [markdown]
# Prediction on dev dataset and performance

# %%
from sklearn.metrics import accuracy_score

dev_set_processed[target] = label_encoder.transform(dev_set[target])
dev_pred = model.predict(dev_set_processed[best_features])
accuracy_score(dev_set_processed[target], dev_pred)
# Out:
# 0.94

# %% [markdown]
# ## What's next?
#
# * Thanks to **Carvers** all of your features are now optimally processed for your classification task!
# * As a final step towards your model, **Selectors** can prove to be handy tools to operate target optimal Data Pre-Selection, so make sure to check out [Selectors Examples](https://autocarver.readthedocs.io/en/latest/selectors_examples.html)!
#
# ## Well done!
#
# Your commitment to achieving optimal results in multiclass classification tasks shines through in your meticulous use of **AutoCarver**'s ``MulticlassCarver`` for data preprocessing. By fine-tuning and optimizing your dataset, you have set the stage for robust and accurate machine learning models.
#
# The ``MulticlassCarver`` has proven to be a valuable ally in your pursuit of excellence, carving out a path toward enhanced feature representation and model interpretability. Your dedication to refining the data preprocessing steps reflects a commitment to extracting the maximum value from your datasets.
#
# We extend our sincere appreciation for choosing **AutoCarver** as your companion in the data preprocessing journey. Your use of **AutoCarver** demonstrates a dedication to leveraging cutting-edge tools for achieving excellence in multiclass classification tasks.
#
# As you transition to the modeling phase, may the carefully crafted features and preprocessing steps contribute to the success of your predictive models. We're excited to see the impact of your work and are grateful for the opportunity to be part of your data science endeavors.
#
# Thank you for trusting **AutoCarver**, and we wish you continued success in your data-driven ventures.
